# %% [markdown]
# #Présentation du projet Mastermind - Python
# Ce projet a été réalisé dans le cadre de la validation du cours de Python donné du Prof Selim Mellouk par les etudiants dont les noms suivent :
# Loïc AMIAND, François BELIERE, Armand KOUYATE et Alexis DA MOTA.
# Plusieurs modes de jeu sont disponibles dans le jeu notement un humain qui joue contre une intelligence artificielle ou encore deux intélligences artificielles qui s'affrontent entre elles et par la suite une analyse statistique des taux de victoires sur 1000 parties de chaque IA a été réalisée.
#
# Plusieurs modes de jeu sont disponibles et sont présentés ci-dessous:
#
# #Joueur vs Joueur - Joueur vs IA
# Un joueur humain peut jouer au jeu de mastermind. Lorsqu'il va lancer la partie, il devrait à chaque fois saisir la couleur de son choix entre 8 couleurs possible ("rouge", "jaune", "bleu", "vert", "noire", "orange", "gris", "marron") de 4 combinaisons pour tenter de deviner le code couleur. Chaque couleur doit être placée dans la position idéale pour esperer deviner le code. Une Zone de saisir apparait afin de saisir son choix et le valider à chaque tour.
#
# #IA Smart vs IA Dumb
# On peut également faire s'affronter des IA entre elles pendant plusieurs parties. Il y a deux IA différentes :
#
# #IA Smart
# Une IA smart qui joue de manière totalement aléatoire entre.
# Ia Smart est smart car après chaque proposition comparée, elle va déduire quelles sont les combinaisons qui sont impossibles dans les 1680 possibles et les retirer.
# A chaque tour, la liste des possibilités va se réduire jusqu'à ce qu'elle
# tombe sur la bonne ou qu'elle ait éliminée toutes celles qui sont impossibles.
#
# # IA Dumb
# l'IA Dumb qui joue de manière aléatoire et renvoit une combinaison
# aléatoire à chaque fois.
#
#
#
# #Rapport de fin de match
# A la fin d'un affrontement (potentiellement plusieurs matchs), vous aurez un petit rapport vous indiquant le nombre de parties jouées, et le nombre de parties remportées par chacune des IA. Vous trouverez également un graphique, réalisé avec matplotlib, indiquant l'évolution du winrate de chacun des deux IA.
#
# #Test à effectuer pour l'analyse statistique
# Etant donné que certains tests peuvent durer longtemps, voilà ce qu'on vous conseille de tester (entre chaque test il sera nécessaire de relancer le kernel) :
#
# Un jeu entre l'IA Smart et l'IA Dumb
# Une simulation IA Aléatoire (IA Dumb) vs IA Intelligente (Smart).
# Nombre et Pourcentage de victoires de l'IaDumb et de l'IaSmart sur 1000 parties.
#
# - Le nombre de victoire de l'IaDumb est très faible et car elle remplit la
# grille de manière aléatoire. Quand on sait qu'il y a une chance sur 1680 de
# trouver la combinaison gagnante sans prendre en compte les couleurs bien et mal
# placées, il parait logique que l'IaDumb ne dépasse presque jamais les 1% de
# réussites sur 1000 parties.
#
# - A contrario, l'IaSmart a un grand nombre de victoire élevé car sa classe est
# dotée de fonctions qui testent des combinaisons en prenant en compte les
# couleurs bien et mal placées tout en éliminant les combinaisons impossibles.
# L'IaSmart s'approche donc des 100% de réussites avec des résultats avoisinant
# les 96 à 98% en moyenne sur 1000 parties.
#
# - On notera aussi que l'IaSmart met en moyenne 7 tours pour trouver la bonne
# solution. Avec l'IaDumb, c'est encore une fois aléatoire.

# %%
import random
import numpy as np
from pprint import pprint
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import pyplot
import statistics

 
class Mastermind: 
    def __init__(self, user, n_games = 1):

        # Variables utilisées tout au long du programme : 
    
        # liste qui va contenir la solution générée par l'ia au début d'une partie
        self.liste_solution = []

        # liste qui va contenir la combinaison du joueur à chaque tour
        self.liste_proposition = []

        # variables compteurs qui vont indiquer combien de couleurs bien placées
        # et mal placées à chaque tour
        self.nombre_mal_place = 0
        self.nombre_bien_place = 0

        # variable qu'on incrémente à chaque tour
        self.tour = 1 

        # booléen qui prend True quand on trouve la bonne combinaison
        self.partie_gagne = False

        # dictionnaire qui va stocker toutes les combinaisons testées par le joueur 
        # ainsi que les bonnes et mauvaises réponses associées
        self.dict_actions_precedentes = {}

        # liste de toutes les couleurs disponibles
        self.couleur = ["rouge", "jaune", "bleu", "vert", "noire", "orange", "gris", "marron"]

        # booléen qui permettra d'utiliser certaines fonctions spécifiques pour 
        # l'IaSmart
        self.ia_smart = False

        self.user = user

        # variables qui vont être utiles quand on veut simuler n_parties
        self.n_games = n_games
        self.compteur_victoires = 0
        self.tours_necessaires_victoire = []
        
 
    # fonction qui va retourner la solution pour la partie qu'on commence 
    def initialisation_jeu(self):    
 
        # partie_gagne vaut false quand on initialise une partie, important quand 
        # on fait n parties

        # tour prend 1, pour la même raison
        
        # On initialise la partie en générant la solution (4 couleurs diférentes) 
        # qu'on met dans une liste

        print("Nouvelle partie")
        self.partie_gagne = False
        self.tour = 1 
        self.dict_actions_precedentes = {}
        self.liste_solution = random.sample(self.couleur, k=4) 

        # si vous voulez avoir la solution en débutant la partie :

        #print(f'La solution choisie par le jeu : {self.liste_solution}')
        self.liste_proposition = []
    
 
    # fonction qui va comparer la proposition du joueur à la solution
    def comparaison_de_grille(self):  

        # si la proposition du joueur correspond à la solution le joueur gagne la partie
        if self.liste_proposition == self.liste_solution: 
          self.partie_gagne = True
        
        # sinon on va tester pour chaque "case" de proposition et la comparer à celle 
        # de la solution
        else:
            for case in range(4):
              # si la couleur est la bonne, la variable s'incrémente
              if self.liste_proposition[case] == self.liste_solution[case]:
                self.nombre_bien_place += 1
              else:
                 #check les 3 autres cases, si elle sont mal placées la variable
                 #s'incrémente
                for compteur in range(1,4):     
                  autre_case_a_comparer = (case + compteur) 
                 # modulo 4, si check la case 3 + 2 par exemple, case 6 existe pas, on veut check la
                 #case 2 -> 6  modulo 4 = 2
                  if self.liste_proposition[autre_case_a_comparer % 4] == self.liste_solution[case] :  
                    self.nombre_mal_place += 1
 
    def fin_de_tour(self):
 
        # On remplit le dictionnaire qui récapitule nos actions et résulats précédents par tour
        # et on l'affiche
        self.dict_actions_precedentes[self.tour] = [self.liste_proposition, self.nombre_bien_place, self.nombre_mal_place]
        pprint(self.dict_actions_precedentes)
        print("\n")
 
        # On reset nos compteurs de couleurs bien ou mal placées
        self.nombre_bien_place = 0   
        self.nombre_mal_place = 0 
 
        # On incrémente la variable pour nous faire passer au tour suivant
        self.tour += 1
     
    # fonction qu'on appelle à chaque tour et qui va faire tourner 
    def tour_de_jeu(self):    
        
        # tant que le joueur n'a pas gagné, on va lui demander une combinaison de 
        # couleur, la comparer à la solution et lui dire ce qu'il a de bien ou 
        # de mal placé

        if self.partie_gagne is False:

          # fonction où on demande au joueur une combinaison
          # chaque classe fille a une fonction remplir_une_grille spécifique 
          self.remplir_une_grille()

          # compare les grilles pour connaître les nombres de billes bien placées  
          # et mal placées
          self.comparaison_de_grille()    
          print(f'Couleurs proposées : {self.liste_proposition}')
          print(f"Couleurs bien placées : {self.nombre_bien_place}")
          print(f"Couleurs mal placées : {self.nombre_mal_place}")  
          print("\n")
 
          # fonction de l'ia smart qu'on utilisera seulement si l'ia smart joue
          if self.ia_smart == True:
            self.parcours_ensemble()
            self.clean_l_ensemble()
 
        # si partie_gagne est vrai alors le joueur gagne la partie
        # sinon c'est la fin du tour
        if self.partie_gagne is True:    
           print(f"Partie gagnée, bravo {self.user} ! Cela t'a pris seulement {self.tour} tours pour y arriver, you're so french !")
           print(f'La solution était {self.liste_solution}')
           print("\n")
        else:
          self.fin_de_tour()

         # fonction qui lancera notre partie, elle appelera d'abord la fonction  
         # d'initialisation puis celle du tour de jeu, tant qu'on a pas gagné ou
         # qu'on n'est pas au tour 13
    def lancer_une_partie(self): 
        self.initialisation_jeu()
 
        while self.partie_gagne is False and self.tour < 13:
          self.tour_de_jeu()
        
        # si le tour suivant qu'on s'apprête à jouer est le 13ème, et que le joueur 
        # n'a pas trouvé la solution, alors il a perdu
        if self.tour == 13:    
          print(f"Partie perdue, t'es mauvais {self.user} !")
          print(f'La solution était {self.liste_solution}')
          print("\n")

    # fonction qui permet de lancer n parties, assez similaire à celle vue en cours
    # chaque fois que partie_gagne est vraie on incrémente un compteur 
    # et on met dans une liste le nombre de tours qu'il a fallu pour gagner
    # => utile pour les stats
    def lancer_n_parties(self):

      for game in range(self.n_games):

        self.lancer_une_partie()
        if self.partie_gagne is True:
          self.compteur_victoires += 1
          self.tours_necessaires_victoire.append(self.tour)
          

        if self.ia_smart is True:
          self.instanciation_de_l_ensemble_des_possibilites()
        #print(f'{self.compteur_victoires} parties gagnées pour {self.n_games} parties jouées')
      


# classe du joueur humain, avec sa fonction remplir_une_grille spécifique

class Joueur(Mastermind):
 
  def __init__(self, user, n_games = 1):
      super().__init__(user, n_games)
 
  def remplir_une_grille(self):
 
        # liste locale dans laquelle on mettra les couleurs choisies par le joueur
        liste_couleurs_joueur = [0,0,0,0] 
 
        #liste de couleurs disponibles à la sélection
 
        self.choix_possible = ["rouge", "jaune", "bleu", "vert", "noire", "orange", "gris", "marron"] 
        
        for case in range(4): # pour chaque case on va choisir une couleur
 
            # On indique la case qu'on doit remplir 
            print (f"Rentrez la couleur de la case {case}. Vous avez le choix entre {len(self.choix_possible)} couleurs") 
 
            # et les couleurs de boule qui sont dispos
            print(self.choix_possible, "\n")   
 
            # on demande au joueur de remplir la case
            liste_couleurs_joueur[case] = input() 
            
            couleur_choisie = False
 
            # on vérifie grâce à une boucle que  le joueur a choisi à une des couleurs choisies 
            while couleur_choisie is False: 
              
              for couleur in self.choix_possible:
 
                if liste_couleurs_joueur[case] == couleur:  
                  # si la couleur choisie correspond à une des couleurs dispos, 
                  # on la supprime des choix possibles et on sort de la boucle  
                  self.choix_possible.remove(liste_couleurs_joueur[case])
                  couleur_choisie = True
              
              # sinon on repropose au joueur de rentrer une couleur
              if couleur_choisie is False: 
                print("Vous devez choisir une des couleurs restantes !")
                print(self.choix_possible)
                liste_couleurs_joueur[case] = input()
        
        # on donne les valeurs de la liste local à liste_proposition pour l'utiliser
        # dans les autres fonctions
        self.liste_proposition = liste_couleurs_joueur
 

# classe de l'IA Dumb, sa fonction remplir_une_grille renvoit une combinaison 
# aléatoire à chaque fois 

class IaDumb(Mastermind):
 
    def __init__(self,user, n_games = 1):
        super().__init__(user, n_games)
   
    def remplir_une_grille(self):
 
        self.liste_proposition = random.sample(self.couleur, k=4)


# classe de l'IA Smart
# sa fonction remplir_une_grille va aussi renvoyer une combinaison aléatoire
# Ia Smart est smart car après chaque proposition comparée, elle va déduire quelles 
# sont les combinaisons qui sont impossibles dans les 1680 possibles et les retirer.
# A chaque tour la liste des possibilités va se réduire jusqu'à ce qu'elle 
# tombe sur la bonne ou qu'elle ait éliminée toutes celles qui sont impossibles
 
class IaSmart(Mastermind):
 
    def __init__(self,user, n_games = 1):
 
      super().__init__(user, n_games)
 
 
      # liste de l'ensemble des combinaisons possibles pour notre jeu :
      # 4 cases et 8 couleurs : 1680 possibiltés
      self.liste_ensemble = []   

      # combinaison de couleurs prise dans l'ensemble des possibilités qu'on va
      # tester pour savoir si on la garde ou pas
      self.liste_test = []   

      # liste des combinaisons à enlever de l'ensemble des possiblités 
      self.liste_a_delete = []   
 
      self.liste_proposition = [ 0, 0, 0, 0]

      # booléen qui prend quand on utilise un objet IaSmart
      self.ia_smart = True
 

    # on remplit notre liste de toutes les combinaisons possibles (1680)
    def instanciation_de_l_ensemble_des_possibilites(self):
 
      self.liste_ensemble = []
 
      for a in self.couleur:
        for b in self.couleur:
          for c in self.couleur:
            for d in self.couleur:
              if (a!=b) and (a!=c) and (a!=d) and (b!=c) and (b!=d) and (c!=d):
                self.liste_ensemble.append([a,b,c,d])
 
 
   # on enlève de l'ensemble des possibiltés (liste_ensemble)  
   # toutes les combinaisons que l'ia considère comme impossible (liste_a_delete)
    def clean_l_ensemble (self):

      l = []
      print(f'Le nombre de combinaisons possibles avant la suppression : {len(self.liste_ensemble)}')
      print(f'Le nombre de combinaisons quon veut enlever : {len(self.liste_a_delete)}')
      cpt = 0
      for combinaison in range(len(self.liste_a_delete)):
        l = self.liste_ensemble[self.liste_a_delete[combinaison] - cpt]
        self.liste_ensemble.remove(l)
        cpt +=1
      
      if len(self.liste_ensemble) != 1:
        if self.liste_proposition in self.liste_ensemble:
          self.liste_ensemble.remove(self.liste_proposition)

      print(f'Le nombre de combinaisons possibles après la suppression : {len(self.liste_ensemble)}')
      print("\n")
 

 # les trois prochaines fonctions vont tester chaque possibilité et regarder
 # si elles ont les mêmes nombres de couleurs bien placées ou mal placées que celle 
 # proposée par l'IaSmart au tour où on se trouve
 # elles vont trouver quelles sont les combinaisons qui sont encore possibles, 
 # qui "survivent" et supprimer les autres 

    def condition_survie_bien_place(self):
 
      case = 0
      while self.condition_de_survie_bien_place != self.nombre_bien_place and case < 4: 
        
        #compare la liste proposée par l'ia à une des liste possibles que l'on est 
        # en train de tester
        if self.liste_proposition[case] == self.liste_test[case]:   
          self.condition_de_survie_bien_place  += 1
 
        case +=1  
 
      # dans le cas ou les conditions de survie bien placé ne sont pas respectées
      # on l'ajoute à liste des combinaisons à enlever        
      if self.condition_de_survie_bien_place < self.nombre_bien_place:                                                               
        self.liste_a_delete.append((self.liste_ensemble.index(self.liste_test)))                      
        self.autorisation_de_suppression = True   
 

    def condition_survie_mal_place(self):
 
      if self.autorisation_de_suppression == False:
 
        case = 0    
 
        while self.condition_de_survie_mal_place != self.nombre_mal_place and case < 4:
          compteur = 1
 
          while self.condition_de_survie_mal_place != self.nombre_mal_place and compteur < 4: 
 
            autre_case_a_comparer = (case + compteur)
 
            if self.liste_proposition[case] == self.liste_test[autre_case_a_comparer % 4]: 
              self.condition_de_survie_mal_place += 1 
 
            compteur += 1 
 
          case += 1
      
        if self.condition_de_survie_mal_place < self.nombre_mal_place:
          self.liste_a_delete.append((self.liste_ensemble.index(self.liste_test)))                      
          self.autorisation_de_suppression = True 
 
 
 
    def pas_de_correspondance(self):
 
      if self.autorisation_de_suppression == False and self.nombre_bien_place == 0 and self.nombre_mal_place == 0:  
        case = 0                                                                  
        compteur = 0
 
        while case < 4 and self.autorisation_de_suppression == False:
 
          while compteur < 4 and self.autorisation_de_suppression == False:
 
            if self.liste_proposition[case] == self.liste_test[compteur] : 
              self.autorisation_de_suppression == True 
 
            compteur += 1
 
          case += 1
          
        if self.autorisation_de_suppression == True:
          self.liste_a_delete.append(self.liste_ensemble.index(self.liste_test))
 
  
    # fonction qui va appeler les trois fonctions précédentes et qui testent 
    # la "survie" d'une combinaison

    def survivor(self):
      
      #variable servant a verifier les conditions de positionement bien placé ou non
      # et un booléen qui va prendre true si la combinaison qu'on teste ne remplit
      # pas les conditions de survie
      self.condition_de_survie_bien_place = 0     
      self.condition_de_survie_mal_place = 0
      self.autorisation_de_suppression = False
 
      self.condition_survie_bien_place()
      self.condition_survie_mal_place()
      self.pas_de_correspondance()
 
      
    # fonction qui va parcourir la liste des combinaisons possibles et tester
    # chacune d'entre elles avec la fonction survivor
    def parcours_ensemble(self):  
      for combinaison in range(len(self.liste_ensemble)):
        self.liste_test = self.liste_ensemble[combinaison]
        self.survivor()
 
 
    # la fonction remplir_une_grille propre à IaSmart 
    # si on est au tour 1 on instancie la liste des ensembles avec toutes les 
    # combinaisons possibles. Elle propose ensuite une combinaison random

    # si partie_gagne vaut toujours false, cad si l'ia n'a toujours pas gagné,
    # elle propose une combinaison random parmi la liste de combinaisons possibles
    # dont la taille diminuera tour après tour.

    def remplir_une_grille(self):
      
      if self.tour == 1:
        self.instanciation_de_l_ensemble_des_possibilites()
        self.liste_proposition = random.sample(self.couleur, k=4)
        #print(f'La première proposition de l IaSmart : {self.liste_proposition}')
      
      if self.partie_gagne is False:
        self.liste_proposition = random.choice(self.liste_ensemble)
        self.liste_a_delete = []

# %%
joujou = Joueur("lolo")
joujou.lancer_une_partie()
# Out:
# Nouvelle partie
# Rentrez la couleur de la case 0. Vous avez le choix entre 8 couleurs
# ['rouge', 'jaune', 'bleu', 'vert', 'noire', 'orange', 'gris', 'marron']
#
# vert
# Rentrez la couleur de la case 1. Vous avez le choix entre 7 couleurs
# ['rouge', 'jaune', 'bleu', 'noire', 'orange', 'gris', 'marron']
#
# jaune
# Rentrez la couleur de la case 2. Vous avez le choix entre 6 couleurs
# ['rouge', 'bleu', 'noire', 'orange', 'gris', 'marron']
#
# orange
# Rentrez la couleur de la case 3. Vous avez le choix entre 5 couleurs
# ['rouge', 'bleu', 'noire', 'gris', 'marron']
#
# bleu
# Couleurs proposées : ['vert', 'jaune', 'orange', 'bleu']
# Couleurs bien placées : 1
# Couleurs mal placées : 2
#
#
# {1: [['vert', 'jaune', 'orange', 'bleu'], 1, 2]}
#
#
# Rentrez la couleur de la case 0. Vous avez le choix entre 8 couleurs
# ['rouge', 'jaune', 'bleu', 'vert', 'noire', 'orange', 'gris', 'marron']
#
# jaune
# Rentrez la couleur de la case 1. Vous avez le choix entre 7 couleurs
# ['rouge', 'bleu', 'vert', 'noire', 'orange', 'gris', 'marron']
#
# vert
# Rentrez la couleur de la case 2. Vous avez le choix entre 6 couleurs
# ['rouge', 'bleu', 'noire', 'orange', 'gris', 'marron']
#
# orange
# Rentrez la couleur de la case 3. Vous avez le choix entre 5 couleurs
# ['rouge', 'bleu', 'noire', 'gris', 'marron']
#
# bleu
# Couleurs proposées : ['jaune', 'vert', 'orange', 'bleu']
# Couleurs bien placées : 0
# Couleurs mal placées : 3
#
#
# {1: [['vert', 'jaune', 'orange', 'bleu'], 1, 2],
#  2: [['jaune', 'vert', 'orange', 'bleu'], 0, 3]}
#
#
# Rentrez la couleur de la case 0. Vous avez le choix entre 8 couleurs
# ['rouge', 'jaune', 'bleu', 'vert', 'noire', 'orange', 'gris', 'marron']
#
# rouge
# Rentrez la couleur de la case 1. Vous avez le choix entre 7 couleurs
# ['jaune', 'bleu', 'vert', 'noire', 'orange', 'gris', 'marron']
#
# jaune
# Rentrez la couleur de la case 2. Vous avez le choix entre 6 couleurs
# ['bleu', 'vert', 'noire', 'orange', 'gris', 'marron']
#
# bleu
# Rentrez la couleur de la case 3. Vous avez le choix entre 5 couleurs
# ['vert', 'noire', 'orange', 'gris', 'marron']
#
# orange
# Couleurs proposées : ['rouge', 'jaune', 'bleu', 'orange']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# {1: [['vert', 'jaune', 'orange', 'bleu'], 1, 2],
#  2: [['jaune', 'vert', 'orange', 'bleu'], 0, 3],
#  3: [['rouge', 'jaune', 'bleu', 'orange'], 1, 1]}
#
#
# Rentrez la couleur de la case 0. Vous avez le choix entre 8 couleurs
# ['rouge', 'jaune', 'bleu', 'vert', 'noire', 'orange', 'gris', 'marron']
#
# Jaune
# Vous devez choisir une des couleurs restantes !
# ['rouge', 'jaune', 'bleu', 'vert', 'noire', 'orange', 'gris', 'marron']
# vert
# Rentrez la couleur de la case 1. Vous avez le choix entre 7 couleurs
# ['rouge', 'jaune', 'bleu', 'noire', 'orange', 'gris', 'marron']
#
# bleu
# Rentrez la couleur de la case 2. Vous avez le choix entre 6 couleurs
# ['rouge', 'jaune', 'noire', 'orange', 'gris', 'marron']
#
# orange
# Rentrez la couleur de la case 3. Vous avez le choix entre 5 couleurs
# ['rouge', 'jaune', 'noire', 'gris', 'marron']
#
# jaune
# Couleurs proposées : ['vert', 'bleu', 'orange', 'jaune']
# Couleurs bien placées : 2
# Couleurs mal placées : 1
#
#
# {1: [['vert', 'jaune', 'orange', 'bleu'], 1, 2],
#  2: [['jaune', 'vert', 'orange', 'bleu'], 0, 3],
#  3: [['rouge', 'jaune', 'bleu', 'orange'], 1, 1],
#  4: [['vert', 'bleu', 'orange', 'jaune'], 2, 1]}
#
#
# Rentrez la couleur de la case 0. Vous avez le choix entre 8 couleurs
# ['rouge', 'jaune', 'bleu', 'vert', 'noire', 'orange', 'gris', 'marron']
#
# jaune
# Rentrez la couleur de la case 1. Vous avez le choix entre 7 couleurs
# ['rouge', 'bleu', 'vert', 'noire', 'orange', 'gris', 'marron']
#
# bleu
# Rentrez la couleur de la case 2. Vous avez le choix entre 6 couleurs
# ['rouge', 'vert', 'noire', 'orange', 'gris', 'marron']
#
# orange
# Rentrez la couleur de la case 3. Vous avez le choix entre 5 couleurs
# ['rouge', 'vert', 'noire', 'gris', 'marron']
#
# vert
# Couleurs proposées : ['jaune', 'bleu', 'orange', 'vert']
# Couleurs bien placées : 1
# Couleurs mal placées : 2
#
#
# {1: [['vert', 'jaune', 'orange', 'bleu'], 1, 2],
#  2: [['jaune', 'vert', 'orange', 'bleu'], 0, 3],
#  3: [['rouge', 'jaune', 'bleu', 'orange'], 1, 1],
#  4: [['vert', 'bleu', 'orange', 'jaune'], 2, 1],
#  5: [['jaune', 'bleu', 'orange', 'vert'], 1, 2]}
#
#
# Rentrez la couleur de la case 0. Vous avez le choix entre 8 couleurs
# ['rouge', 'jaune', 'bleu', 'vert', 'noire', 'orange', 'gris', 'marron']
#
# vert
# Rentrez la couleur de la case 1. Vous avez le choix entre 7 couleurs
# ['rouge', 'jaune', 'bleu', 'noire', 'orange', 'gris', 'marron']
#
# bleu
# Rentrez la couleur de la case 2. Vous avez le choix entre 6 couleurs
# ['rouge', 'jaune', 'noire', 'orange', 'gris', 'marron']
#
# jaune
# Rentrez la couleur de la case 3. Vous avez le choix entre 5 couleurs
# ['rouge', 'noire', 'orange', 'gris', 'marron']
#
# noire
# Couleurs proposées : ['vert', 'bleu', 'jaune', 'noire']
# Couleurs bien placées : 2
# Couleurs mal placées : 1
#
#
# {1: [['vert', 'jaune', 'orange', 'bleu'], 1, 2],
#  2: [['jaune', 'vert', 'orange', 'bleu'], 0, 3],
#  3: [['rouge', 'jaune', 'bleu', 'orange'], 1, 1],
#  4: [['vert', 'bleu', 'orange', 'jaune'], 2, 1],
#  5: [['jaune', 'bleu', 'orange', 'vert'], 1, 2],
#  6: [['vert', 'bleu', 'jaune', 'noire'], 2, 1]}
#
#
# Rentrez la couleur de la case 0. Vous avez le choix entre 8 couleurs
# ['rouge', 'jaune', 'bleu', 'vert', 'noire', 'orange', 'gris', 'marron']
#
# vert
# Rentrez la couleur de la case 1. Vous avez le choix entre 7 couleurs
# ['rouge', 'jaune', 'bleu', 'noire', 'orange', 'gris', 'marron']
#
# bleu
# Rentrez la couleur de la case 2. Vous avez le choix entre 6 couleurs
# ['rouge', 'jaune', 'noire', 'orange', 'gris', 'marron']
#
# noire
# Rentrez la couleur de la case 3. Vous avez le choix entre 5 couleurs
# ['rouge', 'jaune', 'orange', 'gris', 'marron']
#
# vert
# Vous devez choisir une des couleurs restantes !
# ['rouge', 'jaune', 'orange', 'gris', 'marron']
# gris
# Couleurs proposées : ['vert', 'bleu', 'noire', 'gris']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# {1: [['vert', 'jaune', 'orange', 'bleu'], 1, 2],
#  2: [['jaune', 'vert', 'orange', 'bleu'], 0, 3],
#  3: [['rouge', 'jaune', 'bleu', 'orange'], 1, 1],
#  4: [['vert', 'bleu', 'orange', 'jaune'], 2, 1],
#  5: [['jaune', 'bleu', 'orange', 'vert'], 1, 2],
#  6: [['vert', 'bleu', 'jaune', 'noire'], 2, 1],
#  7: [['vert', 'bleu', 'noire', 'gris'], 3, 0]}
#
#
# Rentrez la couleur de la case 0. Vous avez le choix entre 8 couleurs
# ['rouge', 'jaune', 'bleu', 'vert', 'noire', 'orange', 'gris', 'marron']
#
# vert
# Rentrez la couleur de la case 1. Vous avez le choix entre 7 couleurs
# ['rouge', 'jaune', 'bleu', 'noire', 'orange', 'gris', 'marron']
#
# bleu
# Rentrez la couleur de la case 2. Vous avez le choix entre 6 couleurs
# ['rouge', 'jaune', 'noire', 'orange', 'gris', 'marron']
#
# noire
# Rentrez la couleur de la case 3. Vous avez le choix entre 5 couleurs
# ['rouge', 'jaune', 'orange', 'gris', 'marron']
#
# jaune
# Couleurs proposées : ['vert', 'bleu', 'noire', 'jaune']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# {1: [['vert', 'jaune', 'orange', 'bleu'], 1, 2],
#  2: [['jaune', 'vert', 'orange', 'bleu'], 0, 3],
#  3: [['rouge', 'jaune', 'bleu', 'orange'], 1, 1],
#  4: [['vert', 'bleu', 'orange', 'jaune'], 2, 1],
#  5: [['jaune', 'bleu', 'orange', 'vert'], 1, 2],
#  6: [['vert', 'bleu', 'jaune', 'noire'], 2, 1],
#  7: [['vert', 'bleu', 'noire', 'gris'], 3, 0],
#  8: [['vert', 'bleu', 'noire', 'jaune'], 3, 0]}
#
#
# Rentrez la couleur de la case 0. Vous avez le choix entre 8 couleurs
# ['rouge', 'jaune', 'bleu', 'vert', 'noire', 'orange', 'gris', 'marron']
#
# vert
# Rentrez la couleur de la case 1. Vous avez le choix entre 7 couleurs
# ['rouge', 'jaune', 'bleu', 'noire', 'orange', 'gris', 'marron']
#
# bleu
# Rentrez la couleur de la case 2. Vous avez le choix entre 6 couleurs
# ['rouge', 'jaune', 'noire', 'orange', 'gris', 'marron']
#
# noire
# Rentrez la couleur de la case 3. Vous avez le choix entre 5 couleurs
# ['rouge', 'jaune', 'orange', 'gris', 'marron']
#
# orange
# Couleurs proposées : ['vert', 'bleu', 'noire', 'orange']
# Couleurs bien placées : 0
# Couleurs mal placées : 0
#
#
# Partie gagnée, bravo lolo ! Cela t'a pris seulement 9 tours pour y arriver, you're so french !
# La solution était ['vert', 'bleu', 'noire', 'orange']

# %%
joujou = IaDumb("lolo")
joujou.lancer_une_partie()
# Out:
# Nouvelle partie
# Couleurs proposées : ['rouge', 'vert', 'bleu', 'jaune']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# {1: [['rouge', 'vert', 'bleu', 'jaune'], 1, 1]}
#
#
# Couleurs proposées : ['rouge', 'bleu', 'orange', 'jaune']
# Couleurs bien placées : 0
# Couleurs mal placées : 3
#
#
# {1: [['rouge', 'vert', 'bleu', 'jaune'], 1, 1],
#  2: [['rouge', 'bleu', 'orange', 'jaune'], 0, 3]}
#
#
# Couleurs proposées : ['noire', 'rouge', 'gris', 'vert']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# {1: [['rouge', 'vert', 'bleu', 'jaune'], 1, 1],
#  2: [['rouge', 'bleu', 'orange', 'jaune'], 0, 3],
#  3: [['noire', 'rouge', 'gris', 'vert'], 0, 1]}
#
#
# Couleurs proposées : ['bleu', 'gris', 'noire', 'orange']
# Couleurs bien placées : 2
# Couleurs mal placées : 1
#
#
# {1: [['rouge', 'vert', 'bleu', 'jaune'], 1, 1],
#  2: [['rouge', 'bleu', 'orange', 'jaune'], 0, 3],
#  3: [['noire', 'rouge', 'gris', 'vert'], 0, 1],
#  4: [['bleu', 'gris', 'noire', 'orange'], 2, 1]}
#
#
# Couleurs proposées : ['vert', 'orange', 'rouge', 'marron']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# {1: [['rouge', 'vert', 'bleu', 'jaune'], 1, 1],
#  2: [['rouge', 'bleu', 'orange', 'jaune'], 0, 3],
#  3: [['noire', 'rouge', 'gris', 'vert'], 0, 1],
#  4: [['bleu', 'gris', 'noire', 'orange'], 2, 1],
#  5: [['vert', 'orange', 'rouge', 'marron'], 0, 1]}
#
#
# Couleurs proposées : ['jaune', 'orange', 'noire', 'marron']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# {1: [['rouge', 'vert', 'bleu', 'jaune'], 1, 1],
#  2: [['rouge', 'bleu', 'orange', 'jaune'], 0, 3],
#  3: [['noire', 'rouge', 'gris', 'vert'], 0, 1],
#  4: [['bleu', 'gris', 'noire', 'orange'], 2, 1],
#  5: [['vert', 'orange', 'rouge', 'marron'], 0, 1],
#  6: [['jaune', 'orange', 'noire', 'marron'], 1, 1]}
#
#
# Couleurs proposées : ['gris', 'vert', 'orange', 'noire']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['rouge', 'vert', 'bleu', 'jaune'], 1, 1],
#  2: [['rouge', 'bleu', 'orange', 'jaune'], 0, 3],
#  3: [['noire', 'rouge', 'gris', 'vert'], 0, 1],
#  4: [['bleu', 'gris', 'noire', 'orange'], 2, 1],
#  5: [['vert', 'orange', 'rouge', 'marron'], 0, 1],
#  6: [['jaune', 'orange', 'noire', 'marron'], 1, 1],
#  7: [['gris', 'vert', 'orange', 'noire'], 0, 2]}
#
#
# Couleurs proposées : ['rouge', 'noire', 'orange', 'marron']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# {1: [['rouge', 'vert', 'bleu', 'jaune'], 1, 1],
#  2: [['rouge', 'bleu', 'orange', 'jaune'], 0, 3],
#  3: [['noire', 'rouge', 'gris', 'vert'], 0, 1],
#  4: [['bleu', 'gris', 'noire', 'orange'], 2, 1],
#  5: [['vert', 'orange', 'rouge', 'marron'], 0, 1],
#  6: [['jaune', 'orange', 'noire', 'marron'], 1, 1],
#  7: [['gris', 'vert', 'orange', 'noire'], 0, 2],
#  8: [['rouge', 'noire', 'orange', 'marron'], 0, 1]}
#
#
# Couleurs proposées : ['gris', 'vert', 'orange', 'marron']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['rouge', 'vert', 'bleu', 'jaune'], 1, 1],
#  2: [['rouge', 'bleu', 'orange', 'jaune'], 0, 3],
#  3: [['noire', 'rouge', 'gris', 'vert'], 0, 1],
#  4: [['bleu', 'gris', 'noire', 'orange'], 2, 1],
#  5: [['vert', 'orange', 'rouge', 'marron'], 0, 1],
#  6: [['jaune', 'orange', 'noire', 'marron'], 1, 1],
#  7: [['gris', 'vert', 'orange', 'noire'], 0, 2],
#  8: [['rouge', 'noire', 'orange', 'marron'], 0, 1],
#  9: [['gris', 'vert', 'orange', 'marron'], 0, 2]}
#
#
# Couleurs proposées : ['bleu', 'jaune', 'gris', 'rouge']
# Couleurs bien placées : 0
# Couleurs mal placées : 3
#
#
# {1: [['rouge', 'vert', 'bleu', 'jaune'], 1, 1],
#  2: [['rouge', 'bleu', 'orange', 'jaune'], 0, 3],
#  3: [['noire', 'rouge', 'gris', 'vert'], 0, 1],
#  4: [['bleu', 'gris', 'noire', 'orange'], 2, 1],
#  5: [['vert', 'orange', 'rouge', 'marron'], 0, 1],
#  6: [['jaune', 'orange', 'noire', 'marron'], 1, 1],
#  7: [['gris', 'vert', 'orange', 'noire'], 0, 2],
#  8: [['rouge', 'noire', 'orange', 'marron'], 0, 1],
#  9: [['gris', 'vert', 'orange', 'marron'], 0, 2],
#  10: [['bleu', 'jaune', 'gris', 'rouge'], 0, 3]}
#
#
# Couleurs proposées : ['bleu', 'noire', 'orange', 'rouge']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['rouge', 'vert', 'bleu', 'jaune'], 1, 1],
#  2: [['rouge', 'bleu', 'orange', 'jaune'], 0, 3],
#  3: [['noire', 'rouge', 'gris', 'vert'], 0, 1],
#  4: [['bleu', 'gris', 'noire', 'orange'], 2, 1],
#  5: [['vert', 'orange', 'rouge', 'marron'], 0, 1],
#  6: [['jaune', 'orange', 'noire', 'marron'], 1, 1],
#  7: [['gris', 'vert', 'orange', 'noire'], 0, 2],
#  8: [['rouge', 'noire', 'orange', 'marron'], 0, 1],
#  9: [['gris', 'vert', 'orange', 'marron'], 0, 2],
#  10: [['bleu', 'jaune', 'gris', 'rouge'], 0, 3],
#  11: [['bleu', 'noire', 'orange', 'rouge'], 0, 2]}
#
#
# Couleurs proposées : ['vert', 'jaune', 'orange', 'bleu']
# Couleurs bien placées : 0
# Couleurs mal placées : 3
#
#
# {1: [['rouge', 'vert', 'bleu', 'jaune'], 1, 1],
#  2: [['rouge', 'bleu', 'orange', 'jaune'], 0, 3],
#  3: [['noire', 'rouge', 'gris', 'vert'], 0, 1],
#  4: [['bleu', 'gris', 'noire', 'orange'], 2, 1],
#  5: [['vert', 'orange', 'rouge', 'marron'], 0, 1],
#  6: [['jaune', 'orange', 'noire', 'marron'], 1, 1],
#  7: [['gris', 'vert', 'orange', 'noire'], 0, 2],
#  8: [['rouge', 'noire', 'orange', 'marron'], 0, 1],
#  9: [['gris', 'vert', 'orange', 'marron'], 0, 2],
#  10: [['bleu', 'jaune', 'gris', 'rouge'], 0, 3],
#  11: [['bleu', 'noire', 'orange', 'rouge'], 0, 2],
#  12: [['vert', 'jaune', 'orange', 'bleu'], 0, 3]}
#
#
# Partie perdue, t'es mauvais lolo !
# La solution était ['jaune', 'gris', 'bleu', 'orange']

# %%
joujou = IaSmart("lolo")
joujou.lancer_une_partie()
# Out:
# Nouvelle partie
# Couleurs proposées : ['rouge', 'noire', 'jaune', 'vert']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 1680
# Le nombre de combinaisons quon veut enlever : 833
# Le nombre de combinaisons possibles après la suppression : 847
#
#
# {1: [['rouge', 'noire', 'jaune', 'vert'], 0, 2]}
#
#
# Couleurs proposées : ['marron', 'jaune', 'noire', 'gris']
# Couleurs bien placées : 2
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 847
# Le nombre de combinaisons quon veut enlever : 814
# Le nombre de combinaisons possibles après la suppression : 33
#
#
# {1: [['rouge', 'noire', 'jaune', 'vert'], 0, 2],
#  2: [['marron', 'jaune', 'noire', 'gris'], 2, 1]}
#
#
# Couleurs proposées : ['marron', 'jaune', 'gris', 'noire']
# Couleurs bien placées : 1
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 33
# Le nombre de combinaisons quon veut enlever : 12
# Le nombre de combinaisons possibles après la suppression : 21
#
#
# {1: [['rouge', 'noire', 'jaune', 'vert'], 0, 2],
#  2: [['marron', 'jaune', 'noire', 'gris'], 2, 1],
#  3: [['marron', 'jaune', 'gris', 'noire'], 1, 2]}
#
#
# Couleurs proposées : ['vert', 'jaune', 'marron', 'gris']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 21
# Le nombre de combinaisons quon veut enlever : 13
# Le nombre de combinaisons possibles après la suppression : 8
#
#
# {1: [['rouge', 'noire', 'jaune', 'vert'], 0, 2],
#  2: [['marron', 'jaune', 'noire', 'gris'], 2, 1],
#  3: [['marron', 'jaune', 'gris', 'noire'], 1, 2],
#  4: [['vert', 'jaune', 'marron', 'gris'], 0, 2]}
#
#
# Couleurs proposées : ['gris', 'jaune', 'noire', 'marron']
# Couleurs bien placées : 1
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 8
# Le nombre de combinaisons quon veut enlever : 2
# Le nombre de combinaisons possibles après la suppression : 6
#
#
# {1: [['rouge', 'noire', 'jaune', 'vert'], 0, 2],
#  2: [['marron', 'jaune', 'noire', 'gris'], 2, 1],
#  3: [['marron', 'jaune', 'gris', 'noire'], 1, 2],
#  4: [['vert', 'jaune', 'marron', 'gris'], 0, 2],
#  5: [['gris', 'jaune', 'noire', 'marron'], 1, 2]}
#
#
# Couleurs proposées : ['marron', 'vert', 'noire', 'jaune']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 6
# Le nombre de combinaisons quon veut enlever : 1
# Le nombre de combinaisons possibles après la suppression : 4
#
#
# {1: [['rouge', 'noire', 'jaune', 'vert'], 0, 2],
#  2: [['marron', 'jaune', 'noire', 'gris'], 2, 1],
#  3: [['marron', 'jaune', 'gris', 'noire'], 1, 2],
#  4: [['vert', 'jaune', 'marron', 'gris'], 0, 2],
#  5: [['gris', 'jaune', 'noire', 'marron'], 1, 2],
#  6: [['marron', 'vert', 'noire', 'jaune'], 3, 0]}
#
#
# Couleurs proposées : ['marron', 'gris', 'noire', 'jaune']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 4
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 3
#
#
# {1: [['rouge', 'noire', 'jaune', 'vert'], 0, 2],
#  2: [['marron', 'jaune', 'noire', 'gris'], 2, 1],
#  3: [['marron', 'jaune', 'gris', 'noire'], 1, 2],
#  4: [['vert', 'jaune', 'marron', 'gris'], 0, 2],
#  5: [['gris', 'jaune', 'noire', 'marron'], 1, 2],
#  6: [['marron', 'vert', 'noire', 'jaune'], 3, 0],
#  7: [['marron', 'gris', 'noire', 'jaune'], 3, 0]}
#
#
# Couleurs proposées : ['marron', 'orange', 'noire', 'jaune']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 3
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 2
#
#
# {1: [['rouge', 'noire', 'jaune', 'vert'], 0, 2],
#  2: [['marron', 'jaune', 'noire', 'gris'], 2, 1],
#  3: [['marron', 'jaune', 'gris', 'noire'], 1, 2],
#  4: [['vert', 'jaune', 'marron', 'gris'], 0, 2],
#  5: [['gris', 'jaune', 'noire', 'marron'], 1, 2],
#  6: [['marron', 'vert', 'noire', 'jaune'], 3, 0],
#  7: [['marron', 'gris', 'noire', 'jaune'], 3, 0],
#  8: [['marron', 'orange', 'noire', 'jaune'], 3, 0]}
#
#
# Couleurs proposées : ['marron', 'bleu', 'noire', 'jaune']
# Couleurs bien placées : 0
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 2
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# Partie gagnée, bravo lolo ! Cela t'a pris seulement 9 tours pour y arriver, you're so french !
# La solution était ['marron', 'bleu', 'noire', 'jaune']

# %%
joujou = IaDumb("lolo", 100)
joujou.lancer_n_parties()
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# Couleurs bien placées : 1
# Couleurs mal placées : 0
#
#
# {1: [['bleu', 'gris', 'rouge', 'vert'], 1, 1],
#  2: [['marron', 'rouge', 'bleu', 'vert'], 1, 0]}
#
#
# Couleurs proposées : ['vert', 'marron', 'rouge', 'bleu']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# {1: [['bleu', 'gris', 'rouge', 'vert'], 1, 1],
#  2: [['marron', 'rouge', 'bleu', 'vert'], 1, 0],
#  3: [['vert', 'marron', 'rouge', 'bleu'], 0, 1]}
#
#
# Couleurs proposées : ['marron', 'noire', 'gris', 'bleu']
# Couleurs bien placées : 0
# Couleurs mal placées : 3
#
#
# {1: [['bleu', 'gris', 'rouge', 'vert'], 1, 1],
#  2: [['marron', 'rouge', 'bleu', 'vert'], 1, 0],
#  3: [['vert', 'marron', 'rouge', 'bleu'], 0, 1],
#  4: [['marron', 'noire', 'gris', 'bleu'], 0, 3]}
#
#
# Couleurs proposées : ['vert', 'bleu', 'rouge', 'marron']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# {1: [['bleu', 'gris', 'rouge', 'vert'], 1, 1],
#  2: [['marron', 'rouge', 'bleu', 'vert'], 1, 0],
#  3: [['vert', 'marron', 'rouge', 'bleu'], 0, 1],
#  4: [['marron', 'noire', 'gris', 'bleu'], 0, 3],
#  5: [['vert', 'bleu', 'rouge', 'marron'], 0, 1]}
#
#
# Couleurs proposées : ['vert', 'orange', 'rouge', 'gris']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# {1: [['bleu', 'gris', 'rouge', 'vert'], 1, 1],
#  2: [['marron', 'rouge', 'bleu', 'vert'], 1, 0],
#  3: [['vert', 'marron', 'rouge', 'bleu'], 0, 1],
#  4: [['marron', 'noire', 'gris', 'bleu'], 0, 3],
#  5: [['vert', 'bleu', 'rouge', 'marron'], 0, 1],
#  6: [['vert', 'orange', 'rouge', 'gris'], 0, 1]}
#
#
# Couleurs proposées : ['vert', 'jaune', 'gris', 'noire']
# Couleurs bien placées : 0
# Couleurs mal placées : 3
#
#
# {1: [['bleu', 'gris', 'rouge', 'vert'], 1, 1],
#  2: [['marron', 'rouge', 'bleu', 'vert'], 1, 0],
#  3: [['vert', 'marron', 'rouge', 'bleu'], 0, 1],
#  4: [['marron', 'noire', 'gris', 'bleu'], 0, 3],
#  5: [['vert', 'bleu', 'rouge', 'marron'], 0, 1],
#  6: [['vert', 'orange', 'rouge', 'gris'], 0, 1],
#  7: [['vert', 'jaune', 'gris', 'noire'], 0, 3]}
#
#
# Couleurs proposées : ['marron', 'noire', 'gris', 'bleu']
# Couleurs bien placées : 0
# Couleurs mal placées : 3
#
#
# {1: [['bleu', 'gris', 'rouge', 'vert'], 1, 1],
#  2: [['marron', 'rouge', 'bleu', 'vert'], 1, 0],
#  3: [['vert', 'marron', 'rouge', 'bleu'], 0, 1],
#  4: [['marron', 'noire', 'gris', 'bleu'], 0, 3],
#  5: [['vert', 'bleu', 'rouge', 'marron'], 0, 1],
#  6: [['vert', 'orange', 'rouge', 'gris'], 0, 1],
#  7: [['vert', 'jaune', 'gris', 'noire'], 0, 3],
#  8: [['marron', 'noire', 'gris', 'bleu'], 0, 3]}
#
#
# Couleurs proposées : ['bleu', 'orange', 'marron', 'rouge']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# {1: [['bleu', 'gris', 'rouge', 'vert'], 1, 1],
#  2: [['marron', 'rouge', 'bleu', 'vert'], 1, 0],
#  3: [['vert', 'marron', 'rouge', 'bleu'], 0, 1],
#  4: [['marron', 'noire', 'gris', 'bleu'], 0, 3],
#  5: [['vert', 'bleu', 'rouge', 'marron'], 0, 1],
#  6: [['vert', 'orange', 'rouge', 'gris'], 0, 1],
#  7: [['vert', 'jaune', 'gris', 'noire'], 0, 3],
#  8: [['marron', 'noire', 'gris', 'bleu'], 0, 3],
#  9: [['bleu', 'orange', 'marron', 'rouge'], 0, 1]}
#
#
# Couleurs proposées : ['jaune', 'noire', 'rouge', 'marron']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['bleu', 'gris', 'rouge', 'vert'], 1, 1],
#  2: [['marron', 'rouge', 'bleu', 'vert'], 1, 0],
#  3: [['vert', 'marron', 'rouge', 'bleu'], 0, 1],
#  4: [['marron', 'noire', 'gris', 'bleu'], 0, 3],
#  5: [['vert', 'bleu', 'rouge', 'marron'], 0, 1],
#  6: [['vert', 'orange', 'rouge', 'gris'], 0, 1],
#  7: [['vert', 'jaune', 'gris', 'noire'], 0, 3],
#  8: [['marron', 'noire', 'gris', 'bleu'], 0, 3],
#  9: [['bleu', 'orange', 'marron', 'rouge'], 0, 1],
#  10: [['jaune', 'noire', 'rouge', 'marron'], 0, 2]}
#
#
# Couleurs proposées : ['bleu', 'marron', 'noire', 'rouge']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['bleu', 'gris', 'rouge', 'vert'], 1, 1],
#  2: [['marron', 'rouge', 'bleu', 'vert'], 1, 0],
#  3: [['vert', 'marron', 'rouge', 'bleu'], 0, 1],
#  4: [['marron', 'noire', 'gris', 'bleu'], 0, 3],
#  5: [['vert', 'bleu', 'rouge', 'marron'], 0, 1],
#  6: [['vert', 'orange', 'rouge', 'gris'], 0, 1],
#  7: [['vert', 'jaune', 'gris', 'noire'], 0, 3],
#  8: [['marron', 'noire', 'gris', 'bleu'], 0, 3],
#  9: [['bleu', 'orange', 'marron', 'rouge'], 0, 1],
#  10: [['jaune', 'noire', 'rouge', 'marron'], 0, 2],
#  11: [['bleu', 'marron', 'noire', 'rouge'], 0, 2]}
#
#
# Couleurs proposées : ['noire', 'marron', 'gris', 'bleu']
# Couleurs bien placées : 1
# Couleurs mal placées : 2
#
#
# {1: [['bleu', 'gris', 'rouge', 'vert'], 1, 1],
#  2: [['marron', 'rouge', 'bleu', 'vert'], 1, 0],
#  3: [['vert', 'marron', 'rouge', 'bleu'], 0, 1],
#  4: [['marron', 'noire', 'gris', 'bleu'], 0, 3],
#  5: [['vert', 'bleu', 'rouge', 'marron'], 0, 1],
#  6: [['vert', 'orange', 'rouge', 'gris'], 0, 1],
#  7: [['vert', 'jaune', 'gris', 'noire'], 0, 3],
#  8: [['marron', 'noire', 'gris', 'bleu'], 0, 3],
#  9: [['bleu', 'orange', 'marron', 'rouge'], 0, 1],
#  10: [['jaune', 'noire', 'rouge', 'marron'], 0, 2],
#  11: [['bleu', 'marron', 'noire', 'rouge'], 0, 2],
#  12: [['noire', 'marron', 'gris', 'bleu'], 1, 2]}
#
#
# Partie perdue, t'es mauvais lolo !
# La solution était ['noire', 'gris', 'bleu', 'jaune']
#
#
# Nouvelle partie
# Couleurs proposées : ['noire', 'vert', 'marron', 'bleu']
# Couleurs bien placées : 0
# Couleurs mal placées : 3
#
#
# {1: [['noire', 'vert', 'marron', 'bleu'], 0, 3]}
#
#
# Couleurs proposées : ['noire', 'gris', 'orange', 'bleu']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# {1: [['noire', 'vert', 'marron', 'bleu'], 0, 3],
#  2: [['noire', 'gris', 'orange', 'bleu'], 0, 1]}
#
#
# Couleurs proposées : ['vert', 'noire', 'gris', 'bleu']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# {1: [['noire', 'vert', 'marron', 'bleu'], 0, 3],
#  2: [['noire', 'gris', 'orange', 'bleu'], 0, 1],
#  3: [['vert', 'noire', 'gris', 'bleu'], 1, 1]}
#
#
# Couleurs proposées : ['vert', 'orange', 'rouge', 'jaune']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# {1: [['noire', 'vert', 'marron', 'bleu'], 0, 3],
#  2: [['noire', 'gris', 'orange', 'bleu'], 0, 1],
#  3: [['vert', 'noire', 'gris', 'bleu'], 1, 1],
#  4: [['vert', 'orange', 'rouge', 'jaune'], 1, 1]}
#
#
# Couleurs proposées : ['noire', 'gris', 'jaune', 'bleu']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['noire', 'vert', 'marron', 'bleu'], 0, 3],
#  2: [['noire', 'gris', 'orange', 'bleu'], 0, 1],
#  3: [['vert', 'noire', 'gris', 'bleu'], 1, 1],
#  4: [['vert', 'orange', 'rouge', 'jaune'], 1, 1],
#  5: [['noire', 'gris', 'jaune', 'bleu'], 0, 2]}
#
#
# Couleurs proposées : ['bleu', 'orange', 'marron', 'noire']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['noire', 'vert', 'marron', 'bleu'], 0, 3],
#  2: [['noire', 'gris', 'orange', 'bleu'], 0, 1],
#  3: [['vert', 'noire', 'gris', 'bleu'], 1, 1],
#  4: [['vert', 'orange', 'rouge', 'jaune'], 1, 1],
#  5: [['noire', 'gris', 'jaune', 'bleu'], 0, 2],
#  6: [['bleu', 'orange', 'marron', 'noire'], 0, 2]}
#
#
# Couleurs proposées : ['rouge', 'gris', 'bleu', 'noire']
# Couleurs bien placées : 1
# Couleurs mal placées : 0
#
#
# {1: [['noire', 'vert', 'marron', 'bleu'], 0, 3],
#  2: [['noire', 'gris', 'orange', 'bleu'], 0, 1],
#  3: [['vert', 'noire', 'gris', 'bleu'], 1, 1],
#  4: [['vert', 'orange', 'rouge', 'jaune'], 1, 1],
#  5: [['noire', 'gris', 'jaune', 'bleu'], 0, 2],
#  6: [['bleu', 'orange', 'marron', 'noire'], 0, 2],
#  7: [['rouge', 'gris', 'bleu', 'noire'], 1, 0]}
#
#
# Couleurs proposées : ['jaune', 'bleu', 'gris', 'noire']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['noire', 'vert', 'marron', 'bleu'], 0, 3],
#  2: [['noire', 'gris', 'orange', 'bleu'], 0, 1],
#  3: [['vert', 'noire', 'gris', 'bleu'], 1, 1],
#  4: [['vert', 'orange', 'rouge', 'jaune'], 1, 1],
#  5: [['noire', 'gris', 'jaune', 'bleu'], 0, 2],
#  6: [['bleu', 'orange', 'marron', 'noire'], 0, 2],
#  7: [['rouge', 'gris', 'bleu', 'noire'], 1, 0],
#  8: [['jaune', 'bleu', 'gris', 'noire'], 0, 2]}
#
#
# Couleurs proposées : ['orange', 'vert', 'gris', 'marron']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# {1: [['noire', 'vert', 'marron', 'bleu'], 0, 3],
#  2: [['noire', 'gris', 'orange', 'bleu'], 0, 1],
#  3: [['vert', 'noire', 'gris', 'bleu'], 1, 1],
#  4: [['vert', 'orange', 'rouge', 'jaune'], 1, 1],
#  5: [['noire', 'gris', 'jaune', 'bleu'], 0, 2],
#  6: [['bleu', 'orange', 'marron', 'noire'], 0, 2],
#  7: [['rouge', 'gris', 'bleu', 'noire'], 1, 0],
#  8: [['jaune', 'bleu', 'gris', 'noire'], 0, 2],
#  9: [['orange', 'vert', 'gris', 'marron'], 1, 1]}
#
#
# Couleurs proposées : ['rouge', 'bleu', 'marron', 'noire']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['noire', 'vert', 'marron', 'bleu'], 0, 3],
#  2: [['noire', 'gris', 'orange', 'bleu'], 0, 1],
#  3: [['vert', 'noire', 'gris', 'bleu'], 1, 1],
#  4: [['vert', 'orange', 'rouge', 'jaune'], 1, 1],
#  5: [['noire', 'gris', 'jaune', 'bleu'], 0, 2],
#  6: [['bleu', 'orange', 'marron', 'noire'], 0, 2],
#  7: [['rouge', 'gris', 'bleu', 'noire'], 1, 0],
#  8: [['jaune', 'bleu', 'gris', 'noire'], 0, 2],
#  9: [['orange', 'vert', 'gris', 'marron'], 1, 1],
#  10: [['rouge', 'bleu', 'marron', 'noire'], 0, 2]}
#
#
# Couleurs proposées : ['bleu', 'rouge', 'vert', 'orange']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['noire', 'vert', 'marron', 'bleu'], 0, 3],
#  2: [['noire', 'gris', 'orange', 'bleu'], 0, 1],
#  3: [['vert', 'noire', 'gris', 'bleu'], 1, 1],
#  4: [['vert', 'orange', 'rouge', 'jaune'], 1, 1],
#  5: [['noire', 'gris', 'jaune', 'bleu'], 0, 2],
#  6: [['bleu', 'orange', 'marron', 'noire'], 0, 2],
#  7: [['rouge', 'gris', 'bleu', 'noire'], 1, 0],
#  8: [['jaune', 'bleu', 'gris', 'noire'], 0, 2],
#  9: [['orange', 'vert', 'gris', 'marron'], 1, 1],
#  10: [['rouge', 'bleu', 'marron', 'noire'], 0, 2],
#  11: [['bleu', 'rouge', 'vert', 'orange'], 0, 2]}
#
#
# Couleurs proposées : ['gris', 'orange', 'bleu', 'jaune']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# {1: [['noire', 'vert', 'marron', 'bleu'], 0, 3],
#  2: [['noire', 'gris', 'orange', 'bleu'], 0, 1],
#  3: [['vert', 'noire', 'gris', 'bleu'], 1, 1],
#  4: [['vert', 'orange', 'rouge', 'jaune'], 1, 1],
#  5: [['noire', 'gris', 'jaune', 'bleu'], 0, 2],
#  6: [['bleu', 'orange', 'marron', 'noire'], 0, 2],
#  7: [['rouge', 'gris', 'bleu', 'noire'], 1, 0],
#  8: [['jaune', 'bleu', 'gris', 'noire'], 0, 2],
#  9: [['orange', 'vert', 'gris', 'marron'], 1, 1],
#  10: [['rouge', 'bleu', 'marron', 'noire'], 0, 2],
#  11: [['bleu', 'rouge', 'vert', 'orange'], 0, 2],
#  12: [['gris', 'orange', 'bleu', 'jaune'], 1, 1]}
#
#
# Partie perdue, t'es mauvais lolo !
# La solution était ['vert', 'jaune', 'bleu', 'marron']
#
#
# Nouvelle partie
# Couleurs proposées : ['bleu', 'gris', 'jaune', 'vert']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# {1: [['bleu', 'gris', 'jaune', 'vert'], 0, 1]}
#
#
# Couleurs proposées : ['noire', 'rouge', 'bleu', 'jaune']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# {1: [['bleu', 'gris', 'jaune', 'vert'], 0, 1],
#  2: [['noire', 'rouge', 'bleu', 'jaune'], 1, 1]}
#
#
# Couleurs proposées : ['marron', 'gris', 'noire', 'orange']
# Couleurs bien placées : 0
# Couleurs mal placées : 3
#
#
# {1: [['bleu', 'gris', 'jaune', 'vert'], 0, 1],
#  2: [['noire', 'rouge', 'bleu', 'jaune'], 1, 1],
#  3: [['marron', 'gris', 'noire', 'orange'], 0, 3]}
#
#
# Couleurs proposées : ['vert', 'rouge', 'jaune', 'marron']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['bleu', 'gris', 'jaune', 'vert'], 0, 1],
#  2: [['noire', 'rouge', 'bleu', 'jaune'], 1, 1],
#  3: [['marron', 'gris', 'noire', 'orange'], 0, 3],
#  4: [['vert', 'rouge', 'jaune', 'marron'], 0, 2]}
#
#
# Couleurs proposées : ['gris', 'marron', 'vert', 'rouge']
# Couleurs bien placées : 2
# Couleurs mal placées : 1
#
#
# {1: [['bleu', 'gris', 'jaune', 'vert'], 0, 1],
#  2: [['noire', 'rouge', 'bleu', 'jaune'], 1, 1],
#  3: [['marron', 'gris', 'noire', 'orange'], 0, 3],
#  4: [['vert', 'rouge', 'jaune', 'marron'], 0, 2],
#  5: [['gris', 'marron', 'vert', 'rouge'], 2, 1]}
#
#
# Couleurs proposées : ['orange', 'vert', 'noire', 'bleu']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# {1: [['bleu', 'gris', 'jaune', 'vert'], 0, 1],
#  2: [['noire', 'rouge', 'bleu', 'jaune'], 1, 1],
#  3: [['marron', 'gris', 'noire', 'orange'], 0, 3],
#  4: [['vert', 'rouge', 'jaune', 'marron'], 0, 2],
#  5: [['gris', 'marron', 'vert', 'rouge'], 2, 1],
#  6: [['orange', 'vert', 'noire', 'bleu'], 0, 1]}
#
#
# Couleurs proposées : ['marron', 'vert', 'jaune', 'bleu']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# {1: [['bleu', 'gris', 'jaune', 'vert'], 0, 1],
#  2: [['noire', 'rouge', 'bleu', 'jaune'], 1, 1],
#  3: [['marron', 'gris', 'noire', 'orange'], 0, 3],
#  4: [['vert', 'rouge', 'jaune', 'marron'], 0, 2],
#  5: [['gris', 'marron', 'vert', 'rouge'], 2, 1],
#  6: [['orange', 'vert', 'noire', 'bleu'], 0, 1],
#  7: [['marron', 'vert', 'jaune', 'bleu'], 0, 1]}
#
#
# Couleurs proposées : ['jaune', 'bleu', 'vert', 'rouge']
# Couleurs bien placées : 1
# Couleurs mal placées : 0
#
#
# {1: [['bleu', 'gris', 'jaune', 'vert'], 0, 1],
#  2: [['noire', 'rouge', 'bleu', 'jaune'], 1, 1],
#  3: [['marron', 'gris', 'noire', 'orange'], 0, 3],
#  4: [['vert', 'rouge', 'jaune', 'marron'], 0, 2],
#  5: [['gris', 'marron', 'vert', 'rouge'], 2, 1],
#  6: [['orange', 'vert', 'noire', 'bleu'], 0, 1],
#  7: [['marron', 'vert', 'jaune', 'bleu'], 0, 1],
#  8: [['jaune', 'bleu', 'vert', 'rouge'], 1, 0]}
#
#
# Couleurs proposées : ['rouge', 'jaune', 'gris', 'orange']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# {1: [['bleu', 'gris', 'jaune', 'vert'], 0, 1],
#  2: [['noire', 'rouge', 'bleu', 'jaune'], 1, 1],
#  3: [['marron', 'gris', 'noire', 'orange'], 0, 3],
#  4: [['vert', 'rouge', 'jaune', 'marron'], 0, 2],
#  5: [['gris', 'marron', 'vert', 'rouge'], 2, 1],
#  6: [['orange', 'vert', 'noire', 'bleu'], 0, 1],
#  7: [['marron', 'vert', 'jaune', 'bleu'], 0, 1],
#  8: [['jaune', 'bleu', 'vert', 'rouge'], 1, 0],
#  9: [['rouge', 'jaune', 'gris', 'orange'], 1, 1]}
#
#
# Couleurs proposées : ['vert', 'marron', 'noire', 'orange']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# {1: [['bleu', 'gris', 'jaune', 'vert'], 0, 1],
#  2: [['noire', 'rouge', 'bleu', 'jaune'], 1, 1],
#  3: [['marron', 'gris', 'noire', 'orange'], 0, 3],
#  4: [['vert', 'rouge', 'jaune', 'marron'], 0, 2],
#  5: [['gris', 'marron', 'vert', 'rouge'], 2, 1],
#  6: [['orange', 'vert', 'noire', 'bleu'], 0, 1],
#  7: [['marron', 'vert', 'jaune', 'bleu'], 0, 1],
#  8: [['jaune', 'bleu', 'vert', 'rouge'], 1, 0],
#  9: [['rouge', 'jaune', 'gris', 'orange'], 1, 1],
#  10: [['vert', 'marron', 'noire', 'orange'], 1, 1]}
#
#
# Couleurs proposées : ['gris', 'marron', 'bleu', 'noire']
# Couleurs bien placées : 1
# Couleurs mal placées : 2
#
#
# {1: [['bleu', 'gris', 'jaune', 'vert'], 0, 1],
#  2: [['noire', 'rouge', 'bleu', 'jaune'], 1, 1],
#  3: [['marron', 'gris', 'noire', 'orange'], 0, 3],
#  4: [['vert', 'rouge', 'jaune', 'marron'], 0, 2],
#  5: [['gris', 'marron', 'vert', 'rouge'], 2, 1],
#  6: [['orange', 'vert', 'noire', 'bleu'], 0, 1],
#  7: [['marron', 'vert', 'jaune', 'bleu'], 0, 1],
#  8: [['jaune', 'bleu', 'vert', 'rouge'], 1, 0],
#  9: [['rouge', 'jaune', 'gris', 'orange'], 1, 1],
#  10: [['vert', 'marron', 'noire', 'orange'], 1, 1],
#  11: [['gris', 'marron', 'bleu', 'noire'], 1, 2]}
#
#
# Couleurs proposées : ['gris', 'vert', 'orange', 'jaune']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# {1: [['bleu', 'gris', 'jaune', 'vert'], 0, 1],
#  2: [['noire', 'rouge', 'bleu', 'jaune'], 1, 1],
#  3: [['marron', 'gris', 'noire', 'orange'], 0, 3],
#  4: [['vert', 'rouge', 'jaune', 'marron'], 0, 2],
#  5: [['gris', 'marron', 'vert', 'rouge'], 2, 1],
#  6: [['orange', 'vert', 'noire', 'bleu'], 0, 1],
#  7: [['marron', 'vert', 'jaune', 'bleu'], 0, 1],
#  8: [['jaune', 'bleu', 'vert', 'rouge'], 1, 0],
#  9: [['rouge', 'jaune', 'gris', 'orange'], 1, 1],
#  10: [['vert', 'marron', 'noire', 'orange'], 1, 1],
#  11: [['gris', 'marron', 'bleu', 'noire'], 1, 2],
#  12: [['gris', 'vert', 'orange', 'jaune'], 0, 1]}
#
#
# Partie perdue, t'es mauvais lolo !
# La solution était ['noire', 'marron', 'gris', 'rouge']
#
#
# Nouvelle partie
# Couleurs proposées : ['jaune', 'vert', 'orange', 'rouge']
# Couleurs bien placées : 2
# Couleurs mal placées : 1
#
#
# {1: [['jaune', 'vert', 'orange', 'rouge'], 2, 1]}
#
#
# Couleurs proposées : ['gris', 'orange', 'rouge', 'noire']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# {1: [['jaune', 'vert', 'orange', 'rouge'], 2, 1],
#  2: [['gris', 'orange', 'rouge', 'noire'], 0, 1]}
#
#
# Couleurs proposées : ['vert', 'orange', 'marron', 'bleu']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['jaune', 'vert', 'orange', 'rouge'], 2, 1],
#  2: [['gris', 'orange', 'rouge', 'noire'], 0, 1],
#  3: [['vert', 'orange', 'marron', 'bleu'], 0, 2]}
#
#
# Couleurs proposées : ['orange', 'bleu', 'rouge', 'gris']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# {1: [['jaune', 'vert', 'orange', 'rouge'], 2, 1],
#  2: [['gris', 'orange', 'rouge', 'noire'], 0, 1],
#  3: [['vert', 'orange', 'marron', 'bleu'], 0, 2],
#  4: [['orange', 'bleu', 'rouge', 'gris'], 1, 1]}
#
#
# Couleurs proposées : ['bleu', 'jaune', 'gris', 'rouge']
# Couleurs bien placées : 1
# Couleurs mal placées : 2
#
#
# {1: [['jaune', 'vert', 'orange', 'rouge'], 2, 1],
#  2: [['gris', 'orange', 'rouge', 'noire'], 0, 1],
#  3: [['vert', 'orange', 'marron', 'bleu'], 0, 2],
#  4: [['orange', 'bleu', 'rouge', 'gris'], 1, 1],
#  5: [['bleu', 'jaune', 'gris', 'rouge'], 1, 2]}
#
#
# Couleurs proposées : ['orange', 'vert', 'noire', 'rouge']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# {1: [['jaune', 'vert', 'orange', 'rouge'], 2, 1],
#  2: [['gris', 'orange', 'rouge', 'noire'], 0, 1],
#  3: [['vert', 'orange', 'marron', 'bleu'], 0, 2],
#  4: [['orange', 'bleu', 'rouge', 'gris'], 1, 1],
#  5: [['bleu', 'jaune', 'gris', 'rouge'], 1, 2],
#  6: [['orange', 'vert', 'noire', 'rouge'], 1, 1]}
#
#
# Couleurs proposées : ['noire', 'rouge', 'gris', 'bleu']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['jaune', 'vert', 'orange', 'rouge'], 2, 1],
#  2: [['gris', 'orange', 'rouge', 'noire'], 0, 1],
#  3: [['vert', 'orange', 'marron', 'bleu'], 0, 2],
#  4: [['orange', 'bleu', 'rouge', 'gris'], 1, 1],
#  5: [['bleu', 'jaune', 'gris', 'rouge'], 1, 2],
#  6: [['orange', 'vert', 'noire', 'rouge'], 1, 1],
#  7: [['noire', 'rouge', 'gris', 'bleu'], 0, 2]}
#
#
# Couleurs proposées : ['noire', 'rouge', 'jaune', 'gris']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['jaune', 'vert', 'orange', 'rouge'], 2, 1],
#  2: [['gris', 'orange', 'rouge', 'noire'], 0, 1],
#  3: [['vert', 'orange', 'marron', 'bleu'], 0, 2],
#  4: [['orange', 'bleu', 'rouge', 'gris'], 1, 1],
#  5: [['bleu', 'jaune', 'gris', 'rouge'], 1, 2],
#  6: [['orange', 'vert', 'noire', 'rouge'], 1, 1],
#  7: [['noire', 'rouge', 'gris', 'bleu'], 0, 2],
#  8: [['noire', 'rouge', 'jaune', 'gris'], 0, 2]}
#
#
# Couleurs proposées : ['vert', 'rouge', 'bleu', 'jaune']
# Couleurs bien placées : 0
# Couleurs mal placées : 4
#
#
# {1: [['jaune', 'vert', 'orange', 'rouge'], 2, 1],
#  2: [['gris', 'orange', 'rouge', 'noire'], 0, 1],
#  3: [['vert', 'orange', 'marron', 'bleu'], 0, 2],
#  4: [['orange', 'bleu', 'rouge', 'gris'], 1, 1],
#  5: [['bleu', 'jaune', 'gris', 'rouge'], 1, 2],
#  6: [['orange', 'vert', 'noire', 'rouge'], 1, 1],
#  7: [['noire', 'rouge', 'gris', 'bleu'], 0, 2],
#  8: [['noire', 'rouge', 'jaune', 'gris'], 0, 2],
#  9: [['vert', 'rouge', 'bleu', 'jaune'], 0, 4]}
#
#
# Couleurs proposées : ['marron', 'noire', 'vert', 'orange']
# Couleurs bien placées : 1
# Couleurs mal placées : 0
#
#
# {1: [['jaune', 'vert', 'orange', 'rouge'], 2, 1],
#  2: [['gris', 'orange', 'rouge', 'noire'], 0, 1],
#  3: [['vert', 'orange', 'marron', 'bleu'], 0, 2],
#  4: [['orange', 'bleu', 'rouge', 'gris'], 1, 1],
#  5: [['bleu', 'jaune', 'gris', 'rouge'], 1, 2],
#  6: [['orange', 'vert', 'noire', 'rouge'], 1, 1],
#  7: [['noire', 'rouge', 'gris', 'bleu'], 0, 2],
#  8: [['noire', 'rouge', 'jaune', 'gris'], 0, 2],
#  9: [['vert', 'rouge', 'bleu', 'jaune'], 0, 4],
#  10: [['marron', 'noire', 'vert', 'orange'], 1, 0]}
#
#
# Couleurs proposées : ['marron', 'bleu', 'orange', 'rouge']
# Couleurs bien placées : 2
# Couleurs mal placées : 0
#
#
# {1: [['jaune', 'vert', 'orange', 'rouge'], 2, 1],
#  2: [['gris', 'orange', 'rouge', 'noire'], 0, 1],
#  3: [['vert', 'orange', 'marron', 'bleu'], 0, 2],
#  4: [['orange', 'bleu', 'rouge', 'gris'], 1, 1],
#  5: [['bleu', 'jaune', 'gris', 'rouge'], 1, 2],
#  6: [['orange', 'vert', 'noire', 'rouge'], 1, 1],
#  7: [['noire', 'rouge', 'gris', 'bleu'], 0, 2],
#  8: [['noire', 'rouge', 'jaune', 'gris'], 0, 2],
#  9: [['vert', 'rouge', 'bleu', 'jaune'], 0, 4],
#  10: [['marron', 'noire', 'vert', 'orange'], 1, 0],
#  11: [['marron', 'bleu', 'orange', 'rouge'], 2, 0]}
#
#
# Couleurs proposées : ['gris', 'orange', 'rouge', 'vert']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['jaune', 'vert', 'orange', 'rouge'], 2, 1],
#  2: [['gris', 'orange', 'rouge', 'noire'], 0, 1],
#  3: [['vert', 'orange', 'marron', 'bleu'], 0, 2],
#  4: [['orange', 'bleu', 'rouge', 'gris'], 1, 1],
#  5: [['bleu', 'jaune', 'gris', 'rouge'], 1, 2],
#  6: [['orange', 'vert', 'noire', 'rouge'], 1, 1],
#  7: [['noire', 'rouge', 'gris', 'bleu'], 0, 2],
#  8: [['noire', 'rouge', 'jaune', 'gris'], 0, 2],
#  9: [['vert', 'rouge', 'bleu', 'jaune'], 0, 4],
#  10: [['marron', 'noire', 'vert', 'orange'], 1, 0],
#  11: [['marron', 'bleu', 'orange', 'rouge'], 2, 0],
#  12: [['gris', 'orange', 'rouge', 'vert'], 0, 2]}
#
#
# Partie perdue, t'es mauvais lolo !
# La solution était ['jaune', 'bleu', 'vert', 'rouge']
#
#
# Nouvelle partie
# Couleurs proposées : ['bleu', 'noire', 'jaune', 'gris']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# {1: [['bleu', 'noire', 'jaune', 'gris'], 1, 1]}
#
#
# Couleurs proposées : ['noire', 'bleu', 'marron', 'rouge']
# Couleurs bien placées : 0
# Couleurs mal placées : 3
#
#
# {1: [['bleu', 'noire', 'jaune', 'gris'], 1, 1],
#  2: [['noire', 'bleu', 'marron', 'rouge'], 0, 3]}
#
#
# Couleurs proposées : ['vert', 'marron', 'noire', 'orange']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['bleu', 'noire', 'jaune', 'gris'], 1, 1],
#  2: [['noire', 'bleu', 'marron', 'rouge'], 0, 3],
#  3: [['vert', 'marron', 'noire', 'orange'], 0, 2]}
#
#
# Couleurs proposées : ['orange', 'marron', 'bleu', 'rouge']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['bleu', 'noire', 'jaune', 'gris'], 1, 1],
#  2: [['noire', 'bleu', 'marron', 'rouge'], 0, 3],
#  3: [['vert', 'marron', 'noire', 'orange'], 0, 2],
#  4: [['orange', 'marron', 'bleu', 'rouge'], 0, 2]}
#
#
# Couleurs proposées : ['vert', 'noire', 'jaune', 'marron']
# Couleurs bien placées : 2
# Couleurs mal placées : 1
#
#
# {1: [['bleu', 'noire', 'jaune', 'gris'], 1, 1],
#  2: [['noire', 'bleu', 'marron', 'rouge'], 0, 3],
#  3: [['vert', 'marron', 'noire', 'orange'], 0, 2],
#  4: [['orange', 'marron', 'bleu', 'rouge'], 0, 2],
#  5: [['vert', 'noire', 'jaune', 'marron'], 2, 1]}
#
#
# Couleurs proposées : ['noire', 'orange', 'bleu', 'marron']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# {1: [['bleu', 'noire', 'jaune', 'gris'], 1, 1],
#  2: [['noire', 'bleu', 'marron', 'rouge'], 0, 3],
#  3: [['vert', 'marron', 'noire', 'orange'], 0, 2],
#  4: [['orange', 'marron', 'bleu', 'rouge'], 0, 2],
#  5: [['vert', 'noire', 'jaune', 'marron'], 2, 1],
#  6: [['noire', 'orange', 'bleu', 'marron'], 1, 1]}
#
#
# Couleurs proposées : ['vert', 'orange', 'noire', 'bleu']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# {1: [['bleu', 'noire', 'jaune', 'gris'], 1, 1],
#  2: [['noire', 'bleu', 'marron', 'rouge'], 0, 3],
#  3: [['vert', 'marron', 'noire', 'orange'], 0, 2],
#  4: [['orange', 'marron', 'bleu', 'rouge'], 0, 2],
#  5: [['vert', 'noire', 'jaune', 'marron'], 2, 1],
#  6: [['noire', 'orange', 'bleu', 'marron'], 1, 1],
#  7: [['vert', 'orange', 'noire', 'bleu'], 0, 1]}
#
#
# Couleurs proposées : ['rouge', 'marron', 'jaune', 'gris']
# Couleurs bien placées : 0
# Couleurs mal placées : 3
#
#
# {1: [['bleu', 'noire', 'jaune', 'gris'], 1, 1],
#  2: [['noire', 'bleu', 'marron', 'rouge'], 0, 3],
#  3: [['vert', 'marron', 'noire', 'orange'], 0, 2],
#  4: [['orange', 'marron', 'bleu', 'rouge'], 0, 2],
#  5: [['vert', 'noire', 'jaune', 'marron'], 2, 1],
#  6: [['noire', 'orange', 'bleu', 'marron'], 1, 1],
#  7: [['vert', 'orange', 'noire', 'bleu'], 0, 1],
#  8: [['rouge', 'marron', 'jaune', 'gris'], 0, 3]}
#
#
# Couleurs proposées : ['gris', 'jaune', 'noire', 'rouge']
# Couleurs bien placées : 0
# Couleurs mal placées : 3
#
#
# {1: [['bleu', 'noire', 'jaune', 'gris'], 1, 1],
#  2: [['noire', 'bleu', 'marron', 'rouge'], 0, 3],
#  3: [['vert', 'marron', 'noire', 'orange'], 0, 2],
#  4: [['orange', 'marron', 'bleu', 'rouge'], 0, 2],
#  5: [['vert', 'noire', 'jaune', 'marron'], 2, 1],
#  6: [['noire', 'orange', 'bleu', 'marron'], 1, 1],
#  7: [['vert', 'orange', 'noire', 'bleu'], 0, 1],
#  8: [['rouge', 'marron', 'jaune', 'gris'], 0, 3],
#  9: [['gris', 'jaune', 'noire', 'rouge'], 0, 3]}
#
#
# Couleurs proposées : ['vert', 'jaune', 'bleu', 'noire']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['bleu', 'noire', 'jaune', 'gris'], 1, 1],
#  2: [['noire', 'bleu', 'marron', 'rouge'], 0, 3],
#  3: [['vert', 'marron', 'noire', 'orange'], 0, 2],
#  4: [['orange', 'marron', 'bleu', 'rouge'], 0, 2],
#  5: [['vert', 'noire', 'jaune', 'marron'], 2, 1],
#  6: [['noire', 'orange', 'bleu', 'marron'], 1, 1],
#  7: [['vert', 'orange', 'noire', 'bleu'], 0, 1],
#  8: [['rouge', 'marron', 'jaune', 'gris'], 0, 3],
#  9: [['gris', 'jaune', 'noire', 'rouge'], 0, 3],
#  10: [['vert', 'jaune', 'bleu', 'noire'], 0, 2]}
#
#
# Couleurs proposées : ['rouge', 'vert', 'bleu', 'gris']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# {1: [['bleu', 'noire', 'jaune', 'gris'], 1, 1],
#  2: [['noire', 'bleu', 'marron', 'rouge'], 0, 3],
#  3: [['vert', 'marron', 'noire', 'orange'], 0, 2],
#  4: [['orange', 'marron', 'bleu', 'rouge'], 0, 2],
#  5: [['vert', 'noire', 'jaune', 'marron'], 2, 1],
#  6: [['noire', 'orange', 'bleu', 'marron'], 1, 1],
#  7: [['vert', 'orange', 'noire', 'bleu'], 0, 1],
#  8: [['rouge', 'marron', 'jaune', 'gris'], 0, 3],
#  9: [['gris', 'jaune', 'noire', 'rouge'], 0, 3],
#  10: [['vert', 'jaune', 'bleu', 'noire'], 0, 2],
#  11: [['rouge', 'vert', 'bleu', 'gris'], 0, 1]}
#
#
# Couleurs proposées : ['jaune', 'orange', 'vert', 'rouge']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# {1: [['bleu', 'noire', 'jaune', 'gris'], 1, 1],
#  2: [['noire', 'bleu', 'marron', 'rouge'], 0, 3],
#  3: [['vert', 'marron', 'noire', 'orange'], 0, 2],
#  4: [['orange', 'marron', 'bleu', 'rouge'], 0, 2],
#  5: [['vert', 'noire', 'jaune', 'marron'], 2, 1],
#  6: [['noire', 'orange', 'bleu', 'marron'], 1, 1],
#  7: [['vert', 'orange', 'noire', 'bleu'], 0, 1],
#  8: [['rouge', 'marron', 'jaune', 'gris'], 0, 3],
#  9: [['gris', 'jaune', 'noire', 'rouge'], 0, 3],
#  10: [['vert', 'jaune', 'bleu', 'noire'], 0, 2],
#  11: [['rouge', 'vert', 'bleu', 'gris'], 0, 1],
#  12: [['jaune', 'orange', 'vert', 'rouge'], 1, 1]}
#
#
# Partie perdue, t'es mauvais lolo !
# La solution était ['jaune', 'noire', 'rouge', 'marron']
#
#
# Nouvelle partie
# Couleurs proposées : ['marron', 'gris', 'vert', 'orange']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['marron', 'gris', 'vert', 'orange'], 0, 2]}
#
#
# Couleurs proposées : ['jaune', 'gris', 'marron', 'orange']
# Couleurs bien placées : 2
# Couleurs mal placées : 1
#
#
# {1: [['marron', 'gris', 'vert', 'orange'], 0, 2],
#  2: [['jaune', 'gris', 'marron', 'orange'], 2, 1]}
#
#
# Couleurs proposées : ['vert', 'marron', 'jaune', 'rouge']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['marron', 'gris', 'vert', 'orange'], 0, 2],
#  2: [['jaune', 'gris', 'marron', 'orange'], 2, 1],
#  3: [['vert', 'marron', 'jaune', 'rouge'], 0, 2]}
#
#
# Couleurs proposées : ['rouge', 'orange', 'bleu', 'marron']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# {1: [['marron', 'gris', 'vert', 'orange'], 0, 2],
#  2: [['jaune', 'gris', 'marron', 'orange'], 2, 1],
#  3: [['vert', 'marron', 'jaune', 'rouge'], 0, 2],
#  4: [['rouge', 'orange', 'bleu', 'marron'], 1, 1]}
#
#
# Couleurs proposées : ['noire', 'marron', 'bleu', 'jaune']
# Couleurs bien placées : 0
# Couleurs mal placées : 3
#
#
# {1: [['marron', 'gris', 'vert', 'orange'], 0, 2],
#  2: [['jaune', 'gris', 'marron', 'orange'], 2, 1],
#  3: [['vert', 'marron', 'jaune', 'rouge'], 0, 2],
#  4: [['rouge', 'orange', 'bleu', 'marron'], 1, 1],
#  5: [['noire', 'marron', 'bleu', 'jaune'], 0, 3]}
#
#
# Couleurs proposées : ['bleu', 'jaune', 'vert', 'orange']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['marron', 'gris', 'vert', 'orange'], 0, 2],
#  2: [['jaune', 'gris', 'marron', 'orange'], 2, 1],
#  3: [['vert', 'marron', 'jaune', 'rouge'], 0, 2],
#  4: [['rouge', 'orange', 'bleu', 'marron'], 1, 1],
#  5: [['noire', 'marron', 'bleu', 'jaune'], 0, 3],
#  6: [['bleu', 'jaune', 'vert', 'orange'], 0, 2]}
#
#
# Couleurs proposées : ['gris', 'marron', 'jaune', 'bleu']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['marron', 'gris', 'vert', 'orange'], 0, 2],
#  2: [['jaune', 'gris', 'marron', 'orange'], 2, 1],
#  3: [['vert', 'marron', 'jaune', 'rouge'], 0, 2],
#  4: [['rouge', 'orange', 'bleu', 'marron'], 1, 1],
#  5: [['noire', 'marron', 'bleu', 'jaune'], 0, 3],
#  6: [['bleu', 'jaune', 'vert', 'orange'], 0, 2],
#  7: [['gris', 'marron', 'jaune', 'bleu'], 0, 2]}
#
#
# Couleurs proposées : ['jaune', 'bleu', 'vert', 'orange']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# {1: [['marron', 'gris', 'vert', 'orange'], 0, 2],
#  2: [['jaune', 'gris', 'marron', 'orange'], 2, 1],
#  3: [['vert', 'marron', 'jaune', 'rouge'], 0, 2],
#  4: [['rouge', 'orange', 'bleu', 'marron'], 1, 1],
#  5: [['noire', 'marron', 'bleu', 'jaune'], 0, 3],
#  6: [['bleu', 'jaune', 'vert', 'orange'], 0, 2],
#  7: [['gris', 'marron', 'jaune', 'bleu'], 0, 2],
#  8: [['jaune', 'bleu', 'vert', 'orange'], 1, 1]}
#
#
# Couleurs proposées : ['marron', 'noire', 'vert', 'orange']
# Couleurs bien placées : 0
# Couleurs mal placées : 3
#
#
# {1: [['marron', 'gris', 'vert', 'orange'], 0, 2],
#  2: [['jaune', 'gris', 'marron', 'orange'], 2, 1],
#  3: [['vert', 'marron', 'jaune', 'rouge'], 0, 2],
#  4: [['rouge', 'orange', 'bleu', 'marron'], 1, 1],
#  5: [['noire', 'marron', 'bleu', 'jaune'], 0, 3],
#  6: [['bleu', 'jaune', 'vert', 'orange'], 0, 2],
#  7: [['gris', 'marron', 'jaune', 'bleu'], 0, 2],
#  8: [['jaune', 'bleu', 'vert', 'orange'], 1, 1],
#  9: [['marron', 'noire', 'vert', 'orange'], 0, 3]}
#
#
# Couleurs proposées : ['orange', 'vert', 'marron', 'bleu']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# {1: [['marron', 'gris', 'vert', 'orange'], 0, 2],
#  2: [['jaune', 'gris', 'marron', 'orange'], 2, 1],
#  3: [['vert', 'marron', 'jaune', 'rouge'], 0, 2],
#  4: [['rouge', 'orange', 'bleu', 'marron'], 1, 1],
#  5: [['noire', 'marron', 'bleu', 'jaune'], 0, 3],
#  6: [['bleu', 'jaune', 'vert', 'orange'], 0, 2],
#  7: [['gris', 'marron', 'jaune', 'bleu'], 0, 2],
#  8: [['jaune', 'bleu', 'vert', 'orange'], 1, 1],
#  9: [['marron', 'noire', 'vert', 'orange'], 0, 3],
#  10: [['orange', 'vert', 'marron', 'bleu'], 1, 1]}
#
#
# Couleurs proposées : ['rouge', 'gris', 'orange', 'noire']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# {1: [['marron', 'gris', 'vert', 'orange'], 0, 2],
#  2: [['jaune', 'gris', 'marron', 'orange'], 2, 1],
#  3: [['vert', 'marron', 'jaune', 'rouge'], 0, 2],
#  4: [['rouge', 'orange', 'bleu', 'marron'], 1, 1],
#  5: [['noire', 'marron', 'bleu', 'jaune'], 0, 3],
#  6: [['bleu', 'jaune', 'vert', 'orange'], 0, 2],
#  7: [['gris', 'marron', 'jaune', 'bleu'], 0, 2],
#  8: [['jaune', 'bleu', 'vert', 'orange'], 1, 1],
#  9: [['marron', 'noire', 'vert', 'orange'], 0, 3],
#  10: [['orange', 'vert', 'marron', 'bleu'], 1, 1],
#  11: [['rouge', 'gris', 'orange', 'noire'], 1, 1]}
#
#
# Couleurs proposées : ['orange', 'gris', 'marron', 'vert']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# {1: [['marron', 'gris', 'vert', 'orange'], 0, 2],
#  2: [['jaune', 'gris', 'marron', 'orange'], 2, 1],
#  3: [['vert', 'marron', 'jaune', 'rouge'], 0, 2],
#  4: [['rouge', 'orange', 'bleu', 'marron'], 1, 1],
#  5: [['noire', 'marron', 'bleu', 'jaune'], 0, 3],
#  6: [['bleu', 'jaune', 'vert', 'orange'], 0, 2],
#  7: [['gris', 'marron', 'jaune', 'bleu'], 0, 2],
#  8: [['jaune', 'bleu', 'vert', 'orange'], 1, 1],
#  9: [['marron', 'noire', 'vert', 'orange'], 0, 3],
#  10: [['orange', 'vert', 'marron', 'bleu'], 1, 1],
#  11: [['rouge', 'gris', 'orange', 'noire'], 1, 1],
#  12: [['orange', 'gris', 'marron', 'vert'], 1, 1]}
#
#
# Partie perdue, t'es mauvais lolo !
# La solution était ['jaune', 'orange', 'marron', 'noire']
#
#
# Nouvelle partie
# Couleurs proposées : ['marron', 'bleu', 'gris', 'vert']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# {1: [['marron', 'bleu', 'gris', 'vert'], 0, 1]}
#
#
# Couleurs proposées : ['orange', 'marron', 'noire', 'rouge']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['marron', 'bleu', 'gris', 'vert'], 0, 1],
#  2: [['orange', 'marron', 'noire', 'rouge'], 0, 2]}
#
#
# Couleurs proposées : ['orange', 'noire', 'vert', 'marron']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# {1: [['marron', 'bleu', 'gris', 'vert'], 0, 1],
#  2: [['orange', 'marron', 'noire', 'rouge'], 0, 2],
#  3: [['orange', 'noire', 'vert', 'marron'], 0, 1]}
#
#
# Couleurs proposées : ['orange', 'gris', 'bleu', 'rouge']
# Couleurs bien placées : 0
# Couleurs mal placées : 3
#
#
# {1: [['marron', 'bleu', 'gris', 'vert'], 0, 1],
#  2: [['orange', 'marron', 'noire', 'rouge'], 0, 2],
#  3: [['orange', 'noire', 'vert', 'marron'], 0, 1],
#  4: [['orange', 'gris', 'bleu', 'rouge'], 0, 3]}
#
#
# Couleurs proposées : ['marron', 'jaune', 'rouge', 'noire']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# {1: [['marron', 'bleu', 'gris', 'vert'], 0, 1],
#  2: [['orange', 'marron', 'noire', 'rouge'], 0, 2],
#  3: [['orange', 'noire', 'vert', 'marron'], 0, 1],
#  4: [['orange', 'gris', 'bleu', 'rouge'], 0, 3],
#  5: [['marron', 'jaune', 'rouge', 'noire'], 1, 1]}
#
#
# Couleurs proposées : ['noire', 'gris', 'jaune', 'bleu']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# {1: [['marron', 'bleu', 'gris', 'vert'], 0, 1],
#  2: [['orange', 'marron', 'noire', 'rouge'], 0, 2],
#  3: [['orange', 'noire', 'vert', 'marron'], 0, 1],
#  4: [['orange', 'gris', 'bleu', 'rouge'], 0, 3],
#  5: [['marron', 'jaune', 'rouge', 'noire'], 1, 1],
#  6: [['noire', 'gris', 'jaune', 'bleu'], 1, 1]}
#
#
# Couleurs proposées : ['marron', 'orange', 'noire', 'rouge']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['marron', 'bleu', 'gris', 'vert'], 0, 1],
#  2: [['orange', 'marron', 'noire', 'rouge'], 0, 2],
#  3: [['orange', 'noire', 'vert', 'marron'], 0, 1],
#  4: [['orange', 'gris', 'bleu', 'rouge'], 0, 3],
#  5: [['marron', 'jaune', 'rouge', 'noire'], 1, 1],
#  6: [['noire', 'gris', 'jaune', 'bleu'], 1, 1],
#  7: [['marron', 'orange', 'noire', 'rouge'], 0, 2]}
#
#
# Couleurs proposées : ['bleu', 'noire', 'gris', 'rouge']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['marron', 'bleu', 'gris', 'vert'], 0, 1],
#  2: [['orange', 'marron', 'noire', 'rouge'], 0, 2],
#  3: [['orange', 'noire', 'vert', 'marron'], 0, 1],
#  4: [['orange', 'gris', 'bleu', 'rouge'], 0, 3],
#  5: [['marron', 'jaune', 'rouge', 'noire'], 1, 1],
#  6: [['noire', 'gris', 'jaune', 'bleu'], 1, 1],
#  7: [['marron', 'orange', 'noire', 'rouge'], 0, 2],
#  8: [['bleu', 'noire', 'gris', 'rouge'], 0, 2]}
#
#
# Couleurs proposées : ['noire', 'jaune', 'marron', 'rouge']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# {1: [['marron', 'bleu', 'gris', 'vert'], 0, 1],
#  2: [['orange', 'marron', 'noire', 'rouge'], 0, 2],
#  3: [['orange', 'noire', 'vert', 'marron'], 0, 1],
#  4: [['orange', 'gris', 'bleu', 'rouge'], 0, 3],
#  5: [['marron', 'jaune', 'rouge', 'noire'], 1, 1],
#  6: [['noire', 'gris', 'jaune', 'bleu'], 1, 1],
#  7: [['marron', 'orange', 'noire', 'rouge'], 0, 2],
#  8: [['bleu', 'noire', 'gris', 'rouge'], 0, 2],
#  9: [['noire', 'jaune', 'marron', 'rouge'], 1, 1]}
#
#
# Couleurs proposées : ['marron', 'orange', 'bleu', 'noire']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['marron', 'bleu', 'gris', 'vert'], 0, 1],
#  2: [['orange', 'marron', 'noire', 'rouge'], 0, 2],
#  3: [['orange', 'noire', 'vert', 'marron'], 0, 1],
#  4: [['orange', 'gris', 'bleu', 'rouge'], 0, 3],
#  5: [['marron', 'jaune', 'rouge', 'noire'], 1, 1],
#  6: [['noire', 'gris', 'jaune', 'bleu'], 1, 1],
#  7: [['marron', 'orange', 'noire', 'rouge'], 0, 2],
#  8: [['bleu', 'noire', 'gris', 'rouge'], 0, 2],
#  9: [['noire', 'jaune', 'marron', 'rouge'], 1, 1],
#  10: [['marron', 'orange', 'bleu', 'noire'], 0, 2]}
#
#
# Couleurs proposées : ['noire', 'jaune', 'marron', 'bleu']
# Couleurs bien placées : 2
# Couleurs mal placées : 0
#
#
# {1: [['marron', 'bleu', 'gris', 'vert'], 0, 1],
#  2: [['orange', 'marron', 'noire', 'rouge'], 0, 2],
#  3: [['orange', 'noire', 'vert', 'marron'], 0, 1],
#  4: [['orange', 'gris', 'bleu', 'rouge'], 0, 3],
#  5: [['marron', 'jaune', 'rouge', 'noire'], 1, 1],
#  6: [['noire', 'gris', 'jaune', 'bleu'], 1, 1],
#  7: [['marron', 'orange', 'noire', 'rouge'], 0, 2],
#  8: [['bleu', 'noire', 'gris', 'rouge'], 0, 2],
#  9: [['noire', 'jaune', 'marron', 'rouge'], 1, 1],
#  10: [['marron', 'orange', 'bleu', 'noire'], 0, 2],
#  11: [['noire', 'jaune', 'marron', 'bleu'], 2, 0]}
#
#
# Couleurs proposées : ['vert', 'bleu', 'marron', 'noire']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# {1: [['marron', 'bleu', 'gris', 'vert'], 0, 1],
#  2: [['orange', 'marron', 'noire', 'rouge'], 0, 2],
#  3: [['orange', 'noire', 'vert', 'marron'], 0, 1],
#  4: [['orange', 'gris', 'bleu', 'rouge'], 0, 3],
#  5: [['marron', 'jaune', 'rouge', 'noire'], 1, 1],
#  6: [['noire', 'gris', 'jaune', 'bleu'], 1, 1],
#  7: [['marron', 'orange', 'noire', 'rouge'], 0, 2],
#  8: [['bleu', 'noire', 'gris', 'rouge'], 0, 2],
#  9: [['noire', 'jaune', 'marron', 'rouge'], 1, 1],
#  10: [['marron', 'orange', 'bleu', 'noire'], 0, 2],
#  11: [['noire', 'jaune', 'marron', 'bleu'], 2, 0],
#  12: [['vert', 'bleu', 'marron', 'noire'], 0, 1]}
#
#
# Partie perdue, t'es mauvais lolo !
# La solution était ['rouge', 'jaune', 'orange', 'bleu']
#
#
# Nouvelle partie
# Couleurs proposées : ['marron', 'gris', 'orange', 'bleu']
# Couleurs bien placées : 1
# Couleurs mal placées : 2
#
#
# {1: [['marron', 'gris', 'orange', 'bleu'], 1, 2]}
#
#
# Couleurs proposées : ['jaune', 'noire', 'rouge', 'marron']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# {1: [['marron', 'gris', 'orange', 'bleu'], 1, 2],
#  2: [['jaune', 'noire', 'rouge', 'marron'], 0, 1]}
#
#
# Couleurs proposées : ['bleu', 'noire', 'vert', 'marron']
# Couleurs bien placées : 1
# Couleurs mal placées : 2
#
#
# {1: [['marron', 'gris', 'orange', 'bleu'], 1, 2],
#  2: [['jaune', 'noire', 'rouge', 'marron'], 0, 1],
#  3: [['bleu', 'noire', 'vert', 'marron'], 1, 2]}
#
#
# Couleurs proposées : ['noire', 'rouge', 'marron', 'orange']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['marron', 'gris', 'orange', 'bleu'], 1, 2],
#  2: [['jaune', 'noire', 'rouge', 'marron'], 0, 1],
#  3: [['bleu', 'noire', 'vert', 'marron'], 1, 2],
#  4: [['noire', 'rouge', 'marron', 'orange'], 0, 2]}
#
#
# Couleurs proposées : ['bleu', 'jaune', 'vert', 'orange']
# Couleurs bien placées : 1
# Couleurs mal placées : 2
#
#
# {1: [['marron', 'gris', 'orange', 'bleu'], 1, 2],
#  2: [['jaune', 'noire', 'rouge', 'marron'], 0, 1],
#  3: [['bleu', 'noire', 'vert', 'marron'], 1, 2],
#  4: [['noire', 'rouge', 'marron', 'orange'], 0, 2],
#  5: [['bleu', 'jaune', 'vert', 'orange'], 1, 2]}
#
#
# Couleurs proposées : ['marron', 'noire', 'rouge', 'vert']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# {1: [['marron', 'gris', 'orange', 'bleu'], 1, 2],
#  2: [['jaune', 'noire', 'rouge', 'marron'], 0, 1],
#  3: [['bleu', 'noire', 'vert', 'marron'], 1, 2],
#  4: [['noire', 'rouge', 'marron', 'orange'], 0, 2],
#  5: [['bleu', 'jaune', 'vert', 'orange'], 1, 2],
#  6: [['marron', 'noire', 'rouge', 'vert'], 1, 1]}
#
#
# Couleurs proposées : ['gris', 'noire', 'orange', 'marron']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# {1: [['marron', 'gris', 'orange', 'bleu'], 1, 2],
#  2: [['jaune', 'noire', 'rouge', 'marron'], 0, 1],
#  3: [['bleu', 'noire', 'vert', 'marron'], 1, 2],
#  4: [['noire', 'rouge', 'marron', 'orange'], 0, 2],
#  5: [['bleu', 'jaune', 'vert', 'orange'], 1, 2],
#  6: [['marron', 'noire', 'rouge', 'vert'], 1, 1],
#  7: [['gris', 'noire', 'orange', 'marron'], 1, 1]}
#
#
# Couleurs proposées : ['vert', 'bleu', 'gris', 'orange']
# Couleurs bien placées : 0
# Couleurs mal placées : 3
#
#
# {1: [['marron', 'gris', 'orange', 'bleu'], 1, 2],
#  2: [['jaune', 'noire', 'rouge', 'marron'], 0, 1],
#  3: [['bleu', 'noire', 'vert', 'marron'], 1, 2],
#  4: [['noire', 'rouge', 'marron', 'orange'], 0, 2],
#  5: [['bleu', 'jaune', 'vert', 'orange'], 1, 2],
#  6: [['marron', 'noire', 'rouge', 'vert'], 1, 1],
#  7: [['gris', 'noire', 'orange', 'marron'], 1, 1],
#  8: [['vert', 'bleu', 'gris', 'orange'], 0, 3]}
#
#
# Couleurs proposées : ['vert', 'jaune', 'rouge', 'gris']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# {1: [['marron', 'gris', 'orange', 'bleu'], 1, 2],
#  2: [['jaune', 'noire', 'rouge', 'marron'], 0, 1],
#  3: [['bleu', 'noire', 'vert', 'marron'], 1, 2],
#  4: [['noire', 'rouge', 'marron', 'orange'], 0, 2],
#  5: [['bleu', 'jaune', 'vert', 'orange'], 1, 2],
#  6: [['marron', 'noire', 'rouge', 'vert'], 1, 1],
#  7: [['gris', 'noire', 'orange', 'marron'], 1, 1],
#  8: [['vert', 'bleu', 'gris', 'orange'], 0, 3],
#  9: [['vert', 'jaune', 'rouge', 'gris'], 0, 1]}
#
#
# Couleurs proposées : ['vert', 'marron', 'rouge', 'orange']
# Couleurs bien placées : 1
# Couleurs mal placées : 2
#
#
# {1: [['marron', 'gris', 'orange', 'bleu'], 1, 2],
#  2: [['jaune', 'noire', 'rouge', 'marron'], 0, 1],
#  3: [['bleu', 'noire', 'vert', 'marron'], 1, 2],
#  4: [['noire', 'rouge', 'marron', 'orange'], 0, 2],
#  5: [['bleu', 'jaune', 'vert', 'orange'], 1, 2],
#  6: [['marron', 'noire', 'rouge', 'vert'], 1, 1],
#  7: [['gris', 'noire', 'orange', 'marron'], 1, 1],
#  8: [['vert', 'bleu', 'gris', 'orange'], 0, 3],
#  9: [['vert', 'jaune', 'rouge', 'gris'], 0, 1],
#  10: [['vert', 'marron', 'rouge', 'orange'], 1, 2]}
#
#
# Couleurs proposées : ['vert', 'bleu', 'jaune', 'rouge']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['marron', 'gris', 'orange', 'bleu'], 1, 2],
#  2: [['jaune', 'noire', 'rouge', 'marron'], 0, 1],
#  3: [['bleu', 'noire', 'vert', 'marron'], 1, 2],
#  4: [['noire', 'rouge', 'marron', 'orange'], 0, 2],
#  5: [['bleu', 'jaune', 'vert', 'orange'], 1, 2],
#  6: [['marron', 'noire', 'rouge', 'vert'], 1, 1],
#  7: [['gris', 'noire', 'orange', 'marron'], 1, 1],
#  8: [['vert', 'bleu', 'gris', 'orange'], 0, 3],
#  9: [['vert', 'jaune', 'rouge', 'gris'], 0, 1],
#  10: [['vert', 'marron', 'rouge', 'orange'], 1, 2],
#  11: [['vert', 'bleu', 'jaune', 'rouge'], 0, 2]}
#
#
# Couleurs proposées : ['noire', 'gris', 'bleu', 'marron']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['marron', 'gris', 'orange', 'bleu'], 1, 2],
#  2: [['jaune', 'noire', 'rouge', 'marron'], 0, 1],
#  3: [['bleu', 'noire', 'vert', 'marron'], 1, 2],
#  4: [['noire', 'rouge', 'marron', 'orange'], 0, 2],
#  5: [['bleu', 'jaune', 'vert', 'orange'], 1, 2],
#  6: [['marron', 'noire', 'rouge', 'vert'], 1, 1],
#  7: [['gris', 'noire', 'orange', 'marron'], 1, 1],
#  8: [['vert', 'bleu', 'gris', 'orange'], 0, 3],
#  9: [['vert', 'jaune', 'rouge', 'gris'], 0, 1],
#  10: [['vert', 'marron', 'rouge', 'orange'], 1, 2],
#  11: [['vert', 'bleu', 'jaune', 'rouge'], 0, 2],
#  12: [['noire', 'gris', 'bleu', 'marron'], 0, 2]}
#
#
# Partie perdue, t'es mauvais lolo !
# La solution était ['bleu', 'marron', 'orange', 'vert']
#
#
# Nouvelle partie
# Couleurs proposées : ['bleu', 'orange', 'vert', 'rouge']
# Couleurs bien placées : 0
# Couleurs mal placées : 3
#
#
# {1: [['bleu', 'orange', 'vert', 'rouge'], 0, 3]}
#
#
# Couleurs proposées : ['bleu', 'noire', 'gris', 'jaune']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# {1: [['bleu', 'orange', 'vert', 'rouge'], 0, 3],
#  2: [['bleu', 'noire', 'gris', 'jaune'], 0, 1]}
#
#
# Couleurs proposées : ['rouge', 'bleu', 'orange', 'jaune']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# {1: [['bleu', 'orange', 'vert', 'rouge'], 0, 3],
#  2: [['bleu', 'noire', 'gris', 'jaune'], 0, 1],
#  3: [['rouge', 'bleu', 'orange', 'jaune'], 1, 1]}
#
#
# Couleurs proposées : ['bleu', 'orange', 'vert', 'gris']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['bleu', 'orange', 'vert', 'rouge'], 0, 3],
#  2: [['bleu', 'noire', 'gris', 'jaune'], 0, 1],
#  3: [['rouge', 'bleu', 'orange', 'jaune'], 1, 1],
#  4: [['bleu', 'orange', 'vert', 'gris'], 0, 2]}
#
#
# Couleurs proposées : ['noire', 'vert', 'rouge', 'marron']
# Couleurs bien placées : 1
# Couleurs mal placées : 2
#
#
# {1: [['bleu', 'orange', 'vert', 'rouge'], 0, 3],
#  2: [['bleu', 'noire', 'gris', 'jaune'], 0, 1],
#  3: [['rouge', 'bleu', 'orange', 'jaune'], 1, 1],
#  4: [['bleu', 'orange', 'vert', 'gris'], 0, 2],
#  5: [['noire', 'vert', 'rouge', 'marron'], 1, 2]}
#
#
# Couleurs proposées : ['orange', 'jaune', 'rouge', 'marron']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['bleu', 'orange', 'vert', 'rouge'], 0, 3],
#  2: [['bleu', 'noire', 'gris', 'jaune'], 0, 1],
#  3: [['rouge', 'bleu', 'orange', 'jaune'], 1, 1],
#  4: [['bleu', 'orange', 'vert', 'gris'], 0, 2],
#  5: [['noire', 'vert', 'rouge', 'marron'], 1, 2],
#  6: [['orange', 'jaune', 'rouge', 'marron'], 0, 2]}
#
#
# Couleurs proposées : ['bleu', 'orange', 'rouge', 'noire']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['bleu', 'orange', 'vert', 'rouge'], 0, 3],
#  2: [['bleu', 'noire', 'gris', 'jaune'], 0, 1],
#  3: [['rouge', 'bleu', 'orange', 'jaune'], 1, 1],
#  4: [['bleu', 'orange', 'vert', 'gris'], 0, 2],
#  5: [['noire', 'vert', 'rouge', 'marron'], 1, 2],
#  6: [['orange', 'jaune', 'rouge', 'marron'], 0, 2],
#  7: [['bleu', 'orange', 'rouge', 'noire'], 0, 2]}
#
#
# Couleurs proposées : ['orange', 'bleu', 'marron', 'noire']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# {1: [['bleu', 'orange', 'vert', 'rouge'], 0, 3],
#  2: [['bleu', 'noire', 'gris', 'jaune'], 0, 1],
#  3: [['rouge', 'bleu', 'orange', 'jaune'], 1, 1],
#  4: [['bleu', 'orange', 'vert', 'gris'], 0, 2],
#  5: [['noire', 'vert', 'rouge', 'marron'], 1, 2],
#  6: [['orange', 'jaune', 'rouge', 'marron'], 0, 2],
#  7: [['bleu', 'orange', 'rouge', 'noire'], 0, 2],
#  8: [['orange', 'bleu', 'marron', 'noire'], 1, 1]}
#
#
# Couleurs proposées : ['rouge', 'marron', 'noire', 'orange']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# {1: [['bleu', 'orange', 'vert', 'rouge'], 0, 3],
#  2: [['bleu', 'noire', 'gris', 'jaune'], 0, 1],
#  3: [['rouge', 'bleu', 'orange', 'jaune'], 1, 1],
#  4: [['bleu', 'orange', 'vert', 'gris'], 0, 2],
#  5: [['noire', 'vert', 'rouge', 'marron'], 1, 2],
#  6: [['orange', 'jaune', 'rouge', 'marron'], 0, 2],
#  7: [['bleu', 'orange', 'rouge', 'noire'], 0, 2],
#  8: [['orange', 'bleu', 'marron', 'noire'], 1, 1],
#  9: [['rouge', 'marron', 'noire', 'orange'], 1, 1]}
#
#
# Couleurs proposées : ['vert', 'marron', 'noire', 'bleu']
# Couleurs bien placées : 1
# Couleurs mal placées : 2
#
#
# {1: [['bleu', 'orange', 'vert', 'rouge'], 0, 3],
#  2: [['bleu', 'noire', 'gris', 'jaune'], 0, 1],
#  3: [['rouge', 'bleu', 'orange', 'jaune'], 1, 1],
#  4: [['bleu', 'orange', 'vert', 'gris'], 0, 2],
#  5: [['noire', 'vert', 'rouge', 'marron'], 1, 2],
#  6: [['orange', 'jaune', 'rouge', 'marron'], 0, 2],
#  7: [['bleu', 'orange', 'rouge', 'noire'], 0, 2],
#  8: [['orange', 'bleu', 'marron', 'noire'], 1, 1],
#  9: [['rouge', 'marron', 'noire', 'orange'], 1, 1],
#  10: [['vert', 'marron', 'noire', 'bleu'], 1, 2]}
#
#
# Couleurs proposées : ['orange', 'marron', 'noire', 'jaune']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# {1: [['bleu', 'orange', 'vert', 'rouge'], 0, 3],
#  2: [['bleu', 'noire', 'gris', 'jaune'], 0, 1],
#  3: [['rouge', 'bleu', 'orange', 'jaune'], 1, 1],
#  4: [['bleu', 'orange', 'vert', 'gris'], 0, 2],
#  5: [['noire', 'vert', 'rouge', 'marron'], 1, 2],
#  6: [['orange', 'jaune', 'rouge', 'marron'], 0, 2],
#  7: [['bleu', 'orange', 'rouge', 'noire'], 0, 2],
#  8: [['orange', 'bleu', 'marron', 'noire'], 1, 1],
#  9: [['rouge', 'marron', 'noire', 'orange'], 1, 1],
#  10: [['vert', 'marron', 'noire', 'bleu'], 1, 2],
#  11: [['orange', 'marron', 'noire', 'jaune'], 0, 1]}
#
#
# Couleurs proposées : ['gris', 'jaune', 'marron', 'noire']
# Couleurs bien placées : 1
# Couleurs mal placées : 0
#
#
# {1: [['bleu', 'orange', 'vert', 'rouge'], 0, 3],
#  2: [['bleu', 'noire', 'gris', 'jaune'], 0, 1],
#  3: [['rouge', 'bleu', 'orange', 'jaune'], 1, 1],
#  4: [['bleu', 'orange', 'vert', 'gris'], 0, 2],
#  5: [['noire', 'vert', 'rouge', 'marron'], 1, 2],
#  6: [['orange', 'jaune', 'rouge', 'marron'], 0, 2],
#  7: [['bleu', 'orange', 'rouge', 'noire'], 0, 2],
#  8: [['orange', 'bleu', 'marron', 'noire'], 1, 1],
#  9: [['rouge', 'marron', 'noire', 'orange'], 1, 1],
#  10: [['vert', 'marron', 'noire', 'bleu'], 1, 2],
#  11: [['orange', 'marron', 'noire', 'jaune'], 0, 1],
#  12: [['gris', 'jaune', 'marron', 'noire'], 1, 0]}
#
#
# Partie perdue, t'es mauvais lolo !
# La solution était ['rouge', 'vert', 'marron', 'bleu']
#
#
# Nouvelle partie
# Couleurs proposées : ['gris', 'vert', 'rouge', 'marron']
# Couleurs bien placées : 1
# Couleurs mal placées : 0
#
#
# {1: [['gris', 'vert', 'rouge', 'marron'], 1, 0]}
#
#
# ...
#
#
# Nouvelle partie
# Couleurs proposées : ['orange', 'marron', 'jaune', 'gris']
# Couleurs bien placées : 1
# Couleurs mal placées : 2
#
#
# {1: [['orange', 'marron', 'jaune', 'gris'], 1, 2]}
#
#
# Couleurs proposées : ['noire', 'jaune', 'gris', 'marron']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['orange', 'marron', 'jaune', 'gris'], 1, 2],
#  2: [['noire', 'jaune', 'gris', 'marron'], 0, 2]}
#
#
# Couleurs proposées : ['bleu', 'gris', 'jaune', 'vert']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['orange', 'marron', 'jaune', 'gris'], 1, 2],
#  2: [['noire', 'jaune', 'gris', 'marron'], 0, 2],
#  3: [['bleu', 'gris', 'jaune', 'vert'], 0, 2]}
#
#
# Couleurs proposées : ['gris', 'bleu', 'noire', 'marron']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['orange', 'marron', 'jaune', 'gris'], 1, 2],
#  2: [['noire', 'jaune', 'gris', 'marron'], 0, 2],
#  3: [['bleu', 'gris', 'jaune', 'vert'], 0, 2],
#  4: [['gris', 'bleu', 'noire', 'marron'], 0, 2]}
#
#
# Couleurs proposées : ['vert', 'bleu', 'jaune', 'marron']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['orange', 'marron', 'jaune', 'gris'], 1, 2],
#  2: [['noire', 'jaune', 'gris', 'marron'], 0, 2],
#  3: [['bleu', 'gris', 'jaune', 'vert'], 0, 2],
#  4: [['gris', 'bleu', 'noire', 'marron'], 0, 2],
#  5: [['vert', 'bleu', 'jaune', 'marron'], 0, 2]}
#
#
# Couleurs proposées : ['gris', 'bleu', 'vert', 'noire']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# {1: [['orange', 'marron', 'jaune', 'gris'], 1, 2],
#  2: [['noire', 'jaune', 'gris', 'marron'], 0, 2],
#  3: [['bleu', 'gris', 'jaune', 'vert'], 0, 2],
#  4: [['gris', 'bleu', 'noire', 'marron'], 0, 2],
#  5: [['vert', 'bleu', 'jaune', 'marron'], 0, 2],
#  6: [['gris', 'bleu', 'vert', 'noire'], 1, 1]}
#
#
# Couleurs proposées : ['orange', 'noire', 'gris', 'bleu']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['orange', 'marron', 'jaune', 'gris'], 1, 2],
#  2: [['noire', 'jaune', 'gris', 'marron'], 0, 2],
#  3: [['bleu', 'gris', 'jaune', 'vert'], 0, 2],
#  4: [['gris', 'bleu', 'noire', 'marron'], 0, 2],
#  5: [['vert', 'bleu', 'jaune', 'marron'], 0, 2],
#  6: [['gris', 'bleu', 'vert', 'noire'], 1, 1],
#  7: [['orange', 'noire', 'gris', 'bleu'], 0, 2]}
#
#
# Couleurs proposées : ['jaune', 'noire', 'vert', 'rouge']
# Couleurs bien placées : 1
# Couleurs mal placées : 0
#
#
# {1: [['orange', 'marron', 'jaune', 'gris'], 1, 2],
#  2: [['noire', 'jaune', 'gris', 'marron'], 0, 2],
#  3: [['bleu', 'gris', 'jaune', 'vert'], 0, 2],
#  4: [['gris', 'bleu', 'noire', 'marron'], 0, 2],
#  5: [['vert', 'bleu', 'jaune', 'marron'], 0, 2],
#  6: [['gris', 'bleu', 'vert', 'noire'], 1, 1],
#  7: [['orange', 'noire', 'gris', 'bleu'], 0, 2],
#  8: [['jaune', 'noire', 'vert', 'rouge'], 1, 0]}
#
#
# Couleurs proposées : ['noire', 'marron', 'vert', 'gris']
# Couleurs bien placées : 2
# Couleurs mal placées : 1
#
#
# {1: [['orange', 'marron', 'jaune', 'gris'], 1, 2],
#  2: [['noire', 'jaune', 'gris', 'marron'], 0, 2],
#  3: [['bleu', 'gris', 'jaune', 'vert'], 0, 2],
#  4: [['gris', 'bleu', 'noire', 'marron'], 0, 2],
#  5: [['vert', 'bleu', 'jaune', 'marron'], 0, 2],
#  6: [['gris', 'bleu', 'vert', 'noire'], 1, 1],
#  7: [['orange', 'noire', 'gris', 'bleu'], 0, 2],
#  8: [['jaune', 'noire', 'vert', 'rouge'], 1, 0],
#  9: [['noire', 'marron', 'vert', 'gris'], 2, 1]}
#
#
# Couleurs proposées : ['vert', 'jaune', 'noire', 'rouge']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# {1: [['orange', 'marron', 'jaune', 'gris'], 1, 2],
#  2: [['noire', 'jaune', 'gris', 'marron'], 0, 2],
#  3: [['bleu', 'gris', 'jaune', 'vert'], 0, 2],
#  4: [['gris', 'bleu', 'noire', 'marron'], 0, 2],
#  5: [['vert', 'bleu', 'jaune', 'marron'], 0, 2],
#  6: [['gris', 'bleu', 'vert', 'noire'], 1, 1],
#  7: [['orange', 'noire', 'gris', 'bleu'], 0, 2],
#  8: [['jaune', 'noire', 'vert', 'rouge'], 1, 0],
#  9: [['noire', 'marron', 'vert', 'gris'], 2, 1],
#  10: [['vert', 'jaune', 'noire', 'rouge'], 0, 1]}
#
#
# Couleurs proposées : ['noire', 'bleu', 'orange', 'marron']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['orange', 'marron', 'jaune', 'gris'], 1, 2],
#  2: [['noire', 'jaune', 'gris', 'marron'], 0, 2],
#  3: [['bleu', 'gris', 'jaune', 'vert'], 0, 2],
#  4: [['gris', 'bleu', 'noire', 'marron'], 0, 2],
#  5: [['vert', 'bleu', 'jaune', 'marron'], 0, 2],
#  6: [['gris', 'bleu', 'vert', 'noire'], 1, 1],
#  7: [['orange', 'noire', 'gris', 'bleu'], 0, 2],
#  8: [['jaune', 'noire', 'vert', 'rouge'], 1, 0],
#  9: [['noire', 'marron', 'vert', 'gris'], 2, 1],
#  10: [['vert', 'jaune', 'noire', 'rouge'], 0, 1],
#  11: [['noire', 'bleu', 'orange', 'marron'], 0, 2]}
#
#
# Couleurs proposées : ['bleu', 'noire', 'gris', 'rouge']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# {1: [['orange', 'marron', 'jaune', 'gris'], 1, 2],
#  2: [['noire', 'jaune', 'gris', 'marron'], 0, 2],
#  3: [['bleu', 'gris', 'jaune', 'vert'], 0, 2],
#  4: [['gris', 'bleu', 'noire', 'marron'], 0, 2],
#  5: [['vert', 'bleu', 'jaune', 'marron'], 0, 2],
#  6: [['gris', 'bleu', 'vert', 'noire'], 1, 1],
#  7: [['orange', 'noire', 'gris', 'bleu'], 0, 2],
#  8: [['jaune', 'noire', 'vert', 'rouge'], 1, 0],
#  9: [['noire', 'marron', 'vert', 'gris'], 2, 1],
#  10: [['vert', 'jaune', 'noire', 'rouge'], 0, 1],
#  11: [['noire', 'bleu', 'orange', 'marron'], 0, 2],
#  12: [['bleu', 'noire', 'gris', 'rouge'], 0, 1]}
#
#
# Partie perdue, t'es mauvais lolo !
# La solution était ['marron', 'orange', 'vert', 'gris']
#
#
# Nouvelle partie
# Couleurs proposées : ['noire', 'gris', 'vert', 'marron']
# Couleurs bien placées : 0
# Couleurs mal placées : 3
#
#
# {1: [['noire', 'gris', 'vert', 'marron'], 0, 3]}
#
#
# Couleurs proposées : ['orange', 'vert', 'marron', 'bleu']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# {1: [['noire', 'gris', 'vert', 'marron'], 0, 3],
#  2: [['orange', 'vert', 'marron', 'bleu'], 1, 1]}
#
#
# Couleurs proposées : ['marron', 'gris', 'rouge', 'noire']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['noire', 'gris', 'vert', 'marron'], 0, 3],
#  2: [['orange', 'vert', 'marron', 'bleu'], 1, 1],
#  3: [['marron', 'gris', 'rouge', 'noire'], 0, 2]}
#
#
# Couleurs proposées : ['orange', 'vert', 'bleu', 'rouge']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# {1: [['noire', 'gris', 'vert', 'marron'], 0, 3],
#  2: [['orange', 'vert', 'marron', 'bleu'], 1, 1],
#  3: [['marron', 'gris', 'rouge', 'noire'], 0, 2],
#  4: [['orange', 'vert', 'bleu', 'rouge'], 0, 1]}
#
#
# Couleurs proposées : ['bleu', 'rouge', 'orange', 'gris']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# {1: [['noire', 'gris', 'vert', 'marron'], 0, 3],
#  2: [['orange', 'vert', 'marron', 'bleu'], 1, 1],
#  3: [['marron', 'gris', 'rouge', 'noire'], 0, 2],
#  4: [['orange', 'vert', 'bleu', 'rouge'], 0, 1],
#  5: [['bleu', 'rouge', 'orange', 'gris'], 0, 1]}
#
#
# Couleurs proposées : ['orange', 'marron', 'vert', 'jaune']
# Couleurs bien placées : 0
# Couleurs mal placées : 3
#
#
# {1: [['noire', 'gris', 'vert', 'marron'], 0, 3],
#  2: [['orange', 'vert', 'marron', 'bleu'], 1, 1],
#  3: [['marron', 'gris', 'rouge', 'noire'], 0, 2],
#  4: [['orange', 'vert', 'bleu', 'rouge'], 0, 1],
#  5: [['bleu', 'rouge', 'orange', 'gris'], 0, 1],
#  6: [['orange', 'marron', 'vert', 'jaune'], 0, 3]}
#
#
# Couleurs proposées : ['noire', 'bleu', 'orange', 'gris']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# {1: [['noire', 'gris', 'vert', 'marron'], 0, 3],
#  2: [['orange', 'vert', 'marron', 'bleu'], 1, 1],
#  3: [['marron', 'gris', 'rouge', 'noire'], 0, 2],
#  4: [['orange', 'vert', 'bleu', 'rouge'], 0, 1],
#  5: [['bleu', 'rouge', 'orange', 'gris'], 0, 1],
#  6: [['orange', 'marron', 'vert', 'jaune'], 0, 3],
#  7: [['noire', 'bleu', 'orange', 'gris'], 0, 1]}
#
#
# Couleurs proposées : ['marron', 'jaune', 'noire', 'vert']
# Couleurs bien placées : 2
# Couleurs mal placées : 1
#
#
# {1: [['noire', 'gris', 'vert', 'marron'], 0, 3],
#  2: [['orange', 'vert', 'marron', 'bleu'], 1, 1],
#  3: [['marron', 'gris', 'rouge', 'noire'], 0, 2],
#  4: [['orange', 'vert', 'bleu', 'rouge'], 0, 1],
#  5: [['bleu', 'rouge', 'orange', 'gris'], 0, 1],
#  6: [['orange', 'marron', 'vert', 'jaune'], 0, 3],
#  7: [['noire', 'bleu', 'orange', 'gris'], 0, 1],
#  8: [['marron', 'jaune', 'noire', 'vert'], 2, 1]}
#
#
# Couleurs proposées : ['orange', 'noire', 'bleu', 'vert']
# Couleurs bien placées : 1
# Couleurs mal placées : 0
#
#
# {1: [['noire', 'gris', 'vert', 'marron'], 0, 3],
#  2: [['orange', 'vert', 'marron', 'bleu'], 1, 1],
#  3: [['marron', 'gris', 'rouge', 'noire'], 0, 2],
#  4: [['orange', 'vert', 'bleu', 'rouge'], 0, 1],
#  5: [['bleu', 'rouge', 'orange', 'gris'], 0, 1],
#  6: [['orange', 'marron', 'vert', 'jaune'], 0, 3],
#  7: [['noire', 'bleu', 'orange', 'gris'], 0, 1],
#  8: [['marron', 'jaune', 'noire', 'vert'], 2, 1],
#  9: [['orange', 'noire', 'bleu', 'vert'], 1, 0]}
#
#
# Couleurs proposées : ['noire', 'marron', 'vert', 'orange']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['noire', 'gris', 'vert', 'marron'], 0, 3],
#  2: [['orange', 'vert', 'marron', 'bleu'], 1, 1],
#  3: [['marron', 'gris', 'rouge', 'noire'], 0, 2],
#  4: [['orange', 'vert', 'bleu', 'rouge'], 0, 1],
#  5: [['bleu', 'rouge', 'orange', 'gris'], 0, 1],
#  6: [['orange', 'marron', 'vert', 'jaune'], 0, 3],
#  7: [['noire', 'bleu', 'orange', 'gris'], 0, 1],
#  8: [['marron', 'jaune', 'noire', 'vert'], 2, 1],
#  9: [['orange', 'noire', 'bleu', 'vert'], 1, 0],
#  10: [['noire', 'marron', 'vert', 'orange'], 0, 2]}
#
#
# Couleurs proposées : ['noire', 'jaune', 'orange', 'bleu']
# Couleurs bien placées : 1
# Couleurs mal placées : 0
#
#
# {1: [['noire', 'gris', 'vert', 'marron'], 0, 3],
#  2: [['orange', 'vert', 'marron', 'bleu'], 1, 1],
#  3: [['marron', 'gris', 'rouge', 'noire'], 0, 2],
#  4: [['orange', 'vert', 'bleu', 'rouge'], 0, 1],
#  5: [['bleu', 'rouge', 'orange', 'gris'], 0, 1],
#  6: [['orange', 'marron', 'vert', 'jaune'], 0, 3],
#  7: [['noire', 'bleu', 'orange', 'gris'], 0, 1],
#  8: [['marron', 'jaune', 'noire', 'vert'], 2, 1],
#  9: [['orange', 'noire', 'bleu', 'vert'], 1, 0],
#  10: [['noire', 'marron', 'vert', 'orange'], 0, 2],
#  11: [['noire', 'jaune', 'orange', 'bleu'], 1, 0]}
#
#
# Couleurs proposées : ['noire', 'rouge', 'jaune', 'bleu']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# {1: [['noire', 'gris', 'vert', 'marron'], 0, 3],
#  2: [['orange', 'vert', 'marron', 'bleu'], 1, 1],
#  3: [['marron', 'gris', 'rouge', 'noire'], 0, 2],
#  4: [['orange', 'vert', 'bleu', 'rouge'], 0, 1],
#  5: [['bleu', 'rouge', 'orange', 'gris'], 0, 1],
#  6: [['orange', 'marron', 'vert', 'jaune'], 0, 3],
#  7: [['noire', 'bleu', 'orange', 'gris'], 0, 1],
#  8: [['marron', 'jaune', 'noire', 'vert'], 2, 1],
#  9: [['orange', 'noire', 'bleu', 'vert'], 1, 0],
#  10: [['noire', 'marron', 'vert', 'orange'], 0, 2],
#  11: [['noire', 'jaune', 'orange', 'bleu'], 1, 0],
#  12: [['noire', 'rouge', 'jaune', 'bleu'], 0, 1]}
#
#
# Partie perdue, t'es mauvais lolo !
# La solution était ['gris', 'jaune', 'marron', 'vert']
#
#
# Nouvelle partie
# Couleurs proposées : ['gris', 'jaune', 'marron', 'noire']
# Couleurs bien placées : 0
# Couleurs mal placées : 3
#
#
# {1: [['gris', 'jaune', 'marron', 'noire'], 0, 3]}
#
#
# Couleurs proposées : ['rouge', 'vert', 'orange', 'jaune']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# {1: [['gris', 'jaune', 'marron', 'noire'], 0, 3],
#  2: [['rouge', 'vert', 'orange', 'jaune'], 0, 1]}
#
#
# Couleurs proposées : ['rouge', 'orange', 'marron', 'jaune']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# {1: [['gris', 'jaune', 'marron', 'noire'], 0, 3],
#  2: [['rouge', 'vert', 'orange', 'jaune'], 0, 1],
#  3: [['rouge', 'orange', 'marron', 'jaune'], 0, 1]}
#
#
# Couleurs proposées : ['rouge', 'bleu', 'gris', 'orange']
# Couleurs bien placées : 1
# Couleurs mal placées : 0
#
#
# {1: [['gris', 'jaune', 'marron', 'noire'], 0, 3],
#  2: [['rouge', 'vert', 'orange', 'jaune'], 0, 1],
#  3: [['rouge', 'orange', 'marron', 'jaune'], 0, 1],
#  4: [['rouge', 'bleu', 'gris', 'orange'], 1, 0]}
#
#
# Couleurs proposées : ['gris', 'marron', 'orange', 'vert']
# Couleurs bien placées : 0
# Couleurs mal placées : 3
#
#
# {1: [['gris', 'jaune', 'marron', 'noire'], 0, 3],
#  2: [['rouge', 'vert', 'orange', 'jaune'], 0, 1],
#  3: [['rouge', 'orange', 'marron', 'jaune'], 0, 1],
#  4: [['rouge', 'bleu', 'gris', 'orange'], 1, 0],
#  5: [['gris', 'marron', 'orange', 'vert'], 0, 3]}
#
#
# Couleurs proposées : ['rouge', 'bleu', 'orange', 'vert']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# {1: [['gris', 'jaune', 'marron', 'noire'], 0, 3],
#  2: [['rouge', 'vert', 'orange', 'jaune'], 0, 1],
#  3: [['rouge', 'orange', 'marron', 'jaune'], 0, 1],
#  4: [['rouge', 'bleu', 'gris', 'orange'], 1, 0],
#  5: [['gris', 'marron', 'orange', 'vert'], 0, 3],
#  6: [['rouge', 'bleu', 'orange', 'vert'], 0, 1]}
#
#
# Couleurs proposées : ['orange', 'jaune', 'marron', 'rouge']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# {1: [['gris', 'jaune', 'marron', 'noire'], 0, 3],
#  2: [['rouge', 'vert', 'orange', 'jaune'], 0, 1],
#  3: [['rouge', 'orange', 'marron', 'jaune'], 0, 1],
#  4: [['rouge', 'bleu', 'gris', 'orange'], 1, 0],
#  5: [['gris', 'marron', 'orange', 'vert'], 0, 3],
#  6: [['rouge', 'bleu', 'orange', 'vert'], 0, 1],
#  7: [['orange', 'jaune', 'marron', 'rouge'], 0, 1]}
#
#
# Couleurs proposées : ['orange', 'gris', 'bleu', 'vert']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['gris', 'jaune', 'marron', 'noire'], 0, 3],
#  2: [['rouge', 'vert', 'orange', 'jaune'], 0, 1],
#  3: [['rouge', 'orange', 'marron', 'jaune'], 0, 1],
#  4: [['rouge', 'bleu', 'gris', 'orange'], 1, 0],
#  5: [['gris', 'marron', 'orange', 'vert'], 0, 3],
#  6: [['rouge', 'bleu', 'orange', 'vert'], 0, 1],
#  7: [['orange', 'jaune', 'marron', 'rouge'], 0, 1],
#  8: [['orange', 'gris', 'bleu', 'vert'], 0, 2]}
#
#
# Couleurs proposées : ['marron', 'rouge', 'gris', 'jaune']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# {1: [['gris', 'jaune', 'marron', 'noire'], 0, 3],
#  2: [['rouge', 'vert', 'orange', 'jaune'], 0, 1],
#  3: [['rouge', 'orange', 'marron', 'jaune'], 0, 1],
#  4: [['rouge', 'bleu', 'gris', 'orange'], 1, 0],
#  5: [['gris', 'marron', 'orange', 'vert'], 0, 3],
#  6: [['rouge', 'bleu', 'orange', 'vert'], 0, 1],
#  7: [['orange', 'jaune', 'marron', 'rouge'], 0, 1],
#  8: [['orange', 'gris', 'bleu', 'vert'], 0, 2],
#  9: [['marron', 'rouge', 'gris', 'jaune'], 1, 1]}
#
#
# Couleurs proposées : ['rouge', 'orange', 'noire', 'marron']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# {1: [['gris', 'jaune', 'marron', 'noire'], 0, 3],
#  2: [['rouge', 'vert', 'orange', 'jaune'], 0, 1],
#  3: [['rouge', 'orange', 'marron', 'jaune'], 0, 1],
#  4: [['rouge', 'bleu', 'gris', 'orange'], 1, 0],
#  5: [['gris', 'marron', 'orange', 'vert'], 0, 3],
#  6: [['rouge', 'bleu', 'orange', 'vert'], 0, 1],
#  7: [['orange', 'jaune', 'marron', 'rouge'], 0, 1],
#  8: [['orange', 'gris', 'bleu', 'vert'], 0, 2],
#  9: [['marron', 'rouge', 'gris', 'jaune'], 1, 1],
#  10: [['rouge', 'orange', 'noire', 'marron'], 1, 1]}
#
#
# Couleurs proposées : ['bleu', 'orange', 'jaune', 'gris']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# {1: [['gris', 'jaune', 'marron', 'noire'], 0, 3],
#  2: [['rouge', 'vert', 'orange', 'jaune'], 0, 1],
#  3: [['rouge', 'orange', 'marron', 'jaune'], 0, 1],
#  4: [['rouge', 'bleu', 'gris', 'orange'], 1, 0],
#  5: [['gris', 'marron', 'orange', 'vert'], 0, 3],
#  6: [['rouge', 'bleu', 'orange', 'vert'], 0, 1],
#  7: [['orange', 'jaune', 'marron', 'rouge'], 0, 1],
#  8: [['orange', 'gris', 'bleu', 'vert'], 0, 2],
#  9: [['marron', 'rouge', 'gris', 'jaune'], 1, 1],
#  10: [['rouge', 'orange', 'noire', 'marron'], 1, 1],
#  11: [['bleu', 'orange', 'jaune', 'gris'], 0, 1]}
#
#
# Couleurs proposées : ['noire', 'orange', 'vert', 'bleu']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# {1: [['gris', 'jaune', 'marron', 'noire'], 0, 3],
#  2: [['rouge', 'vert', 'orange', 'jaune'], 0, 1],
#  3: [['rouge', 'orange', 'marron', 'jaune'], 0, 1],
#  4: [['rouge', 'bleu', 'gris', 'orange'], 1, 0],
#  5: [['gris', 'marron', 'orange', 'vert'], 0, 3],
#  6: [['rouge', 'bleu', 'orange', 'vert'], 0, 1],
#  7: [['orange', 'jaune', 'marron', 'rouge'], 0, 1],
#  8: [['orange', 'gris', 'bleu', 'vert'], 0, 2],
#  9: [['marron', 'rouge', 'gris', 'jaune'], 1, 1],
#  10: [['rouge', 'orange', 'noire', 'marron'], 1, 1],
#  11: [['bleu', 'orange', 'jaune', 'gris'], 0, 1],
#  12: [['noire', 'orange', 'vert', 'bleu'], 0, 2]}
#
#
# Partie perdue, t'es mauvais lolo !
# La solution était ['vert', 'noire', 'gris', 'marron']

# %%
joujou = IaSmart("Armand", 100)
joujou.lancer_n_parties()
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#
#
# {1: [['gris', 'jaune', 'orange', 'rouge'], 0, 1],
#  2: [['jaune', 'orange', 'gris', 'rouge'], 0, 1],
#  3: [['marron', 'orange', 'rouge', 'jaune'], 0, 2],
#  4: [['rouge', 'orange', 'marron', 'jaune'], 0, 2]}
#
#
# Couleurs proposées : ['orange', 'jaune', 'marron', 'noire']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 507
# Le nombre de combinaisons quon veut enlever : 45
# Le nombre de combinaisons possibles après la suppression : 462
#
#
# {1: [['gris', 'jaune', 'orange', 'rouge'], 0, 1],
#  2: [['jaune', 'orange', 'gris', 'rouge'], 0, 1],
#  3: [['marron', 'orange', 'rouge', 'jaune'], 0, 2],
#  4: [['rouge', 'orange', 'marron', 'jaune'], 0, 2],
#  5: [['orange', 'jaune', 'marron', 'noire'], 0, 1]}
#
#
# Couleurs proposées : ['noire', 'rouge', 'bleu', 'marron']
# Couleurs bien placées : 2
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 462
# Le nombre de combinaisons quon veut enlever : 443
# Le nombre de combinaisons possibles après la suppression : 19
#
#
# {1: [['gris', 'jaune', 'orange', 'rouge'], 0, 1],
#  2: [['jaune', 'orange', 'gris', 'rouge'], 0, 1],
#  3: [['marron', 'orange', 'rouge', 'jaune'], 0, 2],
#  4: [['rouge', 'orange', 'marron', 'jaune'], 0, 2],
#  5: [['orange', 'jaune', 'marron', 'noire'], 0, 1],
#  6: [['noire', 'rouge', 'bleu', 'marron'], 2, 1]}
#
#
# Couleurs proposées : ['noire', 'marron', 'bleu', 'orange']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 19
# Le nombre de combinaisons quon veut enlever : 7
# Le nombre de combinaisons possibles après la suppression : 12
#
#
# {1: [['gris', 'jaune', 'orange', 'rouge'], 0, 1],
#  2: [['jaune', 'orange', 'gris', 'rouge'], 0, 1],
#  3: [['marron', 'orange', 'rouge', 'jaune'], 0, 2],
#  4: [['rouge', 'orange', 'marron', 'jaune'], 0, 2],
#  5: [['orange', 'jaune', 'marron', 'noire'], 0, 1],
#  6: [['noire', 'rouge', 'bleu', 'marron'], 2, 1],
#  7: [['noire', 'marron', 'bleu', 'orange'], 0, 2]}
#
#
# Couleurs proposées : ['noire', 'bleu', 'jaune', 'marron']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 12
# Le nombre de combinaisons quon veut enlever : 1
# Le nombre de combinaisons possibles après la suppression : 11
#
#
# {1: [['gris', 'jaune', 'orange', 'rouge'], 0, 1],
#  2: [['jaune', 'orange', 'gris', 'rouge'], 0, 1],
#  3: [['marron', 'orange', 'rouge', 'jaune'], 0, 2],
#  4: [['rouge', 'orange', 'marron', 'jaune'], 0, 2],
#  5: [['orange', 'jaune', 'marron', 'noire'], 0, 1],
#  6: [['noire', 'rouge', 'bleu', 'marron'], 2, 1],
#  7: [['noire', 'marron', 'bleu', 'orange'], 0, 2],
#  8: [['noire', 'bleu', 'jaune', 'marron'], 1, 1]}
#
#
# Couleurs proposées : ['bleu', 'rouge', 'vert', 'marron']
# Couleurs bien placées : 0
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 11
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 10
#
#
# Partie gagnée, bravo Armand ! Cela t'a pris seulement 9 tours pour y arriver, you're so french !
# La solution était ['bleu', 'rouge', 'vert', 'marron']
#
#
# Nouvelle partie
# Couleurs proposées : ['gris', 'vert', 'rouge', 'bleu']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 1680
# Le nombre de combinaisons quon veut enlever : 1186
# Le nombre de combinaisons possibles après la suppression : 494
#
#
# {1: [['gris', 'vert', 'rouge', 'bleu'], 1, 1]}
#
#
# Couleurs proposées : ['marron', 'gris', 'rouge', 'jaune']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 494
# Le nombre de combinaisons quon veut enlever : 347
# Le nombre de combinaisons possibles après la suppression : 147
#
#
# {1: [['gris', 'vert', 'rouge', 'bleu'], 1, 1],
#  2: [['marron', 'gris', 'rouge', 'jaune'], 1, 1]}
#
#
# Couleurs proposées : ['vert', 'jaune', 'rouge', 'gris']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 147
# Le nombre de combinaisons quon veut enlever : 80
# Le nombre de combinaisons possibles après la suppression : 67
#
#
# {1: [['gris', 'vert', 'rouge', 'bleu'], 1, 1],
#  2: [['marron', 'gris', 'rouge', 'jaune'], 1, 1],
#  3: [['vert', 'jaune', 'rouge', 'gris'], 0, 2]}
#
#
# Couleurs proposées : ['gris', 'bleu', 'rouge', 'jaune']
# Couleurs bien placées : 2
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 67
# Le nombre de combinaisons quon veut enlever : 56
# Le nombre de combinaisons possibles après la suppression : 11
#
#
# {1: [['gris', 'vert', 'rouge', 'bleu'], 1, 1],
#  2: [['marron', 'gris', 'rouge', 'jaune'], 1, 1],
#  3: [['vert', 'jaune', 'rouge', 'gris'], 0, 2],
#  4: [['gris', 'bleu', 'rouge', 'jaune'], 2, 1]}
#
#
# Couleurs proposées : ['gris', 'rouge', 'orange', 'jaune']
# Couleurs bien placées : 2
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 11
# Le nombre de combinaisons quon veut enlever : 10
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# {1: [['gris', 'vert', 'rouge', 'bleu'], 1, 1],
#  2: [['marron', 'gris', 'rouge', 'jaune'], 1, 1],
#  3: [['vert', 'jaune', 'rouge', 'gris'], 0, 2],
#  4: [['gris', 'bleu', 'rouge', 'jaune'], 2, 1],
#  5: [['gris', 'rouge', 'orange', 'jaune'], 2, 1]}
#
#
# Couleurs proposées : ['gris', 'orange', 'bleu', 'jaune']
# Couleurs bien placées : 0
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 1
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# Partie gagnée, bravo Armand ! Cela t'a pris seulement 6 tours pour y arriver, you're so french !
# La solution était ['gris', 'orange', 'bleu', 'jaune']
#
#
# Nouvelle partie
# Couleurs proposées : ['bleu', 'gris', 'orange', 'marron']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 1680
# Le nombre de combinaisons quon veut enlever : 833
# Le nombre de combinaisons possibles après la suppression : 847
#
#
# {1: [['bleu', 'gris', 'orange', 'marron'], 0, 2]}
#
#
# Couleurs proposées : ['rouge', 'jaune', 'bleu', 'orange']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 847
# Le nombre de combinaisons quon veut enlever : 124
# Le nombre de combinaisons possibles après la suppression : 723
#
#
# {1: [['bleu', 'gris', 'orange', 'marron'], 0, 2],
#  2: [['rouge', 'jaune', 'bleu', 'orange'], 0, 1]}
#
#
# Couleurs proposées : ['orange', 'jaune', 'marron', 'vert']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 723
# Le nombre de combinaisons quon veut enlever : 112
# Le nombre de combinaisons possibles après la suppression : 611
#
#
# {1: [['bleu', 'gris', 'orange', 'marron'], 0, 2],
#  2: [['rouge', 'jaune', 'bleu', 'orange'], 0, 1],
#  3: [['orange', 'jaune', 'marron', 'vert'], 0, 1]}
#
#
# Couleurs proposées : ['bleu', 'orange', 'marron', 'rouge']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 611
# Le nombre de combinaisons quon veut enlever : 398
# Le nombre de combinaisons possibles après la suppression : 213
#
#
# {1: [['bleu', 'gris', 'orange', 'marron'], 0, 2],
#  2: [['rouge', 'jaune', 'bleu', 'orange'], 0, 1],
#  3: [['orange', 'jaune', 'marron', 'vert'], 0, 1],
#  4: [['bleu', 'orange', 'marron', 'rouge'], 1, 1]}
#
#
# Couleurs proposées : ['marron', 'vert', 'gris', 'rouge']
# Couleurs bien placées : 1
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 213
# Le nombre de combinaisons quon veut enlever : 193
# Le nombre de combinaisons possibles après la suppression : 20
#
#
# {1: [['bleu', 'gris', 'orange', 'marron'], 0, 2],
#  2: [['rouge', 'jaune', 'bleu', 'orange'], 0, 1],
#  3: [['orange', 'jaune', 'marron', 'vert'], 0, 1],
#  4: [['bleu', 'orange', 'marron', 'rouge'], 1, 1],
#  5: [['marron', 'vert', 'gris', 'rouge'], 1, 2]}
#
#
# Couleurs proposées : ['vert', 'marron', 'gris', 'rouge']
# Couleurs bien placées : 2
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 20
# Le nombre de combinaisons quon veut enlever : 11
# Le nombre de combinaisons possibles après la suppression : 9
#
#
# {1: [['bleu', 'gris', 'orange', 'marron'], 0, 2],
#  2: [['rouge', 'jaune', 'bleu', 'orange'], 0, 1],
#  3: [['orange', 'jaune', 'marron', 'vert'], 0, 1],
#  4: [['bleu', 'orange', 'marron', 'rouge'], 1, 1],
#  5: [['marron', 'vert', 'gris', 'rouge'], 1, 2],
#  6: [['vert', 'marron', 'gris', 'rouge'], 2, 1]}
#
#
# Couleurs proposées : ['gris', 'marron', 'noire', 'rouge']
# Couleurs bien placées : 0
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 9
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 8
#
#
# Partie gagnée, bravo Armand ! Cela t'a pris seulement 7 tours pour y arriver, you're so french !
# La solution était ['gris', 'marron', 'noire', 'rouge']
#
#
# Nouvelle partie
# Couleurs proposées : ['rouge', 'jaune', 'marron', 'orange']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 1680
# Le nombre de combinaisons quon veut enlever : 209
# Le nombre de combinaisons possibles après la suppression : 1471
#
#
# {1: [['rouge', 'jaune', 'marron', 'orange'], 0, 1]}
#
#
# Couleurs proposées : ['jaune', 'marron', 'rouge', 'orange']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 1471
# Le nombre de combinaisons quon veut enlever : 161
# Le nombre de combinaisons possibles après la suppression : 1310
#
#
# {1: [['rouge', 'jaune', 'marron', 'orange'], 0, 1],
#  2: [['jaune', 'marron', 'rouge', 'orange'], 0, 1]}
#
#
# Couleurs proposées : ['noire', 'orange', 'marron', 'bleu']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 1310
# Le nombre de combinaisons quon veut enlever : 641
# Le nombre de combinaisons possibles après la suppression : 669
#
#
# {1: [['rouge', 'jaune', 'marron', 'orange'], 0, 1],
#  2: [['jaune', 'marron', 'rouge', 'orange'], 0, 1],
#  3: [['noire', 'orange', 'marron', 'bleu'], 0, 2]}
#
#
# Couleurs proposées : ['orange', 'gris', 'vert', 'marron']
# Couleurs bien placées : 0
# Couleurs mal placées : 3
#
#
# Le nombre de combinaisons possibles avant la suppression : 669
# Le nombre de combinaisons quon veut enlever : 607
# Le nombre de combinaisons possibles après la suppression : 62
#
#
# {1: [['rouge', 'jaune', 'marron', 'orange'], 0, 1],
#  2: [['jaune', 'marron', 'rouge', 'orange'], 0, 1],
#  3: [['noire', 'orange', 'marron', 'bleu'], 0, 2],
#  4: [['orange', 'gris', 'vert', 'marron'], 0, 3]}
#
#
# Couleurs proposées : ['marron', 'noire', 'gris', 'orange']
# Couleurs bien placées : 1
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 62
# Le nombre de combinaisons quon veut enlever : 46
# Le nombre de combinaisons possibles après la suppression : 16
#
#
# {1: [['rouge', 'jaune', 'marron', 'orange'], 0, 1],
#  2: [['jaune', 'marron', 'rouge', 'orange'], 0, 1],
#  3: [['noire', 'orange', 'marron', 'bleu'], 0, 2],
#  4: [['orange', 'gris', 'vert', 'marron'], 0, 3],
#  5: [['marron', 'noire', 'gris', 'orange'], 1, 2]}
#
#
# Couleurs proposées : ['marron', 'gris', 'orange', 'vert']
# Couleurs bien placées : 1
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 16
# Le nombre de combinaisons quon veut enlever : 9
# Le nombre de combinaisons possibles après la suppression : 7
#
#
# {1: [['rouge', 'jaune', 'marron', 'orange'], 0, 1],
#  2: [['jaune', 'marron', 'rouge', 'orange'], 0, 1],
#  3: [['noire', 'orange', 'marron', 'bleu'], 0, 2],
#  4: [['orange', 'gris', 'vert', 'marron'], 0, 3],
#  5: [['marron', 'noire', 'gris', 'orange'], 1, 2],
#  6: [['marron', 'gris', 'orange', 'vert'], 1, 2]}
#
#
# Couleurs proposées : ['marron', 'orange', 'noire', 'gris']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 7
# Le nombre de combinaisons quon veut enlever : 4
# Le nombre de combinaisons possibles après la suppression : 2
#
#
# {1: [['rouge', 'jaune', 'marron', 'orange'], 0, 1],
#  2: [['jaune', 'marron', 'rouge', 'orange'], 0, 1],
#  3: [['noire', 'orange', 'marron', 'bleu'], 0, 2],
#  4: [['orange', 'gris', 'vert', 'marron'], 0, 3],
#  5: [['marron', 'noire', 'gris', 'orange'], 1, 2],
#  6: [['marron', 'gris', 'orange', 'vert'], 1, 2],
#  7: [['marron', 'orange', 'noire', 'gris'], 3, 0]}
#
#
# Couleurs proposées : ['marron', 'vert', 'noire', 'gris']
# Couleurs bien placées : 0
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 2
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# Partie gagnée, bravo Armand ! Cela t'a pris seulement 8 tours pour y arriver, you're so french !
# La solution était ['marron', 'vert', 'noire', 'gris']
#
#
# Nouvelle partie
# Couleurs proposées : ['orange', 'vert', 'rouge', 'gris']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 1680
# Le nombre de combinaisons quon veut enlever : 833
# Le nombre de combinaisons possibles après la suppression : 847
#
#
# {1: [['orange', 'vert', 'rouge', 'gris'], 0, 2]}
#
#
# Couleurs proposées : ['bleu', 'rouge', 'vert', 'marron']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 847
# Le nombre de combinaisons quon veut enlever : 125
# Le nombre de combinaisons possibles après la suppression : 722
#
#
# {1: [['orange', 'vert', 'rouge', 'gris'], 0, 2],
#  2: [['bleu', 'rouge', 'vert', 'marron'], 0, 1]}
#
#
# Couleurs proposées : ['rouge', 'marron', 'noire', 'orange']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 722
# Le nombre de combinaisons quon veut enlever : 397
# Le nombre de combinaisons possibles après la suppression : 325
#
#
# {1: [['orange', 'vert', 'rouge', 'gris'], 0, 2],
#  2: [['bleu', 'rouge', 'vert', 'marron'], 0, 1],
#  3: [['rouge', 'marron', 'noire', 'orange'], 0, 2]}
#
#
# Couleurs proposées : ['jaune', 'noire', 'vert', 'rouge']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 325
# Le nombre de combinaisons quon veut enlever : 62
# Le nombre de combinaisons possibles après la suppression : 263
#
#
# {1: [['orange', 'vert', 'rouge', 'gris'], 0, 2],
#  2: [['bleu', 'rouge', 'vert', 'marron'], 0, 1],
#  3: [['rouge', 'marron', 'noire', 'orange'], 0, 2],
#  4: [['jaune', 'noire', 'vert', 'rouge'], 0, 1]}
#
#
# Couleurs proposées : ['noire', 'vert', 'gris', 'rouge']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 263
# Le nombre de combinaisons quon veut enlever : 106
# Le nombre de combinaisons possibles après la suppression : 157
#
#
# {1: [['orange', 'vert', 'rouge', 'gris'], 0, 2],
#  2: [['bleu', 'rouge', 'vert', 'marron'], 0, 1],
#  3: [['rouge', 'marron', 'noire', 'orange'], 0, 2],
#  4: [['jaune', 'noire', 'vert', 'rouge'], 0, 1],
#  5: [['noire', 'vert', 'gris', 'rouge'], 0, 2]}
#
#
# Couleurs proposées : ['rouge', 'orange', 'marron', 'vert']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 157
# Le nombre de combinaisons quon veut enlever : 13
# Le nombre de combinaisons possibles après la suppression : 144
#
#
# {1: [['orange', 'vert', 'rouge', 'gris'], 0, 2],
#  2: [['bleu', 'rouge', 'vert', 'marron'], 0, 1],
#  3: [['rouge', 'marron', 'noire', 'orange'], 0, 2],
#  4: [['jaune', 'noire', 'vert', 'rouge'], 0, 1],
#  5: [['noire', 'vert', 'gris', 'rouge'], 0, 2],
#  6: [['rouge', 'orange', 'marron', 'vert'], 0, 1]}
#
#
# Couleurs proposées : ['gris', 'rouge', 'marron', 'vert']
# Couleurs bien placées : 1
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 144
# Le nombre de combinaisons quon veut enlever : 51
# Le nombre de combinaisons possibles après la suppression : 92
#
#
# {1: [['orange', 'vert', 'rouge', 'gris'], 0, 2],
#  2: [['bleu', 'rouge', 'vert', 'marron'], 0, 1],
#  3: [['rouge', 'marron', 'noire', 'orange'], 0, 2],
#  4: [['jaune', 'noire', 'vert', 'rouge'], 0, 1],
#  5: [['noire', 'vert', 'gris', 'rouge'], 0, 2],
#  6: [['rouge', 'orange', 'marron', 'vert'], 0, 1],
#  7: [['gris', 'rouge', 'marron', 'vert'], 1, 0]}
#
#
# Couleurs proposées : ['gris', 'noire', 'jaune', 'rouge']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 92
# Le nombre de combinaisons quon veut enlever : 62
# Le nombre de combinaisons possibles après la suppression : 30
#
#
# {1: [['orange', 'vert', 'rouge', 'gris'], 0, 2],
#  2: [['bleu', 'rouge', 'vert', 'marron'], 0, 1],
#  3: [['rouge', 'marron', 'noire', 'orange'], 0, 2],
#  4: [['jaune', 'noire', 'vert', 'rouge'], 0, 1],
#  5: [['noire', 'vert', 'gris', 'rouge'], 0, 2],
#  6: [['rouge', 'orange', 'marron', 'vert'], 0, 1],
#  7: [['gris', 'rouge', 'marron', 'vert'], 1, 0],
#  8: [['gris', 'noire', 'jaune', 'rouge'], 1, 1]}
#
#
# Couleurs proposées : ['rouge', 'noire', 'marron', 'orange']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 30
# Le nombre de combinaisons quon veut enlever : 11
# Le nombre de combinaisons possibles après la suppression : 19
#
#
# {1: [['orange', 'vert', 'rouge', 'gris'], 0, 2],
#  2: [['bleu', 'rouge', 'vert', 'marron'], 0, 1],
#  3: [['rouge', 'marron', 'noire', 'orange'], 0, 2],
#  4: [['jaune', 'noire', 'vert', 'rouge'], 0, 1],
#  5: [['noire', 'vert', 'gris', 'rouge'], 0, 2],
#  6: [['rouge', 'orange', 'marron', 'vert'], 0, 1],
#  7: [['gris', 'rouge', 'marron', 'vert'], 1, 0],
#  8: [['gris', 'noire', 'jaune', 'rouge'], 1, 1],
#  9: [['rouge', 'noire', 'marron', 'orange'], 0, 2]}
#
#
# Couleurs proposées : ['gris', 'orange', 'rouge', 'vert']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 19
# Le nombre de combinaisons quon veut enlever : 7
# Le nombre de combinaisons possibles après la suppression : 12
#
#
# {1: [['orange', 'vert', 'rouge', 'gris'], 0, 2],
#  2: [['bleu', 'rouge', 'vert', 'marron'], 0, 1],
#  3: [['rouge', 'marron', 'noire', 'orange'], 0, 2],
#  4: [['jaune', 'noire', 'vert', 'rouge'], 0, 1],
#  5: [['noire', 'vert', 'gris', 'rouge'], 0, 2],
#  6: [['rouge', 'orange', 'marron', 'vert'], 0, 1],
#  7: [['gris', 'rouge', 'marron', 'vert'], 1, 0],
#  8: [['gris', 'noire', 'jaune', 'rouge'], 1, 1],
#  9: [['rouge', 'noire', 'marron', 'orange'], 0, 2],
#  10: [['gris', 'orange', 'rouge', 'vert'], 1, 1]}
#
#
# Couleurs proposées : ['gris', 'vert', 'orange', 'noire']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 12
# Le nombre de combinaisons quon veut enlever : 9
# Le nombre de combinaisons possibles après la suppression : 2
#
#
# {1: [['orange', 'vert', 'rouge', 'gris'], 0, 2],
#  2: [['bleu', 'rouge', 'vert', 'marron'], 0, 1],
#  3: [['rouge', 'marron', 'noire', 'orange'], 0, 2],
#  4: [['jaune', 'noire', 'vert', 'rouge'], 0, 1],
#  5: [['noire', 'vert', 'gris', 'rouge'], 0, 2],
#  6: [['rouge', 'orange', 'marron', 'vert'], 0, 1],
#  7: [['gris', 'rouge', 'marron', 'vert'], 1, 0],
#  8: [['gris', 'noire', 'jaune', 'rouge'], 1, 1],
#  9: [['rouge', 'noire', 'marron', 'orange'], 0, 2],
#  10: [['gris', 'orange', 'rouge', 'vert'], 1, 1],
#  11: [['gris', 'vert', 'orange', 'noire'], 3, 0]}
#
#
# Couleurs proposées : ['gris', 'marron', 'orange', 'noire']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 2
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# {1: [['orange', 'vert', 'rouge', 'gris'], 0, 2],
#  2: [['bleu', 'rouge', 'vert', 'marron'], 0, 1],
#  3: [['rouge', 'marron', 'noire', 'orange'], 0, 2],
#  4: [['jaune', 'noire', 'vert', 'rouge'], 0, 1],
#  5: [['noire', 'vert', 'gris', 'rouge'], 0, 2],
#  6: [['rouge', 'orange', 'marron', 'vert'], 0, 1],
#  7: [['gris', 'rouge', 'marron', 'vert'], 1, 0],
#  8: [['gris', 'noire', 'jaune', 'rouge'], 1, 1],
#  9: [['rouge', 'noire', 'marron', 'orange'], 0, 2],
#  10: [['gris', 'orange', 'rouge', 'vert'], 1, 1],
#  11: [['gris', 'vert', 'orange', 'noire'], 3, 0],
#  12: [['gris', 'marron', 'orange', 'noire'], 3, 0]}
#
#
# Partie perdue, t'es mauvais Armand !
# La solution était ['gris', 'bleu', 'orange', 'noire']
#
#
# Nouvelle partie
# Couleurs proposées : ['orange', 'jaune', 'noire', 'vert']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 1680
# Le nombre de combinaisons quon veut enlever : 1186
# Le nombre de combinaisons possibles après la suppression : 494
#
#
# {1: [['orange', 'jaune', 'noire', 'vert'], 1, 1]}
#
#
# Couleurs proposées : ['bleu', 'noire', 'rouge', 'vert']
# Couleurs bien placées : 0
# Couleurs mal placées : 3
#
#
# Le nombre de combinaisons possibles avant la suppression : 494
# Le nombre de combinaisons quon veut enlever : 441
# Le nombre de combinaisons possibles après la suppression : 53
#
#
# {1: [['orange', 'jaune', 'noire', 'vert'], 1, 1],
#  2: [['bleu', 'noire', 'rouge', 'vert'], 0, 3]}
#
#
# Couleurs proposées : ['orange', 'rouge', 'bleu', 'noire']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 53
# Le nombre de combinaisons quon veut enlever : 14
# Le nombre de combinaisons possibles après la suppression : 39
#
#
# {1: [['orange', 'jaune', 'noire', 'vert'], 1, 1],
#  2: [['bleu', 'noire', 'rouge', 'vert'], 0, 3],
#  3: [['orange', 'rouge', 'bleu', 'noire'], 0, 2]}
#
#
# Couleurs proposées : ['noire', 'jaune', 'vert', 'bleu']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 39
# Le nombre de combinaisons quon veut enlever : 6
# Le nombre de combinaisons possibles après la suppression : 33
#
#
# {1: [['orange', 'jaune', 'noire', 'vert'], 1, 1],
#  2: [['bleu', 'noire', 'rouge', 'vert'], 0, 3],
#  3: [['orange', 'rouge', 'bleu', 'noire'], 0, 2],
#  4: [['noire', 'jaune', 'vert', 'bleu'], 0, 2]}
#
#
# Couleurs proposées : ['orange', 'vert', 'noire', 'bleu']
# Couleurs bien placées : 2
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 33
# Le nombre de combinaisons quon veut enlever : 13
# Le nombre de combinaisons possibles après la suppression : 19
#
#
# {1: [['orange', 'jaune', 'noire', 'vert'], 1, 1],
#  2: [['bleu', 'noire', 'rouge', 'vert'], 0, 3],
#  3: [['orange', 'rouge', 'bleu', 'noire'], 0, 2],
#  4: [['noire', 'jaune', 'vert', 'bleu'], 0, 2],
#  5: [['orange', 'vert', 'noire', 'bleu'], 2, 0]}
#
#
# Couleurs proposées : ['bleu', 'vert', 'noire', 'rouge']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 19
# Le nombre de combinaisons quon veut enlever : 14
# Le nombre de combinaisons possibles après la suppression : 4
#
#
# {1: [['orange', 'jaune', 'noire', 'vert'], 1, 1],
#  2: [['bleu', 'noire', 'rouge', 'vert'], 0, 3],
#  3: [['orange', 'rouge', 'bleu', 'noire'], 0, 2],
#  4: [['noire', 'jaune', 'vert', 'bleu'], 0, 2],
#  5: [['orange', 'vert', 'noire', 'bleu'], 2, 0],
#  6: [['bleu', 'vert', 'noire', 'rouge'], 3, 0]}
#
#
# Couleurs proposées : ['marron', 'vert', 'noire', 'rouge']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 4
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 3
#
#
# {1: [['orange', 'jaune', 'noire', 'vert'], 1, 1],
#  2: [['bleu', 'noire', 'rouge', 'vert'], 0, 3],
#  3: [['orange', 'rouge', 'bleu', 'noire'], 0, 2],
#  4: [['noire', 'jaune', 'vert', 'bleu'], 0, 2],
#  5: [['orange', 'vert', 'noire', 'bleu'], 2, 0],
#  6: [['bleu', 'vert', 'noire', 'rouge'], 3, 0],
#  7: [['marron', 'vert', 'noire', 'rouge'], 3, 0]}
#
#
# Couleurs proposées : ['jaune', 'vert', 'noire', 'rouge']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 3
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 2
#
#
# {1: [['orange', 'jaune', 'noire', 'vert'], 1, 1],
#  2: [['bleu', 'noire', 'rouge', 'vert'], 0, 3],
#  3: [['orange', 'rouge', 'bleu', 'noire'], 0, 2],
#  4: [['noire', 'jaune', 'vert', 'bleu'], 0, 2],
#  5: [['orange', 'vert', 'noire', 'bleu'], 2, 0],
#  6: [['bleu', 'vert', 'noire', 'rouge'], 3, 0],
#  7: [['marron', 'vert', 'noire', 'rouge'], 3, 0],
#  8: [['jaune', 'vert', 'noire', 'rouge'], 3, 0]}
#
#
# Couleurs proposées : ['orange', 'vert', 'noire', 'rouge']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 2
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# {1: [['orange', 'jaune', 'noire', 'vert'], 1, 1],
#  2: [['bleu', 'noire', 'rouge', 'vert'], 0, 3],
#  3: [['orange', 'rouge', 'bleu', 'noire'], 0, 2],
#  4: [['noire', 'jaune', 'vert', 'bleu'], 0, 2],
#  5: [['orange', 'vert', 'noire', 'bleu'], 2, 0],
#  6: [['bleu', 'vert', 'noire', 'rouge'], 3, 0],
#  7: [['marron', 'vert', 'noire', 'rouge'], 3, 0],
#  8: [['jaune', 'vert', 'noire', 'rouge'], 3, 0],
#  9: [['orange', 'vert', 'noire', 'rouge'], 3, 0]}
#
#
# Couleurs proposées : ['gris', 'vert', 'noire', 'rouge']
# Couleurs bien placées : 0
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 1
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# Partie gagnée, bravo Armand ! Cela t'a pris seulement 10 tours pour y arriver, you're so french !
# La solution était ['gris', 'vert', 'noire', 'rouge']
#
#
# Nouvelle partie
# Couleurs proposées : ['orange', 'noire', 'jaune', 'gris']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 1680
# Le nombre de combinaisons quon veut enlever : 209
# Le nombre de combinaisons possibles après la suppression : 1471
#
#
# {1: [['orange', 'noire', 'jaune', 'gris'], 0, 1]}
#
#
# Couleurs proposées : ['noire', 'gris', 'bleu', 'vert']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 1471
# Le nombre de combinaisons quon veut enlever : 195
# Le nombre de combinaisons possibles après la suppression : 1276
#
#
# {1: [['orange', 'noire', 'jaune', 'gris'], 0, 1],
#  2: [['noire', 'gris', 'bleu', 'vert'], 0, 1]}
#
#
# Couleurs proposées : ['orange', 'rouge', 'jaune', 'noire']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 1276
# Le nombre de combinaisons quon veut enlever : 605
# Le nombre de combinaisons possibles après la suppression : 671
#
#
# {1: [['orange', 'noire', 'jaune', 'gris'], 0, 1],
#  2: [['noire', 'gris', 'bleu', 'vert'], 0, 1],
#  3: [['orange', 'rouge', 'jaune', 'noire'], 0, 2]}
#
#
# Couleurs proposées : ['gris', 'jaune', 'bleu', 'orange']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 671
# Le nombre de combinaisons quon veut enlever : 339
# Le nombre de combinaisons possibles après la suppression : 332
#
#
# {1: [['orange', 'noire', 'jaune', 'gris'], 0, 1],
#  2: [['noire', 'gris', 'bleu', 'vert'], 0, 1],
#  3: [['orange', 'rouge', 'jaune', 'noire'], 0, 2],
#  4: [['gris', 'jaune', 'bleu', 'orange'], 0, 2]}
#
#
# Couleurs proposées : ['jaune', 'bleu', 'noire', 'marron']
# Couleurs bien placées : 0
# Couleurs mal placées : 3
#
#
# Le nombre de combinaisons possibles avant la suppression : 332
# Le nombre de combinaisons quon veut enlever : 307
# Le nombre de combinaisons possibles après la suppression : 25
#
#
# {1: [['orange', 'noire', 'jaune', 'gris'], 0, 1],
#  2: [['noire', 'gris', 'bleu', 'vert'], 0, 1],
#  3: [['orange', 'rouge', 'jaune', 'noire'], 0, 2],
#  4: [['gris', 'jaune', 'bleu', 'orange'], 0, 2],
#  5: [['jaune', 'bleu', 'noire', 'marron'], 0, 3]}
#
#
# Couleurs proposées : ['marron', 'noire', 'orange', 'jaune']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 25
# Le nombre de combinaisons quon veut enlever : 10
# Le nombre de combinaisons possibles après la suppression : 15
#
#
# {1: [['orange', 'noire', 'jaune', 'gris'], 0, 1],
#  2: [['noire', 'gris', 'bleu', 'vert'], 0, 1],
#  3: [['orange', 'rouge', 'jaune', 'noire'], 0, 2],
#  4: [['gris', 'jaune', 'bleu', 'orange'], 0, 2],
#  5: [['jaune', 'bleu', 'noire', 'marron'], 0, 3],
#  6: [['marron', 'noire', 'orange', 'jaune'], 1, 1]}
#
#
# Couleurs proposées : ['jaune', 'noire', 'marron', 'bleu']
# Couleurs bien placées : 0
# Couleurs mal placées : 3
#
#
# Le nombre de combinaisons possibles avant la suppression : 15
# Le nombre de combinaisons quon veut enlever : 9
# Le nombre de combinaisons possibles après la suppression : 6
#
#
# {1: [['orange', 'noire', 'jaune', 'gris'], 0, 1],
#  2: [['noire', 'gris', 'bleu', 'vert'], 0, 1],
#  3: [['orange', 'rouge', 'jaune', 'noire'], 0, 2],
#  4: [['gris', 'jaune', 'bleu', 'orange'], 0, 2],
#  5: [['jaune', 'bleu', 'noire', 'marron'], 0, 3],
#  6: [['marron', 'noire', 'orange', 'jaune'], 1, 1],
#  7: [['jaune', 'noire', 'marron', 'bleu'], 0, 3]}
#
#
# Couleurs proposées : ['noire', 'marron', 'gris', 'jaune']
# Couleurs bien placées : 2
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 6
# Le nombre de combinaisons quon veut enlever : 1
# Le nombre de combinaisons possibles après la suppression : 4
#
#
# {1: [['orange', 'noire', 'jaune', 'gris'], 0, 1],
#  2: [['noire', 'gris', 'bleu', 'vert'], 0, 1],
#  3: [['orange', 'rouge', 'jaune', 'noire'], 0, 2],
#  4: [['gris', 'jaune', 'bleu', 'orange'], 0, 2],
#  5: [['jaune', 'bleu', 'noire', 'marron'], 0, 3],
#  6: [['marron', 'noire', 'orange', 'jaune'], 1, 1],
#  7: [['jaune', 'noire', 'marron', 'bleu'], 0, 3],
#  8: [['noire', 'marron', 'gris', 'jaune'], 2, 0]}
#
#
# Couleurs proposées : ['noire', 'bleu', 'marron', 'jaune']
# Couleurs bien placées : 1
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 4
# Le nombre de combinaisons quon veut enlever : 1
# Le nombre de combinaisons possibles après la suppression : 3
#
#
# {1: [['orange', 'noire', 'jaune', 'gris'], 0, 1],
#  2: [['noire', 'gris', 'bleu', 'vert'], 0, 1],
#  3: [['orange', 'rouge', 'jaune', 'noire'], 0, 2],
#  4: [['gris', 'jaune', 'bleu', 'orange'], 0, 2],
#  5: [['jaune', 'bleu', 'noire', 'marron'], 0, 3],
#  6: [['marron', 'noire', 'orange', 'jaune'], 1, 1],
#  7: [['jaune', 'noire', 'marron', 'bleu'], 0, 3],
#  8: [['noire', 'marron', 'gris', 'jaune'], 2, 0],
#  9: [['noire', 'bleu', 'marron', 'jaune'], 1, 2]}
#
#
# Couleurs proposées : ['bleu', 'marron', 'rouge', 'jaune']
# Couleurs bien placées : 0
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 3
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 2
#
#
# Partie gagnée, bravo Armand ! Cela t'a pris seulement 10 tours pour y arriver, you're so french !
# La solution était ['bleu', 'marron', 'rouge', 'jaune']
#
#
# Nouvelle partie
# Couleurs proposées : ['gris', 'rouge', 'noire', 'jaune']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 1680
# Le nombre de combinaisons quon veut enlever : 833
# Le nombre de combinaisons possibles après la suppression : 847
#
#
# {1: [['gris', 'rouge', 'noire', 'jaune'], 0, 2]}
#
#
# Couleurs proposées : ['noire', 'marron', 'orange', 'rouge']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 847
# Le nombre de combinaisons quon veut enlever : 126
# Le nombre de combinaisons possibles après la suppression : 721
#
#
# {1: [['gris', 'rouge', 'noire', 'jaune'], 0, 2],
#  2: [['noire', 'marron', 'orange', 'rouge'], 0, 1]}
#
#
# Couleurs proposées : ['noire', 'gris', 'rouge', 'jaune']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 721
# Le nombre de combinaisons quon veut enlever : 440
# Le nombre de combinaisons possibles après la suppression : 281
#
#
# {1: [['gris', 'rouge', 'noire', 'jaune'], 0, 2],
#  2: [['noire', 'marron', 'orange', 'rouge'], 0, 1],
#  3: [['noire', 'gris', 'rouge', 'jaune'], 1, 1]}
#
#
# Couleurs proposées : ['gris', 'jaune', 'rouge', 'orange']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 281
# Le nombre de combinaisons quon veut enlever : 128
# Le nombre de combinaisons possibles après la suppression : 153
#
#
# {1: [['gris', 'rouge', 'noire', 'jaune'], 0, 2],
#  2: [['noire', 'marron', 'orange', 'rouge'], 0, 1],
#  3: [['noire', 'gris', 'rouge', 'jaune'], 1, 1],
#  4: [['gris', 'jaune', 'rouge', 'orange'], 0, 2]}
#
#
# Couleurs proposées : ['noire', 'orange', 'gris', 'jaune']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 153
# Le nombre de combinaisons quon veut enlever : 58
# Le nombre de combinaisons possibles après la suppression : 95
#
#
# {1: [['gris', 'rouge', 'noire', 'jaune'], 0, 2],
#  2: [['noire', 'marron', 'orange', 'rouge'], 0, 1],
#  3: [['noire', 'gris', 'rouge', 'jaune'], 1, 1],
#  4: [['gris', 'jaune', 'rouge', 'orange'], 0, 2],
#  5: [['noire', 'orange', 'gris', 'jaune'], 0, 2]}
#
#
# Couleurs proposées : ['marron', 'gris', 'jaune', 'noire']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 95
# Le nombre de combinaisons quon veut enlever : 85
# Le nombre de combinaisons possibles après la suppression : 9
#
#
# {1: [['gris', 'rouge', 'noire', 'jaune'], 0, 2],
#  2: [['noire', 'marron', 'orange', 'rouge'], 0, 1],
#  3: [['noire', 'gris', 'rouge', 'jaune'], 1, 1],
#  4: [['gris', 'jaune', 'rouge', 'orange'], 0, 2],
#  5: [['noire', 'orange', 'gris', 'jaune'], 0, 2],
#  6: [['marron', 'gris', 'jaune', 'noire'], 3, 0]}
#
#
# Couleurs proposées : ['marron', 'gris', 'jaune', 'orange']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 9
# Le nombre de combinaisons quon veut enlever : 5
# Le nombre de combinaisons possibles après la suppression : 3
#
#
# {1: [['gris', 'rouge', 'noire', 'jaune'], 0, 2],
#  2: [['noire', 'marron', 'orange', 'rouge'], 0, 1],
#  3: [['noire', 'gris', 'rouge', 'jaune'], 1, 1],
#  4: [['gris', 'jaune', 'rouge', 'orange'], 0, 2],
#  5: [['noire', 'orange', 'gris', 'jaune'], 0, 2],
#  6: [['marron', 'gris', 'jaune', 'noire'], 3, 0],
#  7: [['marron', 'gris', 'jaune', 'orange'], 3, 0]}
#
#
# Couleurs proposées : ['marron', 'gris', 'jaune', 'vert']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 3
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 2
#
#
# {1: [['gris', 'rouge', 'noire', 'jaune'], 0, 2],
#  2: [['noire', 'marron', 'orange', 'rouge'], 0, 1],
#  3: [['noire', 'gris', 'rouge', 'jaune'], 1, 1],
#  4: [['gris', 'jaune', 'rouge', 'orange'], 0, 2],
#  5: [['noire', 'orange', 'gris', 'jaune'], 0, 2],
#  6: [['marron', 'gris', 'jaune', 'noire'], 3, 0],
#  7: [['marron', 'gris', 'jaune', 'orange'], 3, 0],
#  8: [['marron', 'gris', 'jaune', 'vert'], 3, 0]}
#
#
# Couleurs proposées : ['marron', 'gris', 'jaune', 'bleu']
# Couleurs bien placées : 0
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 2
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# Partie gagnée, bravo Armand ! Cela t'a pris seulement 9 tours pour y arriver, you're so french !
# La solution était ['marron', 'gris', 'jaune', 'bleu']
#
#
# Nouvelle partie
# Couleurs proposées : ['vert', 'marron', 'rouge', 'jaune']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 1680
# Le nombre de combinaisons quon veut enlever : 833
# Le nombre de combinaisons possibles après la suppression : 847
#
#
# {1: [['vert', 'marron', 'rouge', 'jaune'], 0, 2]}
#
#
# Couleurs proposées : ['rouge', 'noire', 'marron', 'jaune']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 847
# Le nombre de combinaisons quon veut enlever : 70
# Le nombre de combinaisons possibles après la suppression : 777
#
#
# {1: [['vert', 'marron', 'rouge', 'jaune'], 0, 2],
#  2: [['rouge', 'noire', 'marron', 'jaune'], 0, 1]}
#
#
# Couleurs proposées : ['bleu', 'gris', 'jaune', 'vert']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 777
# Le nombre de combinaisons quon veut enlever : 414
# Le nombre de combinaisons possibles après la suppression : 363
#
#
# {1: [['vert', 'marron', 'rouge', 'jaune'], 0, 2],
#  2: [['rouge', 'noire', 'marron', 'jaune'], 0, 1],
#  3: [['bleu', 'gris', 'jaune', 'vert'], 0, 2]}
#
#
# Couleurs proposées : ['vert', 'rouge', 'jaune', 'bleu']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 363
# Le nombre de combinaisons quon veut enlever : 8
# Le nombre de combinaisons possibles après la suppression : 355
#
#
# {1: [['vert', 'marron', 'rouge', 'jaune'], 0, 2],
#  2: [['rouge', 'noire', 'marron', 'jaune'], 0, 1],
#  3: [['bleu', 'gris', 'jaune', 'vert'], 0, 2],
#  4: [['vert', 'rouge', 'jaune', 'bleu'], 0, 1]}
#
#
# Couleurs proposées : ['rouge', 'vert', 'gris', 'marron']
# Couleurs bien placées : 2
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 355
# Le nombre de combinaisons quon veut enlever : 333
# Le nombre de combinaisons possibles après la suppression : 22
#
#
# {1: [['vert', 'marron', 'rouge', 'jaune'], 0, 2],
#  2: [['rouge', 'noire', 'marron', 'jaune'], 0, 1],
#  3: [['bleu', 'gris', 'jaune', 'vert'], 0, 2],
#  4: [['vert', 'rouge', 'jaune', 'bleu'], 0, 1],
#  5: [['rouge', 'vert', 'gris', 'marron'], 2, 1]}
#
#
# Couleurs proposées : ['rouge', 'jaune', 'gris', 'vert']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 22
# Le nombre de combinaisons quon veut enlever : 7
# Le nombre de combinaisons possibles après la suppression : 15
#
#
# {1: [['vert', 'marron', 'rouge', 'jaune'], 0, 2],
#  2: [['rouge', 'noire', 'marron', 'jaune'], 0, 1],
#  3: [['bleu', 'gris', 'jaune', 'vert'], 0, 2],
#  4: [['vert', 'rouge', 'jaune', 'bleu'], 0, 1],
#  5: [['rouge', 'vert', 'gris', 'marron'], 2, 1],
#  6: [['rouge', 'jaune', 'gris', 'vert'], 0, 2]}
#
#
# Couleurs proposées : ['gris', 'vert', 'jaune', 'marron']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 15
# Le nombre de combinaisons quon veut enlever : 10
# Le nombre de combinaisons possibles après la suppression : 4
#
#
# {1: [['vert', 'marron', 'rouge', 'jaune'], 0, 2],
#  2: [['rouge', 'noire', 'marron', 'jaune'], 0, 1],
#  3: [['bleu', 'gris', 'jaune', 'vert'], 0, 2],
#  4: [['vert', 'rouge', 'jaune', 'bleu'], 0, 1],
#  5: [['rouge', 'vert', 'gris', 'marron'], 2, 1],
#  6: [['rouge', 'jaune', 'gris', 'vert'], 0, 2],
#  7: [['gris', 'vert', 'jaune', 'marron'], 3, 0]}
#
#
# Couleurs proposées : ['gris', 'vert', 'noire', 'marron']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 4
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 3
#
#
# {1: [['vert', 'marron', 'rouge', 'jaune'], 0, 2],
#  2: [['rouge', 'noire', 'marron', 'jaune'], 0, 1],
#  3: [['bleu', 'gris', 'jaune', 'vert'], 0, 2],
#  4: [['vert', 'rouge', 'jaune', 'bleu'], 0, 1],
#  5: [['rouge', 'vert', 'gris', 'marron'], 2, 1],
#  6: [['rouge', 'jaune', 'gris', 'vert'], 0, 2],
#  7: [['gris', 'vert', 'jaune', 'marron'], 3, 0],
#  8: [['gris', 'vert', 'noire', 'marron'], 3, 0]}
#
#
# Couleurs proposées : ['gris', 'vert', 'bleu', 'marron']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 3
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 2
#
#
# {1: [['vert', 'marron', 'rouge', 'jaune'], 0, 2],
#  2: [['rouge', 'noire', 'marron', 'jaune'], 0, 1],
#  3: [['bleu', 'gris', 'jaune', 'vert'], 0, 2],
#  4: [['vert', 'rouge', 'jaune', 'bleu'], 0, 1],
#  5: [['rouge', 'vert', 'gris', 'marron'], 2, 1],
#  6: [['rouge', 'jaune', 'gris', 'vert'], 0, 2],
#  7: [['gris', 'vert', 'jaune', 'marron'], 3, 0],
#  8: [['gris', 'vert', 'noire', 'marron'], 3, 0],
#  9: [['gris', 'vert', 'bleu', 'marron'], 3, 0]}
#
#
# Couleurs proposées : ['gris', 'vert', 'rouge', 'marron']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 2
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# {1: [['vert', 'marron', 'rouge', 'jaune'], 0, 2],
#  2: [['rouge', 'noire', 'marron', 'jaune'], 0, 1],
#  3: [['bleu', 'gris', 'jaune', 'vert'], 0, 2],
#  4: [['vert', 'rouge', 'jaune', 'bleu'], 0, 1],
#  5: [['rouge', 'vert', 'gris', 'marron'], 2, 1],
#  6: [['rouge', 'jaune', 'gris', 'vert'], 0, 2],
#  7: [['gris', 'vert', 'jaune', 'marron'], 3, 0],
#  8: [['gris', 'vert', 'noire', 'marron'], 3, 0],
#  9: [['gris', 'vert', 'bleu', 'marron'], 3, 0],
#  10: [['gris', 'vert', 'rouge', 'marron'], 3, 0]}
#
#
# Couleurs proposées : ['gris', 'vert', 'orange', 'marron']
# Couleurs bien placées : 0
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 1
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# Partie gagnée, bravo Armand ! Cela t'a pris seulement 11 tours pour y arriver, you're so french !
# La solution était ['gris', 'vert', 'orange', 'marron']
#
#
# Nouvelle partie
# Couleurs proposées : ['vert', 'noire', 'orange', 'marron']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 1680
# Le nombre de combinaisons quon veut enlever : 1186
# Le nombre de combinaisons possibles après la suppression : 494
#
#
# {1: [['vert', 'noire', 'orange', 'marron'], 1, 1]}
#
#
# Couleurs proposées : ['rouge', 'vert', 'orange', 'bleu']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 494
# Le nombre de combinaisons quon veut enlever : 79
# Le nombre de combinaisons possibles après la suppression : 415
#
#
# {1: [['vert', 'noire', 'orange', 'marron'], 1, 1],
#  2: [['rouge', 'vert', 'orange', 'bleu'], 0, 1]}
#
#
# Couleurs proposées : ['vert', 'orange', 'noire', 'jaune']
# Couleurs bien placées : 1
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 415
# Le nombre de combinaisons quon veut enlever : 370
# Le nombre de combinaisons possibles après la suppression : 45
#
#
# {1: [['vert', 'noire', 'orange', 'marron'], 1, 1],
#  2: [['rouge', 'vert', 'orange', 'bleu'], 0, 1],
#  3: [['vert', 'orange', 'noire', 'jaune'], 1, 2]}
#
#
# Couleurs proposées : ['orange', 'jaune', 'noire', 'marron']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 45
# Le nombre de combinaisons quon veut enlever : 27
# Le nombre de combinaisons possibles après la suppression : 18
#
#
# {1: [['vert', 'noire', 'orange', 'marron'], 1, 1],
#  2: [['rouge', 'vert', 'orange', 'bleu'], 0, 1],
#  3: [['vert', 'orange', 'noire', 'jaune'], 1, 2],
#  4: [['orange', 'jaune', 'noire', 'marron'], 1, 1]}
#
#
# Couleurs proposées : ['noire', 'orange', 'jaune', 'marron']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 18
# Le nombre de combinaisons quon veut enlever : 3
# Le nombre de combinaisons possibles après la suppression : 15
#
#
# {1: [['vert', 'noire', 'orange', 'marron'], 1, 1],
#  2: [['rouge', 'vert', 'orange', 'bleu'], 0, 1],
#  3: [['vert', 'orange', 'noire', 'jaune'], 1, 2],
#  4: [['orange', 'jaune', 'noire', 'marron'], 1, 1],
#  5: [['noire', 'orange', 'jaune', 'marron'], 0, 2]}
#
#
# Couleurs proposées : ['vert', 'jaune', 'gris', 'orange']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 15
# Le nombre de combinaisons quon veut enlever : 9
# Le nombre de combinaisons possibles après la suppression : 5
#
#
# {1: [['vert', 'noire', 'orange', 'marron'], 1, 1],
#  2: [['rouge', 'vert', 'orange', 'bleu'], 0, 1],
#  3: [['vert', 'orange', 'noire', 'jaune'], 1, 2],
#  4: [['orange', 'jaune', 'noire', 'marron'], 1, 1],
#  5: [['noire', 'orange', 'jaune', 'marron'], 0, 2],
#  6: [['vert', 'jaune', 'gris', 'orange'], 3, 0]}
#
#
# Couleurs proposées : ['vert', 'jaune', 'rouge', 'orange']
# Couleurs bien placées : 2
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 5
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 4
#
#
# {1: [['vert', 'noire', 'orange', 'marron'], 1, 1],
#  2: [['rouge', 'vert', 'orange', 'bleu'], 0, 1],
#  3: [['vert', 'orange', 'noire', 'jaune'], 1, 2],
#  4: [['orange', 'jaune', 'noire', 'marron'], 1, 1],
#  5: [['noire', 'orange', 'jaune', 'marron'], 0, 2],
#  6: [['vert', 'jaune', 'gris', 'orange'], 3, 0],
#  7: [['vert', 'jaune', 'rouge', 'orange'], 2, 0]}
#
#
# Couleurs proposées : ['vert', 'jaune', 'bleu', 'orange']
# Couleurs bien placées : 2
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 4
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 3
#
#
# {1: [['vert', 'noire', 'orange', 'marron'], 1, 1],
#  2: [['rouge', 'vert', 'orange', 'bleu'], 0, 1],
#  3: [['vert', 'orange', 'noire', 'jaune'], 1, 2],
#  4: [['orange', 'jaune', 'noire', 'marron'], 1, 1],
#  5: [['noire', 'orange', 'jaune', 'marron'], 0, 2],
#  6: [['vert', 'jaune', 'gris', 'orange'], 3, 0],
#  7: [['vert', 'jaune', 'rouge', 'orange'], 2, 0],
#  8: [['vert', 'jaune', 'bleu', 'orange'], 2, 0]}
#
#
# Couleurs proposées : ['vert', 'jaune', 'noire', 'orange']
# Couleurs bien placées : 2
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 3
# Le nombre de combinaisons quon veut enlever : 2
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# {1: [['vert', 'noire', 'orange', 'marron'], 1, 1],
#  2: [['rouge', 'vert', 'orange', 'bleu'], 0, 1],
#  3: [['vert', 'orange', 'noire', 'jaune'], 1, 2],
#  4: [['orange', 'jaune', 'noire', 'marron'], 1, 1],
#  5: [['noire', 'orange', 'jaune', 'marron'], 0, 2],
#  6: [['vert', 'jaune', 'gris', 'orange'], 3, 0],
#  7: [['vert', 'jaune', 'rouge', 'orange'], 2, 0],
#  8: [['vert', 'jaune', 'bleu', 'orange'], 2, 0],
#  9: [['vert', 'jaune', 'noire', 'orange'], 2, 1]}
#
#
# Couleurs proposées : ['vert', 'jaune', 'gris', 'noire']
# Couleurs bien placées : 0
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 1
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# Partie gagnée, bravo Armand ! Cela t'a pris seulement 10 tours pour y arriver, you're so french !
# La solution était ['vert', 'jaune', 'gris', 'noire']
#
#
# Nouvelle partie
# Couleurs proposées : ['rouge', 'bleu', 'gris', 'noire']
# Couleurs bien placées : 1
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 1680
# Le nombre de combinaisons quon veut enlever : 1522
# Le nombre de combinaisons possibles après la suppression : 158
#
#
# {1: [['rouge', 'bleu', 'gris', 'noire'], 1, 2]}
#
#
# Couleurs proposées : ['noire', 'bleu', 'jaune', 'gris']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 158
# Le nombre de combinaisons quon veut enlever : 101
# Le nombre de combinaisons possibles après la suppression : 57
#
#
# {1: [['rouge', 'bleu', 'gris', 'noire'], 1, 2],
#  2: [['noire', 'bleu', 'jaune', 'gris'], 1, 1]}
#
#
# Couleurs proposées : ['rouge', 'jaune', 'noire', 'gris']
# Couleurs bien placées : 2
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 57
# Le nombre de combinaisons quon veut enlever : 51
# Le nombre de combinaisons possibles après la suppression : 6
#
#
# {1: [['rouge', 'bleu', 'gris', 'noire'], 1, 2],
#  2: [['noire', 'bleu', 'jaune', 'gris'], 1, 1],
# ...
#  2: [['bleu', 'gris', 'marron', 'noire'], 1, 1],
#  3: [['marron', 'orange', 'gris', 'noire'], 0, 2],
#  4: [['rouge', 'gris', 'bleu', 'orange'], 0, 2],
#  5: [['gris', 'rouge', 'marron', 'bleu'], 2, 0]}
#
#
# Couleurs proposées : ['gris', 'vert', 'marron', 'bleu']
# Couleurs bien placées : 2
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 10
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 9
#
#
# {1: [['marron', 'gris', 'orange', 'bleu'], 1, 2],
#  2: [['bleu', 'gris', 'marron', 'noire'], 1, 1],
#  3: [['marron', 'orange', 'gris', 'noire'], 0, 2],
#  4: [['rouge', 'gris', 'bleu', 'orange'], 0, 2],
#  5: [['gris', 'rouge', 'marron', 'bleu'], 2, 0],
#  6: [['gris', 'vert', 'marron', 'bleu'], 2, 0]}
#
#
# Couleurs proposées : ['noire', 'orange', 'marron', 'bleu']
# Couleurs bien placées : 2
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 9
# Le nombre de combinaisons quon veut enlever : 3
# Le nombre de combinaisons possibles après la suppression : 6
#
#
# {1: [['marron', 'gris', 'orange', 'bleu'], 1, 2],
#  2: [['bleu', 'gris', 'marron', 'noire'], 1, 1],
#  3: [['marron', 'orange', 'gris', 'noire'], 0, 2],
#  4: [['rouge', 'gris', 'bleu', 'orange'], 0, 2],
#  5: [['gris', 'rouge', 'marron', 'bleu'], 2, 0],
#  6: [['gris', 'vert', 'marron', 'bleu'], 2, 0],
#  7: [['noire', 'orange', 'marron', 'bleu'], 2, 1]}
#
#
# Couleurs proposées : ['orange', 'noire', 'marron', 'bleu']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 6
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 5
#
#
# {1: [['marron', 'gris', 'orange', 'bleu'], 1, 2],
#  2: [['bleu', 'gris', 'marron', 'noire'], 1, 1],
#  3: [['marron', 'orange', 'gris', 'noire'], 0, 2],
#  4: [['rouge', 'gris', 'bleu', 'orange'], 0, 2],
#  5: [['gris', 'rouge', 'marron', 'bleu'], 2, 0],
#  6: [['gris', 'vert', 'marron', 'bleu'], 2, 0],
#  7: [['noire', 'orange', 'marron', 'bleu'], 2, 1],
#  8: [['orange', 'noire', 'marron', 'bleu'], 3, 0]}
#
#
# Couleurs proposées : ['orange', 'rouge', 'marron', 'bleu']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 5
# Le nombre de combinaisons quon veut enlever : 1
# Le nombre de combinaisons possibles après la suppression : 3
#
#
# {1: [['marron', 'gris', 'orange', 'bleu'], 1, 2],
#  2: [['bleu', 'gris', 'marron', 'noire'], 1, 1],
#  3: [['marron', 'orange', 'gris', 'noire'], 0, 2],
#  4: [['rouge', 'gris', 'bleu', 'orange'], 0, 2],
#  5: [['gris', 'rouge', 'marron', 'bleu'], 2, 0],
#  6: [['gris', 'vert', 'marron', 'bleu'], 2, 0],
#  7: [['noire', 'orange', 'marron', 'bleu'], 2, 1],
#  8: [['orange', 'noire', 'marron', 'bleu'], 3, 0],
#  9: [['orange', 'rouge', 'marron', 'bleu'], 3, 0]}
#
#
# Couleurs proposées : ['orange', 'gris', 'marron', 'bleu']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 3
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 2
#
#
# {1: [['marron', 'gris', 'orange', 'bleu'], 1, 2],
#  2: [['bleu', 'gris', 'marron', 'noire'], 1, 1],
#  3: [['marron', 'orange', 'gris', 'noire'], 0, 2],
#  4: [['rouge', 'gris', 'bleu', 'orange'], 0, 2],
#  5: [['gris', 'rouge', 'marron', 'bleu'], 2, 0],
#  6: [['gris', 'vert', 'marron', 'bleu'], 2, 0],
#  7: [['noire', 'orange', 'marron', 'bleu'], 2, 1],
#  8: [['orange', 'noire', 'marron', 'bleu'], 3, 0],
#  9: [['orange', 'rouge', 'marron', 'bleu'], 3, 0],
#  10: [['orange', 'gris', 'marron', 'bleu'], 3, 0]}
#
#
# Couleurs proposées : ['orange', 'jaune', 'marron', 'bleu']
# Couleurs bien placées : 0
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 2
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# Partie gagnée, bravo Armand ! Cela t'a pris seulement 11 tours pour y arriver, you're so french !
# La solution était ['orange', 'jaune', 'marron', 'bleu']
#
#
# Nouvelle partie
# Couleurs proposées : ['marron', 'orange', 'jaune', 'bleu']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 1680
# Le nombre de combinaisons quon veut enlever : 1186
# Le nombre de combinaisons possibles après la suppression : 494
#
#
# {1: [['marron', 'orange', 'jaune', 'bleu'], 1, 1]}
#
#
# Couleurs proposées : ['orange', 'vert', 'marron', 'bleu']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 494
# Le nombre de combinaisons quon veut enlever : 341
# Le nombre de combinaisons possibles après la suppression : 153
#
#
# {1: [['marron', 'orange', 'jaune', 'bleu'], 1, 1],
#  2: [['orange', 'vert', 'marron', 'bleu'], 1, 1]}
#
#
# Couleurs proposées : ['orange', 'bleu', 'jaune', 'rouge']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 153
# Le nombre de combinaisons quon veut enlever : 62
# Le nombre de combinaisons possibles après la suppression : 91
#
#
# {1: [['marron', 'orange', 'jaune', 'bleu'], 1, 1],
#  2: [['orange', 'vert', 'marron', 'bleu'], 1, 1],
#  3: [['orange', 'bleu', 'jaune', 'rouge'], 0, 2]}
#
#
# Couleurs proposées : ['jaune', 'orange', 'marron', 'noire']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 91
# Le nombre de combinaisons quon veut enlever : 50
# Le nombre de combinaisons possibles après la suppression : 41
#
#
# {1: [['marron', 'orange', 'jaune', 'bleu'], 1, 1],
#  2: [['orange', 'vert', 'marron', 'bleu'], 1, 1],
#  3: [['orange', 'bleu', 'jaune', 'rouge'], 0, 2],
#  4: [['jaune', 'orange', 'marron', 'noire'], 0, 2]}
#
#
# Couleurs proposées : ['bleu', 'vert', 'jaune', 'orange']
# Couleurs bien placées : 0
# Couleurs mal placées : 3
#
#
# Le nombre de combinaisons possibles avant la suppression : 41
# Le nombre de combinaisons quon veut enlever : 28
# Le nombre de combinaisons possibles après la suppression : 13
#
#
# {1: [['marron', 'orange', 'jaune', 'bleu'], 1, 1],
#  2: [['orange', 'vert', 'marron', 'bleu'], 1, 1],
#  3: [['orange', 'bleu', 'jaune', 'rouge'], 0, 2],
#  4: [['jaune', 'orange', 'marron', 'noire'], 0, 2],
#  5: [['bleu', 'vert', 'jaune', 'orange'], 0, 3]}
#
#
# Couleurs proposées : ['vert', 'noire', 'orange', 'bleu']
# Couleurs bien placées : 1
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 13
# Le nombre de combinaisons quon veut enlever : 11
# Le nombre de combinaisons possibles après la suppression : 2
#
#
# {1: [['marron', 'orange', 'jaune', 'bleu'], 1, 1],
#  2: [['orange', 'vert', 'marron', 'bleu'], 1, 1],
#  3: [['orange', 'bleu', 'jaune', 'rouge'], 0, 2],
#  4: [['jaune', 'orange', 'marron', 'noire'], 0, 2],
#  5: [['bleu', 'vert', 'jaune', 'orange'], 0, 3],
#  6: [['vert', 'noire', 'orange', 'bleu'], 1, 2]}
#
#
# Couleurs proposées : ['orange', 'jaune', 'vert', 'bleu']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 2
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# {1: [['marron', 'orange', 'jaune', 'bleu'], 1, 1],
#  2: [['orange', 'vert', 'marron', 'bleu'], 1, 1],
#  3: [['orange', 'bleu', 'jaune', 'rouge'], 0, 2],
#  4: [['jaune', 'orange', 'marron', 'noire'], 0, 2],
#  5: [['bleu', 'vert', 'jaune', 'orange'], 0, 3],
#  6: [['vert', 'noire', 'orange', 'bleu'], 1, 2],
#  7: [['orange', 'jaune', 'vert', 'bleu'], 3, 0]}
#
#
# Couleurs proposées : ['noire', 'jaune', 'vert', 'bleu']
# Couleurs bien placées : 0
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 1
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# Partie gagnée, bravo Armand ! Cela t'a pris seulement 8 tours pour y arriver, you're so french !
# La solution était ['noire', 'jaune', 'vert', 'bleu']
#
#
# Nouvelle partie
# Couleurs proposées : ['marron', 'noire', 'gris', 'bleu']
# Couleurs bien placées : 1
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 1680
# Le nombre de combinaisons quon veut enlever : 1522
# Le nombre de combinaisons possibles après la suppression : 158
#
#
# {1: [['marron', 'noire', 'gris', 'bleu'], 1, 2]}
#
#
# Couleurs proposées : ['marron', 'vert', 'noire', 'gris']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 158
# Le nombre de combinaisons quon veut enlever : 101
# Le nombre de combinaisons possibles après la suppression : 57
#
#
# {1: [['marron', 'noire', 'gris', 'bleu'], 1, 2],
#  2: [['marron', 'vert', 'noire', 'gris'], 1, 1]}
#
#
# Couleurs proposées : ['bleu', 'noire', 'rouge', 'gris']
# Couleurs bien placées : 2
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 57
# Le nombre de combinaisons quon veut enlever : 56
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# {1: [['marron', 'noire', 'gris', 'bleu'], 1, 2],
#  2: [['marron', 'vert', 'noire', 'gris'], 1, 1],
#  3: [['bleu', 'noire', 'rouge', 'gris'], 2, 2]}
#
#
# Couleurs proposées : ['rouge', 'noire', 'bleu', 'gris']
# Couleurs bien placées : 0
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 1
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# Partie gagnée, bravo Armand ! Cela t'a pris seulement 4 tours pour y arriver, you're so french !
# La solution était ['rouge', 'noire', 'bleu', 'gris']
#
#
# Nouvelle partie
# Couleurs proposées : ['rouge', 'vert', 'noire', 'marron']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 1680
# Le nombre de combinaisons quon veut enlever : 209
# Le nombre de combinaisons possibles après la suppression : 1471
#
#
# {1: [['rouge', 'vert', 'noire', 'marron'], 0, 1]}
#
#
# Couleurs proposées : ['jaune', 'bleu', 'rouge', 'marron']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 1471
# Le nombre de combinaisons quon veut enlever : 714
# Le nombre de combinaisons possibles après la suppression : 757
#
#
# {1: [['rouge', 'vert', 'noire', 'marron'], 0, 1],
#  2: [['jaune', 'bleu', 'rouge', 'marron'], 0, 2]}
#
#
# Couleurs proposées : ['rouge', 'noire', 'jaune', 'orange']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 757
# Le nombre de combinaisons quon veut enlever : 103
# Le nombre de combinaisons possibles après la suppression : 654
#
#
# {1: [['rouge', 'vert', 'noire', 'marron'], 0, 1],
#  2: [['jaune', 'bleu', 'rouge', 'marron'], 0, 2],
#  3: [['rouge', 'noire', 'jaune', 'orange'], 0, 1]}
#
#
# Couleurs proposées : ['noire', 'marron', 'vert', 'jaune']
# Couleurs bien placées : 1
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 654
# Le nombre de combinaisons quon veut enlever : 335
# Le nombre de combinaisons possibles après la suppression : 318
#
#
# {1: [['rouge', 'vert', 'noire', 'marron'], 0, 1],
#  2: [['jaune', 'bleu', 'rouge', 'marron'], 0, 2],
#  3: [['rouge', 'noire', 'jaune', 'orange'], 0, 1],
#  4: [['noire', 'marron', 'vert', 'jaune'], 1, 0]}
#
#
# Couleurs proposées : ['noire', 'jaune', 'bleu', 'orange']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 318
# Le nombre de combinaisons quon veut enlever : 164
# Le nombre de combinaisons possibles après la suppression : 154
#
#
# {1: [['rouge', 'vert', 'noire', 'marron'], 0, 1],
#  2: [['jaune', 'bleu', 'rouge', 'marron'], 0, 2],
#  3: [['rouge', 'noire', 'jaune', 'orange'], 0, 1],
#  4: [['noire', 'marron', 'vert', 'jaune'], 1, 0],
#  5: [['noire', 'jaune', 'bleu', 'orange'], 0, 2]}
#
#
# Couleurs proposées : ['jaune', 'marron', 'gris', 'bleu']
# Couleurs bien placées : 2
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 154
# Le nombre de combinaisons quon veut enlever : 146
# Le nombre de combinaisons possibles après la suppression : 8
#
#
# {1: [['rouge', 'vert', 'noire', 'marron'], 0, 1],
#  2: [['jaune', 'bleu', 'rouge', 'marron'], 0, 2],
#  3: [['rouge', 'noire', 'jaune', 'orange'], 0, 1],
#  4: [['noire', 'marron', 'vert', 'jaune'], 1, 0],
#  5: [['noire', 'jaune', 'bleu', 'orange'], 0, 2],
#  6: [['jaune', 'marron', 'gris', 'bleu'], 2, 1]}
#
#
# Couleurs proposées : ['gris', 'marron', 'orange', 'bleu']
# Couleurs bien placées : 0
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 8
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 7
#
#
# Partie gagnée, bravo Armand ! Cela t'a pris seulement 7 tours pour y arriver, you're so french !
# La solution était ['gris', 'marron', 'orange', 'bleu']
#
#
# Nouvelle partie
# Couleurs proposées : ['rouge', 'bleu', 'vert', 'jaune']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 1680
# Le nombre de combinaisons quon veut enlever : 833
# Le nombre de combinaisons possibles après la suppression : 847
#
#
# {1: [['rouge', 'bleu', 'vert', 'jaune'], 0, 2]}
#
#
# Couleurs proposées : ['bleu', 'gris', 'rouge', 'jaune']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 847
# Le nombre de combinaisons quon veut enlever : 564
# Le nombre de combinaisons possibles après la suppression : 283
#
#
# {1: [['rouge', 'bleu', 'vert', 'jaune'], 0, 2],
#  2: [['bleu', 'gris', 'rouge', 'jaune'], 1, 1]}
#
#
# Couleurs proposées : ['bleu', 'vert', 'marron', 'rouge']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 283
# Le nombre de combinaisons quon veut enlever : 149
# Le nombre de combinaisons possibles après la suppression : 134
#
#
# {1: [['rouge', 'bleu', 'vert', 'jaune'], 0, 2],
#  2: [['bleu', 'gris', 'rouge', 'jaune'], 1, 1],
#  3: [['bleu', 'vert', 'marron', 'rouge'], 0, 2]}
#
#
# Couleurs proposées : ['vert', 'bleu', 'rouge', 'noire']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 134
# Le nombre de combinaisons quon veut enlever : 26
# Le nombre de combinaisons possibles après la suppression : 108
#
#
# {1: [['rouge', 'bleu', 'vert', 'jaune'], 0, 2],
#  2: [['bleu', 'gris', 'rouge', 'jaune'], 1, 1],
#  3: [['bleu', 'vert', 'marron', 'rouge'], 0, 2],
#  4: [['vert', 'bleu', 'rouge', 'noire'], 0, 1]}
#
#
# Couleurs proposées : ['jaune', 'marron', 'rouge', 'vert']
# Couleurs bien placées : 1
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 108
# Le nombre de combinaisons quon veut enlever : 93
# Le nombre de combinaisons possibles après la suppression : 15
#
#
# {1: [['rouge', 'bleu', 'vert', 'jaune'], 0, 2],
#  2: [['bleu', 'gris', 'rouge', 'jaune'], 1, 1],
#  3: [['bleu', 'vert', 'marron', 'rouge'], 0, 2],
#  4: [['vert', 'bleu', 'rouge', 'noire'], 0, 1],
#  5: [['jaune', 'marron', 'rouge', 'vert'], 1, 2]}
#
#
# Couleurs proposées : ['marron', 'vert', 'rouge', 'gris']
# Couleurs bien placées : 1
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 15
# Le nombre de combinaisons quon veut enlever : 13
# Le nombre de combinaisons possibles après la suppression : 2
#
#
# {1: [['rouge', 'bleu', 'vert', 'jaune'], 0, 2],
#  2: [['bleu', 'gris', 'rouge', 'jaune'], 1, 1],
#  3: [['bleu', 'vert', 'marron', 'rouge'], 0, 2],
#  4: [['vert', 'bleu', 'rouge', 'noire'], 0, 1],
#  5: [['jaune', 'marron', 'rouge', 'vert'], 1, 2],
#  6: [['marron', 'vert', 'rouge', 'gris'], 1, 2]}
#
#
# Couleurs proposées : ['marron', 'gris', 'jaune', 'vert']
# Couleurs bien placées : 0
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 2
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# Partie gagnée, bravo Armand ! Cela t'a pris seulement 7 tours pour y arriver, you're so french !
# La solution était ['marron', 'gris', 'jaune', 'vert']

# %%
# Nombre et Pourcentage de victoires de l'IaDumb et de l'IaSmart sur 1000 parties.

# Le nombre de victoire de l'IaDumb est très faible et car elle remplit la 
# grille de manière aléatoire. Quand on sait qu'il y a une chance sur 1680 de 
# trouver la combinaison gagnante sans prendre en compte les couleurs bien et mal
# placées, il parait logique que l'IaDumb ne dépasse presque jamais les 1% de 
# réussites sur 1000 parties.

# A contrario, l'IaSmart a un grand nombre de victoire élevé car sa classe est
# dotée de fonctions qui testent des combinaisons en prenant en compte les
# couleurs bien et mal placées tout en éliminant les combinaisons impossibles. 
# L'IaSmart s'approche donc des 100% de réussites avec des résultats avoisinant
# les 96 à 98% en moyenne sur 1000 parties. 

# On notera aussi que l'IaSmart met en moyenne 7 tours pour trouver la bonne 
# solution. Avec l'IaDumb, c'est encore une fois aléatoire.

NB_ESSAI = 1000

md1 = IaDumb(user='francois', n_games= NB_ESSAI)
md1.lancer_n_parties()

md2= IaSmart(user='loic', n_games= NB_ESSAI)
md2.lancer_n_parties()

dumbV = md1.compteur_victoires
dumbD = md1.n_games - md1.compteur_victoires
resultats_Dumb = [dumbV, dumbD]

smartV = md2.compteur_victoires
smartD = md2.n_games - md2.compteur_victoires
resultats_Smart = [smartV, smartD]

moyenneDumb = statistics.mean(md1.tours_necessaires_victoire)
moy_round_dumb = round(moyenneDumb, 2)
moyenneSmart = statistics.mean(md2.tours_necessaires_victoire)
moy_round_smart = round(moyenneSmart, 2)

print(f"IaDumb : {md1.compteur_victoires} victoires sur {md1.n_games} parties - soit un taux de {'{:%}'.format(md1.compteur_victoires / md1.n_games)}")
print(f'Elle met en moyenne {moy_round_dumb} tours pour gagner.')
print(f"IaSmart : {md2.compteur_victoires} victoires sur {md2.n_games} parties - soit un taux de {'{:%}'.format(md2.compteur_victoires / md2.n_games)}")
print(f'Elle met en moyenne {moy_round_smart} tours pour gagner.')

pyplot.figure(figsize = (8, 8))
pyplot.pie(resultats_Dumb, labels = ["Victoires", "Défaites"],
           autopct = lambda x: str(round(x, 2)) + '%',
           pctdistance = 0.7, labeldistance = 1.4,
           shadow = True)
plt.title(f"Pourcentage de victoires en fonction de {NB_ESSAI} parties de l'IaDumb")

pyplot.figure(figsize = (8, 8))
pyplot.pie(resultats_Smart, labels = ['Victoires', 'Défaites'], 
           autopct = lambda x: str(round(x, 2)) + '%',
           pctdistance = 0.7, labeldistance = 1.4,
           shadow = True)
plt.title(f"Pourcentage de victoires en fonction de {NB_ESSAI} parties de l'IaSmart")
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# Couleurs bien placées : 2
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 11
# Le nombre de combinaisons quon veut enlever : 2
# Le nombre de combinaisons possibles après la suppression : 8
#
#
# {1: [['gris', 'vert', 'rouge', 'orange'], 1, 1],
#  2: [['rouge', 'vert', 'marron', 'gris'], 0, 3],
#  3: [['vert', 'marron', 'rouge', 'bleu'], 1, 1],
#  4: [['gris', 'orange', 'rouge', 'vert'], 1, 1],
#  5: [['jaune', 'gris', 'rouge', 'vert'], 0, 2],
#  6: [['gris', 'marron', 'orange', 'rouge'], 2, 0]}
#
#
# Couleurs proposées : ['gris', 'marron', 'jaune', 'rouge']
# Couleurs bien placées : 2
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 8
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 7
#
#
# {1: [['gris', 'vert', 'rouge', 'orange'], 1, 1],
#  2: [['rouge', 'vert', 'marron', 'gris'], 0, 3],
#  3: [['vert', 'marron', 'rouge', 'bleu'], 1, 1],
#  4: [['gris', 'orange', 'rouge', 'vert'], 1, 1],
#  5: [['jaune', 'gris', 'rouge', 'vert'], 0, 2],
#  6: [['gris', 'marron', 'orange', 'rouge'], 2, 0],
#  7: [['gris', 'marron', 'jaune', 'rouge'], 2, 0]}
#
#
# Couleurs proposées : ['gris', 'marron', 'vert', 'bleu']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 7
# Le nombre de combinaisons quon veut enlever : 2
# Le nombre de combinaisons possibles après la suppression : 4
#
#
# {1: [['gris', 'vert', 'rouge', 'orange'], 1, 1],
#  2: [['rouge', 'vert', 'marron', 'gris'], 0, 3],
#  3: [['vert', 'marron', 'rouge', 'bleu'], 1, 1],
#  4: [['gris', 'orange', 'rouge', 'vert'], 1, 1],
#  5: [['jaune', 'gris', 'rouge', 'vert'], 0, 2],
#  6: [['gris', 'marron', 'orange', 'rouge'], 2, 0],
#  7: [['gris', 'marron', 'jaune', 'rouge'], 2, 0],
#  8: [['gris', 'marron', 'vert', 'bleu'], 3, 0]}
#
#
# Couleurs proposées : ['gris', 'marron', 'vert', 'orange']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 4
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 3
#
#
# {1: [['gris', 'vert', 'rouge', 'orange'], 1, 1],
#  2: [['rouge', 'vert', 'marron', 'gris'], 0, 3],
#  3: [['vert', 'marron', 'rouge', 'bleu'], 1, 1],
#  4: [['gris', 'orange', 'rouge', 'vert'], 1, 1],
#  5: [['jaune', 'gris', 'rouge', 'vert'], 0, 2],
#  6: [['gris', 'marron', 'orange', 'rouge'], 2, 0],
#  7: [['gris', 'marron', 'jaune', 'rouge'], 2, 0],
#  8: [['gris', 'marron', 'vert', 'bleu'], 3, 0],
#  9: [['gris', 'marron', 'vert', 'orange'], 3, 0]}
#
#
# Couleurs proposées : ['gris', 'marron', 'vert', 'jaune']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 3
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 2
#
#
# {1: [['gris', 'vert', 'rouge', 'orange'], 1, 1],
#  2: [['rouge', 'vert', 'marron', 'gris'], 0, 3],
#  3: [['vert', 'marron', 'rouge', 'bleu'], 1, 1],
#  4: [['gris', 'orange', 'rouge', 'vert'], 1, 1],
#  5: [['jaune', 'gris', 'rouge', 'vert'], 0, 2],
#  6: [['gris', 'marron', 'orange', 'rouge'], 2, 0],
#  7: [['gris', 'marron', 'jaune', 'rouge'], 2, 0],
#  8: [['gris', 'marron', 'vert', 'bleu'], 3, 0],
#  9: [['gris', 'marron', 'vert', 'orange'], 3, 0],
#  10: [['gris', 'marron', 'vert', 'jaune'], 3, 0]}
#
#
# Couleurs proposées : ['gris', 'marron', 'vert', 'rouge']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 2
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# {1: [['gris', 'vert', 'rouge', 'orange'], 1, 1],
#  2: [['rouge', 'vert', 'marron', 'gris'], 0, 3],
#  3: [['vert', 'marron', 'rouge', 'bleu'], 1, 1],
#  4: [['gris', 'orange', 'rouge', 'vert'], 1, 1],
#  5: [['jaune', 'gris', 'rouge', 'vert'], 0, 2],
#  6: [['gris', 'marron', 'orange', 'rouge'], 2, 0],
#  7: [['gris', 'marron', 'jaune', 'rouge'], 2, 0],
#  8: [['gris', 'marron', 'vert', 'bleu'], 3, 0],
#  9: [['gris', 'marron', 'vert', 'orange'], 3, 0],
#  10: [['gris', 'marron', 'vert', 'jaune'], 3, 0],
#  11: [['gris', 'marron', 'vert', 'rouge'], 3, 0]}
#
#
# Couleurs proposées : ['gris', 'marron', 'vert', 'noire']
# Couleurs bien placées : 0
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 1
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# Partie gagnée, bravo loic ! Cela t'a pris seulement 12 tours pour y arriver, you're so french !
# La solution était ['gris', 'marron', 'vert', 'noire']
#
#
# Nouvelle partie
# Couleurs proposées : ['rouge', 'gris', 'noire', 'bleu']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 1680
# Le nombre de combinaisons quon veut enlever : 833
# Le nombre de combinaisons possibles après la suppression : 847
#
#
# {1: [['rouge', 'gris', 'noire', 'bleu'], 0, 2]}
#
#
# Couleurs proposées : ['gris', 'rouge', 'jaune', 'noire']
# Couleurs bien placées : 1
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 847
# Le nombre de combinaisons quon veut enlever : 731
# Le nombre de combinaisons possibles après la suppression : 116
#
#
# {1: [['rouge', 'gris', 'noire', 'bleu'], 0, 2],
#  2: [['gris', 'rouge', 'jaune', 'noire'], 1, 2]}
#
#
# Couleurs proposées : ['bleu', 'noire', 'jaune', 'gris']
# Couleurs bien placées : 0
# Couleurs mal placées : 3
#
#
# Le nombre de combinaisons possibles avant la suppression : 116
# Le nombre de combinaisons quon veut enlever : 87
# Le nombre de combinaisons possibles après la suppression : 29
#
#
# {1: [['rouge', 'gris', 'noire', 'bleu'], 0, 2],
#  2: [['gris', 'rouge', 'jaune', 'noire'], 1, 2],
#  3: [['bleu', 'noire', 'jaune', 'gris'], 0, 3]}
#
#
# Couleurs proposées : ['jaune', 'gris', 'rouge', 'noire']
# Couleurs bien placées : 1
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 29
# Le nombre de combinaisons quon veut enlever : 17
# Le nombre de combinaisons possibles après la suppression : 12
#
#
# {1: [['rouge', 'gris', 'noire', 'bleu'], 0, 2],
#  2: [['gris', 'rouge', 'jaune', 'noire'], 1, 2],
#  3: [['bleu', 'noire', 'jaune', 'gris'], 0, 3],
#  4: [['jaune', 'gris', 'rouge', 'noire'], 1, 2]}
#
#
# Couleurs proposées : ['vert', 'jaune', 'gris', 'noire']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 12
# Le nombre de combinaisons quon veut enlever : 7
# Le nombre de combinaisons possibles après la suppression : 4
#
#
# {1: [['rouge', 'gris', 'noire', 'bleu'], 0, 2],
#  2: [['gris', 'rouge', 'jaune', 'noire'], 1, 2],
#  3: [['bleu', 'noire', 'jaune', 'gris'], 0, 3],
#  4: [['jaune', 'gris', 'rouge', 'noire'], 1, 2],
#  5: [['vert', 'jaune', 'gris', 'noire'], 3, 0]}
#
#
# Couleurs proposées : ['rouge', 'jaune', 'gris', 'noire']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 4
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 3
#
#
# {1: [['rouge', 'gris', 'noire', 'bleu'], 0, 2],
#  2: [['gris', 'rouge', 'jaune', 'noire'], 1, 2],
#  3: [['bleu', 'noire', 'jaune', 'gris'], 0, 3],
#  4: [['jaune', 'gris', 'rouge', 'noire'], 1, 2],
#  5: [['vert', 'jaune', 'gris', 'noire'], 3, 0],
#  6: [['rouge', 'jaune', 'gris', 'noire'], 3, 0]}
#
#
# Couleurs proposées : ['bleu', 'jaune', 'gris', 'noire']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 3
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 2
#
#
# {1: [['rouge', 'gris', 'noire', 'bleu'], 0, 2],
#  2: [['gris', 'rouge', 'jaune', 'noire'], 1, 2],
#  3: [['bleu', 'noire', 'jaune', 'gris'], 0, 3],
#  4: [['jaune', 'gris', 'rouge', 'noire'], 1, 2],
#  5: [['vert', 'jaune', 'gris', 'noire'], 3, 0],
#  6: [['rouge', 'jaune', 'gris', 'noire'], 3, 0],
#  7: [['bleu', 'jaune', 'gris', 'noire'], 3, 0]}
#
#
# Couleurs proposées : ['marron', 'jaune', 'gris', 'noire']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 2
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# {1: [['rouge', 'gris', 'noire', 'bleu'], 0, 2],
#  2: [['gris', 'rouge', 'jaune', 'noire'], 1, 2],
#  3: [['bleu', 'noire', 'jaune', 'gris'], 0, 3],
#  4: [['jaune', 'gris', 'rouge', 'noire'], 1, 2],
#  5: [['vert', 'jaune', 'gris', 'noire'], 3, 0],
#  6: [['rouge', 'jaune', 'gris', 'noire'], 3, 0],
#  7: [['bleu', 'jaune', 'gris', 'noire'], 3, 0],
#  8: [['marron', 'jaune', 'gris', 'noire'], 3, 0]}
#
#
# Couleurs proposées : ['orange', 'jaune', 'gris', 'noire']
# Couleurs bien placées : 0
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 1
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# Partie gagnée, bravo loic ! Cela t'a pris seulement 9 tours pour y arriver, you're so french !
# La solution était ['orange', 'jaune', 'gris', 'noire']
#
#
# Nouvelle partie
# Couleurs proposées : ['orange', 'marron', 'bleu', 'rouge']
# Couleurs bien placées : 2
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 1680
# Le nombre de combinaisons quon veut enlever : 1537
# Le nombre de combinaisons possibles après la suppression : 142
#
#
# {1: [['orange', 'marron', 'bleu', 'rouge'], 2, 0]}
#
#
# Couleurs proposées : ['rouge', 'marron', 'bleu', 'jaune']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 142
# Le nombre de combinaisons quon veut enlever : 60
# Le nombre de combinaisons possibles après la suppression : 82
#
#
# {1: [['orange', 'marron', 'bleu', 'rouge'], 2, 0],
#  2: [['rouge', 'marron', 'bleu', 'jaune'], 1, 1]}
#
#
# Couleurs proposées : ['bleu', 'marron', 'gris', 'rouge']
# Couleurs bien placées : 1
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 82
# Le nombre de combinaisons quon veut enlever : 65
# Le nombre de combinaisons possibles après la suppression : 17
#
#
# {1: [['orange', 'marron', 'bleu', 'rouge'], 2, 0],
#  2: [['rouge', 'marron', 'bleu', 'jaune'], 1, 1],
#  3: [['bleu', 'marron', 'gris', 'rouge'], 1, 2]}
#
#
# Couleurs proposées : ['vert', 'gris', 'bleu', 'rouge']
# Couleurs bien placées : 0
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 17
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 16
#
#
# Partie gagnée, bravo loic ! Cela t'a pris seulement 4 tours pour y arriver, you're so french !
# La solution était ['vert', 'gris', 'bleu', 'rouge']
#
#
# Nouvelle partie
# Couleurs proposées : ['bleu', 'rouge', 'jaune', 'marron']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 1680
# Le nombre de combinaisons quon veut enlever : 209
# Le nombre de combinaisons possibles après la suppression : 1471
#
#
# {1: [['bleu', 'rouge', 'jaune', 'marron'], 0, 1]}
#
#
# Couleurs proposées : ['noire', 'jaune', 'rouge', 'gris']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 1471
# Le nombre de combinaisons quon veut enlever : 749
# Le nombre de combinaisons possibles après la suppression : 722
#
#
# {1: [['bleu', 'rouge', 'jaune', 'marron'], 0, 1],
#  2: [['noire', 'jaune', 'rouge', 'gris'], 0, 2]}
#
#
# Couleurs proposées : ['marron', 'gris', 'noire', 'jaune']
# Couleurs bien placées : 1
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 722
# Le nombre de combinaisons quon veut enlever : 618
# Le nombre de combinaisons possibles après la suppression : 104
#
#
# {1: [['bleu', 'rouge', 'jaune', 'marron'], 0, 1],
#  2: [['noire', 'jaune', 'rouge', 'gris'], 0, 2],
#  3: [['marron', 'gris', 'noire', 'jaune'], 1, 2]}
#
#
# Couleurs proposées : ['jaune', 'gris', 'orange', 'marron']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 104
# Le nombre de combinaisons quon veut enlever : 33
# Le nombre de combinaisons possibles après la suppression : 71
#
#
# {1: [['bleu', 'rouge', 'jaune', 'marron'], 0, 1],
#  2: [['noire', 'jaune', 'rouge', 'gris'], 0, 2],
#  3: [['marron', 'gris', 'noire', 'jaune'], 1, 2],
#  4: [['jaune', 'gris', 'orange', 'marron'], 0, 2]}
#
#
# Couleurs proposées : ['gris', 'noire', 'rouge', 'jaune']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 71
# Le nombre de combinaisons quon veut enlever : 34
# Le nombre de combinaisons possibles après la suppression : 37
#
#
# {1: [['bleu', 'rouge', 'jaune', 'marron'], 0, 1],
#  2: [['noire', 'jaune', 'rouge', 'gris'], 0, 2],
#  3: [['marron', 'gris', 'noire', 'jaune'], 1, 2],
#  4: [['jaune', 'gris', 'orange', 'marron'], 0, 2],
#  5: [['gris', 'noire', 'rouge', 'jaune'], 1, 1]}
#
#
# Couleurs proposées : ['bleu', 'marron', 'gris', 'jaune']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 37
# Le nombre de combinaisons quon veut enlever : 22
# Le nombre de combinaisons possibles après la suppression : 15
#
#
# {1: [['bleu', 'rouge', 'jaune', 'marron'], 0, 1],
#  2: [['noire', 'jaune', 'rouge', 'gris'], 0, 2],
#  3: [['marron', 'gris', 'noire', 'jaune'], 1, 2],
#  4: [['jaune', 'gris', 'orange', 'marron'], 0, 2],
#  5: [['gris', 'noire', 'rouge', 'jaune'], 1, 1],
#  6: [['bleu', 'marron', 'gris', 'jaune'], 1, 1]}
#
#
# Couleurs proposées : ['gris', 'marron', 'noire', 'bleu']
# Couleurs bien placées : 0
# Couleurs mal placées : 3
#
#
# Le nombre de combinaisons possibles avant la suppression : 15
# Le nombre de combinaisons quon veut enlever : 8
# Le nombre de combinaisons possibles après la suppression : 7
#
#
# {1: [['bleu', 'rouge', 'jaune', 'marron'], 0, 1],
#  2: [['noire', 'jaune', 'rouge', 'gris'], 0, 2],
#  3: [['marron', 'gris', 'noire', 'jaune'], 1, 2],
#  4: [['jaune', 'gris', 'orange', 'marron'], 0, 2],
#  5: [['gris', 'noire', 'rouge', 'jaune'], 1, 1],
#  6: [['bleu', 'marron', 'gris', 'jaune'], 1, 1],
#  7: [['gris', 'marron', 'noire', 'bleu'], 0, 3]}
#
#
# Couleurs proposées : ['noire', 'bleu', 'gris', 'jaune']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 7
# Le nombre de combinaisons quon veut enlever : 1
# Le nombre de combinaisons possibles après la suppression : 6
#
#
# {1: [['bleu', 'rouge', 'jaune', 'marron'], 0, 1],
#  2: [['noire', 'jaune', 'rouge', 'gris'], 0, 2],
#  3: [['marron', 'gris', 'noire', 'jaune'], 1, 2],
#  4: [['jaune', 'gris', 'orange', 'marron'], 0, 2],
#  5: [['gris', 'noire', 'rouge', 'jaune'], 1, 1],
#  6: [['bleu', 'marron', 'gris', 'jaune'], 1, 1],
#  7: [['gris', 'marron', 'noire', 'bleu'], 0, 3],
#  8: [['noire', 'bleu', 'gris', 'jaune'], 1, 1]}
#
#
# Couleurs proposées : ['marron', 'noire', 'gris', 'bleu']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 6
# Le nombre de combinaisons quon veut enlever : 1
# Le nombre de combinaisons possibles après la suppression : 4
#
#
# {1: [['bleu', 'rouge', 'jaune', 'marron'], 0, 1],
#  2: [['noire', 'jaune', 'rouge', 'gris'], 0, 2],
#  3: [['marron', 'gris', 'noire', 'jaune'], 1, 2],
#  4: [['jaune', 'gris', 'orange', 'marron'], 0, 2],
#  5: [['gris', 'noire', 'rouge', 'jaune'], 1, 1],
#  6: [['bleu', 'marron', 'gris', 'jaune'], 1, 1],
#  7: [['gris', 'marron', 'noire', 'bleu'], 0, 3],
#  8: [['noire', 'bleu', 'gris', 'jaune'], 1, 1],
#  9: [['marron', 'noire', 'gris', 'bleu'], 3, 0]}
#
#
# Couleurs proposées : ['marron', 'noire', 'gris', 'rouge']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 4
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 3
#
#
# {1: [['bleu', 'rouge', 'jaune', 'marron'], 0, 1],
#  2: [['noire', 'jaune', 'rouge', 'gris'], 0, 2],
#  3: [['marron', 'gris', 'noire', 'jaune'], 1, 2],
#  4: [['jaune', 'gris', 'orange', 'marron'], 0, 2],
#  5: [['gris', 'noire', 'rouge', 'jaune'], 1, 1],
#  6: [['bleu', 'marron', 'gris', 'jaune'], 1, 1],
#  7: [['gris', 'marron', 'noire', 'bleu'], 0, 3],
#  8: [['noire', 'bleu', 'gris', 'jaune'], 1, 1],
#  9: [['marron', 'noire', 'gris', 'bleu'], 3, 0],
#  10: [['marron', 'noire', 'gris', 'rouge'], 3, 0]}
#
#
# Couleurs proposées : ['marron', 'noire', 'gris', 'orange']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 3
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 2
#
#
# {1: [['bleu', 'rouge', 'jaune', 'marron'], 0, 1],
#  2: [['noire', 'jaune', 'rouge', 'gris'], 0, 2],
#  3: [['marron', 'gris', 'noire', 'jaune'], 1, 2],
#  4: [['jaune', 'gris', 'orange', 'marron'], 0, 2],
#  5: [['gris', 'noire', 'rouge', 'jaune'], 1, 1],
#  6: [['bleu', 'marron', 'gris', 'jaune'], 1, 1],
#  7: [['gris', 'marron', 'noire', 'bleu'], 0, 3],
#  8: [['noire', 'bleu', 'gris', 'jaune'], 1, 1],
#  9: [['marron', 'noire', 'gris', 'bleu'], 3, 0],
#  10: [['marron', 'noire', 'gris', 'rouge'], 3, 0],
#  11: [['marron', 'noire', 'gris', 'orange'], 3, 0]}
#
#
# Couleurs proposées : ['marron', 'noire', 'gris', 'jaune']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 2
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# {1: [['bleu', 'rouge', 'jaune', 'marron'], 0, 1],
#  2: [['noire', 'jaune', 'rouge', 'gris'], 0, 2],
#  3: [['marron', 'gris', 'noire', 'jaune'], 1, 2],
#  4: [['jaune', 'gris', 'orange', 'marron'], 0, 2],
#  5: [['gris', 'noire', 'rouge', 'jaune'], 1, 1],
#  6: [['bleu', 'marron', 'gris', 'jaune'], 1, 1],
#  7: [['gris', 'marron', 'noire', 'bleu'], 0, 3],
#  8: [['noire', 'bleu', 'gris', 'jaune'], 1, 1],
#  9: [['marron', 'noire', 'gris', 'bleu'], 3, 0],
#  10: [['marron', 'noire', 'gris', 'rouge'], 3, 0],
#  11: [['marron', 'noire', 'gris', 'orange'], 3, 0],
#  12: [['marron', 'noire', 'gris', 'jaune'], 3, 0]}
#
#
# Partie perdue, t'es mauvais loic !
# La solution était ['marron', 'noire', 'gris', 'vert']
#
#
# Nouvelle partie
# Couleurs proposées : ['jaune', 'rouge', 'vert', 'noire']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 1680
# Le nombre de combinaisons quon veut enlever : 833
# Le nombre de combinaisons possibles après la suppression : 847
#
#
# {1: [['jaune', 'rouge', 'vert', 'noire'], 0, 2]}
#
#
# Couleurs proposées : ['orange', 'noire', 'gris', 'rouge']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 847
# Le nombre de combinaisons quon veut enlever : 582
# Le nombre de combinaisons possibles après la suppression : 265
#
#
# {1: [['jaune', 'rouge', 'vert', 'noire'], 0, 2],
#  2: [['orange', 'noire', 'gris', 'rouge'], 1, 1]}
#
#
# Couleurs proposées : ['rouge', 'noire', 'marron', 'gris']
# Couleurs bien placées : 1
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 265
# Le nombre de combinaisons quon veut enlever : 229
# Le nombre de combinaisons possibles après la suppression : 36
#
#
# {1: [['jaune', 'rouge', 'vert', 'noire'], 0, 2],
#  2: [['orange', 'noire', 'gris', 'rouge'], 1, 1],
#  3: [['rouge', 'noire', 'marron', 'gris'], 1, 2]}
#
#
# Couleurs proposées : ['rouge', 'jaune', 'gris', 'noire']
# Couleurs bien placées : 0
# Couleurs mal placées : 3
#
#
# Le nombre de combinaisons possibles avant la suppression : 36
# Le nombre de combinaisons quon veut enlever : 21
# Le nombre de combinaisons possibles après la suppression : 15
#
#
# {1: [['jaune', 'rouge', 'vert', 'noire'], 0, 2],
#  2: [['orange', 'noire', 'gris', 'rouge'], 1, 1],
#  3: [['rouge', 'noire', 'marron', 'gris'], 1, 2],
#  4: [['rouge', 'jaune', 'gris', 'noire'], 0, 3]}
#
#
# Couleurs proposées : ['gris', 'noire', 'rouge', 'bleu']
# Couleurs bien placées : 2
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 15
# Le nombre de combinaisons quon veut enlever : 1
# Le nombre de combinaisons possibles après la suppression : 13
#
#
# {1: [['jaune', 'rouge', 'vert', 'noire'], 0, 2],
#  2: [['orange', 'noire', 'gris', 'rouge'], 1, 1],
#  3: [['rouge', 'noire', 'marron', 'gris'], 1, 2],
#  4: [['rouge', 'jaune', 'gris', 'noire'], 0, 3],
#  5: [['gris', 'noire', 'rouge', 'bleu'], 2, 0]}
#
#
# Couleurs proposées : ['gris', 'noire', 'bleu', 'rouge']
# Couleurs bien placées : 2
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 13
# Le nombre de combinaisons quon veut enlever : 3
# Le nombre de combinaisons possibles après la suppression : 9
#
#
# {1: [['jaune', 'rouge', 'vert', 'noire'], 0, 2],
#  2: [['orange', 'noire', 'gris', 'rouge'], 1, 1],
#  3: [['rouge', 'noire', 'marron', 'gris'], 1, 2],
#  4: [['rouge', 'jaune', 'gris', 'noire'], 0, 3],
#  5: [['gris', 'noire', 'rouge', 'bleu'], 2, 0],
#  6: [['gris', 'noire', 'bleu', 'rouge'], 2, 0]}
#
#
# Couleurs proposées : ['gris', 'noire', 'rouge', 'vert']
# Couleurs bien placées : 2
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 9
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 8
#
#
# {1: [['jaune', 'rouge', 'vert', 'noire'], 0, 2],
#  2: [['orange', 'noire', 'gris', 'rouge'], 1, 1],
#  3: [['rouge', 'noire', 'marron', 'gris'], 1, 2],
#  4: [['rouge', 'jaune', 'gris', 'noire'], 0, 3],
#  5: [['gris', 'noire', 'rouge', 'bleu'], 2, 0],
#  6: [['gris', 'noire', 'bleu', 'rouge'], 2, 0],
#  7: [['gris', 'noire', 'rouge', 'vert'], 2, 0]}
#
#
# Couleurs proposées : ['gris', 'noire', 'rouge', 'orange']
# Couleurs bien placées : 2
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 8
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 7
#
#
# {1: [['jaune', 'rouge', 'vert', 'noire'], 0, 2],
#  2: [['orange', 'noire', 'gris', 'rouge'], 1, 1],
#  3: [['rouge', 'noire', 'marron', 'gris'], 1, 2],
#  4: [['rouge', 'jaune', 'gris', 'noire'], 0, 3],
#  5: [['gris', 'noire', 'rouge', 'bleu'], 2, 0],
#  6: [['gris', 'noire', 'bleu', 'rouge'], 2, 0],
#  7: [['gris', 'noire', 'rouge', 'vert'], 2, 0],
#  8: [['gris', 'noire', 'rouge', 'orange'], 2, 0]}
#
#
# Couleurs proposées : ['gris', 'noire', 'jaune', 'rouge']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 7
# Le nombre de combinaisons quon veut enlever : 2
# Le nombre de combinaisons possibles après la suppression : 4
#
#
# {1: [['jaune', 'rouge', 'vert', 'noire'], 0, 2],
#  2: [['orange', 'noire', 'gris', 'rouge'], 1, 1],
#  3: [['rouge', 'noire', 'marron', 'gris'], 1, 2],
#  4: [['rouge', 'jaune', 'gris', 'noire'], 0, 3],
#  5: [['gris', 'noire', 'rouge', 'bleu'], 2, 0],
#  6: [['gris', 'noire', 'bleu', 'rouge'], 2, 0],
#  7: [['gris', 'noire', 'rouge', 'vert'], 2, 0],
#  8: [['gris', 'noire', 'rouge', 'orange'], 2, 0],
#  9: [['gris', 'noire', 'jaune', 'rouge'], 3, 0]}
#
#
# Couleurs proposées : ['gris', 'noire', 'orange', 'rouge']
# Couleurs bien placées : 2
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 4
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 3
#
#
# {1: [['jaune', 'rouge', 'vert', 'noire'], 0, 2],
#  2: [['orange', 'noire', 'gris', 'rouge'], 1, 1],
#  3: [['rouge', 'noire', 'marron', 'gris'], 1, 2],
#  4: [['rouge', 'jaune', 'gris', 'noire'], 0, 3],
#  5: [['gris', 'noire', 'rouge', 'bleu'], 2, 0],
#  6: [['gris', 'noire', 'bleu', 'rouge'], 2, 0],
#  7: [['gris', 'noire', 'rouge', 'vert'], 2, 0],
#  8: [['gris', 'noire', 'rouge', 'orange'], 2, 0],
#  9: [['gris', 'noire', 'jaune', 'rouge'], 3, 0],
#  10: [['gris', 'noire', 'orange', 'rouge'], 2, 0]}
#
#
# Couleurs proposées : ['gris', 'noire', 'marron', 'rouge']
# Couleurs bien placées : 2
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 3
# Le nombre de combinaisons quon veut enlever : 2
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# {1: [['jaune', 'rouge', 'vert', 'noire'], 0, 2],
#  2: [['orange', 'noire', 'gris', 'rouge'], 1, 1],
#  3: [['rouge', 'noire', 'marron', 'gris'], 1, 2],
#  4: [['rouge', 'jaune', 'gris', 'noire'], 0, 3],
#  5: [['gris', 'noire', 'rouge', 'bleu'], 2, 0],
#  6: [['gris', 'noire', 'bleu', 'rouge'], 2, 0],
#  7: [['gris', 'noire', 'rouge', 'vert'], 2, 0],
#  8: [['gris', 'noire', 'rouge', 'orange'], 2, 0],
#  9: [['gris', 'noire', 'jaune', 'rouge'], 3, 0],
#  10: [['gris', 'noire', 'orange', 'rouge'], 2, 0],
#  11: [['gris', 'noire', 'marron', 'rouge'], 2, 1]}
#
#
# Couleurs proposées : ['gris', 'noire', 'jaune', 'marron']
# Couleurs bien placées : 0
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 1
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# Partie gagnée, bravo loic ! Cela t'a pris seulement 12 tours pour y arriver, you're so french !
# La solution était ['gris', 'noire', 'jaune', 'marron']
#
#
# Nouvelle partie
# Couleurs proposées : ['noire', 'bleu', 'vert', 'jaune']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 1680
# Le nombre de combinaisons quon veut enlever : 1186
# Le nombre de combinaisons possibles après la suppression : 494
#
#
# {1: [['noire', 'bleu', 'vert', 'jaune'], 1, 1]}
#
#
# Couleurs proposées : ['jaune', 'bleu', 'orange', 'gris']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 494
# Le nombre de combinaisons quon veut enlever : 79
# Le nombre de combinaisons possibles après la suppression : 415
#
#
# {1: [['noire', 'bleu', 'vert', 'jaune'], 1, 1],
#  2: [['jaune', 'bleu', 'orange', 'gris'], 0, 1]}
#
#
# Couleurs proposées : ['rouge', 'vert', 'orange', 'jaune']
# Couleurs bien placées : 0
# Couleurs mal placées : 3
#
#
# Le nombre de combinaisons possibles avant la suppression : 415
# Le nombre de combinaisons quon veut enlever : 369
# Le nombre de combinaisons possibles après la suppression : 46
#
#
# {1: [['noire', 'bleu', 'vert', 'jaune'], 1, 1],
#  2: [['jaune', 'bleu', 'orange', 'gris'], 0, 1],
#  3: [['rouge', 'vert', 'orange', 'jaune'], 0, 3]}
#
#
# Couleurs proposées : ['noire', 'jaune', 'vert', 'rouge']
# Couleurs bien placées : 2
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 46
# Le nombre de combinaisons quon veut enlever : 38
# Le nombre de combinaisons possibles après la suppression : 8
#
#
# {1: [['noire', 'bleu', 'vert', 'jaune'], 1, 1],
#  2: [['jaune', 'bleu', 'orange', 'gris'], 0, 1],
#  3: [['rouge', 'vert', 'orange', 'jaune'], 0, 3],
#  4: [['noire', 'jaune', 'vert', 'rouge'], 2, 1]}
#
#
# Couleurs proposées : ['noire', 'jaune', 'rouge', 'orange']
# Couleurs bien placées : 0
# Couleurs mal placées : 3
#
#
# Le nombre de combinaisons possibles avant la suppression : 8
# Le nombre de combinaisons quon veut enlever : 5
# Le nombre de combinaisons possibles après la suppression : 3
#
#
# {1: [['noire', 'bleu', 'vert', 'jaune'], 1, 1],
#  2: [['jaune', 'bleu', 'orange', 'gris'], 0, 1],
#  3: [['rouge', 'vert', 'orange', 'jaune'], 0, 3],
#  4: [['noire', 'jaune', 'vert', 'rouge'], 2, 1],
#  5: [['noire', 'jaune', 'rouge', 'orange'], 0, 3]}
#
#
# Couleurs proposées : ['jaune', 'orange', 'vert', 'rouge']
# Couleurs bien placées : 2
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 3
# Le nombre de combinaisons quon veut enlever : 1
# Le nombre de combinaisons possibles après la suppression : 2
#
#
# {1: [['noire', 'bleu', 'vert', 'jaune'], 1, 1],
#  2: [['jaune', 'bleu', 'orange', 'gris'], 0, 1],
#  3: [['rouge', 'vert', 'orange', 'jaune'], 0, 3],
#  4: [['noire', 'jaune', 'vert', 'rouge'], 2, 1],
#  5: [['noire', 'jaune', 'rouge', 'orange'], 0, 3],
#  6: [['jaune', 'orange', 'vert', 'rouge'], 2, 1]}
#
#
# Couleurs proposées : ['noire', 'orange', 'jaune', 'rouge']
# Couleurs bien placées : 1
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 2
# Le nombre de combinaisons quon veut enlever : 1
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# {1: [['noire', 'bleu', 'vert', 'jaune'], 1, 1],
#  2: [['jaune', 'bleu', 'orange', 'gris'], 0, 1],
#  3: [['rouge', 'vert', 'orange', 'jaune'], 0, 3],
#  4: [['noire', 'jaune', 'vert', 'rouge'], 2, 1],
#  5: [['noire', 'jaune', 'rouge', 'orange'], 0, 3],
#  6: [['jaune', 'orange', 'vert', 'rouge'], 2, 1],
#  7: [['noire', 'orange', 'jaune', 'rouge'], 1, 2]}
#
#
# Couleurs proposées : ['orange', 'noire', 'vert', 'rouge']
# Couleurs bien placées : 0
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 1
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# Partie gagnée, bravo loic ! Cela t'a pris seulement 8 tours pour y arriver, you're so french !
# La solution était ['orange', 'noire', 'vert', 'rouge']
#
#
# Nouvelle partie
# Couleurs proposées : ['jaune', 'marron', 'rouge', 'noire']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 1680
# Le nombre de combinaisons quon veut enlever : 833
# Le nombre de combinaisons possibles après la suppression : 847
#
#
# {1: [['jaune', 'marron', 'rouge', 'noire'], 0, 2]}
#
#
# Couleurs proposées : ['orange', 'rouge', 'marron', 'noire']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 847
# Le nombre de combinaisons quon veut enlever : 343
# Le nombre de combinaisons possibles après la suppression : 504
#
#
# {1: [['jaune', 'marron', 'rouge', 'noire'], 0, 2],
#  2: [['orange', 'rouge', 'marron', 'noire'], 0, 2]}
#
#
# Couleurs proposées : ['marron', 'noire', 'jaune', 'rouge']
# Couleurs bien placées : 2
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 504
# Le nombre de combinaisons quon veut enlever : 392
# Le nombre de combinaisons possibles après la suppression : 111
#
#
# {1: [['jaune', 'marron', 'rouge', 'noire'], 0, 2],
#  2: [['orange', 'rouge', 'marron', 'noire'], 0, 2],
#  3: [['marron', 'noire', 'jaune', 'rouge'], 2, 0]}
#
#
# Couleurs proposées : ['jaune', 'noire', 'bleu', 'rouge']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 111
# Le nombre de combinaisons quon veut enlever : 39
# Le nombre de combinaisons possibles après la suppression : 72
#
#
# {1: [['jaune', 'marron', 'rouge', 'noire'], 0, 2],
#  2: [['orange', 'rouge', 'marron', 'noire'], 0, 2],
#  3: [['marron', 'noire', 'jaune', 'rouge'], 2, 0],
#  4: [['jaune', 'noire', 'bleu', 'rouge'], 0, 1]}
#
#
# Couleurs proposées : ['orange', 'noire', 'jaune', 'marron']
# Couleurs bien placées : 1
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 72
# Le nombre de combinaisons quon veut enlever : 53
# Le nombre de combinaisons possibles après la suppression : 19
#
#
# {1: [['jaune', 'marron', 'rouge', 'noire'], 0, 2],
#  2: [['orange', 'rouge', 'marron', 'noire'], 0, 2],
#  3: [['marron', 'noire', 'jaune', 'rouge'], 2, 0],
#  4: [['jaune', 'noire', 'bleu', 'rouge'], 0, 1],
#  5: [['orange', 'noire', 'jaune', 'marron'], 1, 2]}
#
#
# Couleurs proposées : ['marron', 'bleu', 'jaune', 'orange']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 19
# Le nombre de combinaisons quon veut enlever : 14
# Le nombre de combinaisons possibles après la suppression : 4
#
#
# {1: [['jaune', 'marron', 'rouge', 'noire'], 0, 2],
#  2: [['orange', 'rouge', 'marron', 'noire'], 0, 2],
#  3: [['marron', 'noire', 'jaune', 'rouge'], 2, 0],
#  4: [['jaune', 'noire', 'bleu', 'rouge'], 0, 1],
#  5: [['orange', 'noire', 'jaune', 'marron'], 1, 2],
#  6: [['marron', 'bleu', 'jaune', 'orange'], 3, 0]}
#
#
# Couleurs proposées : ['marron', 'noire', 'jaune', 'orange']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 4
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 3
#
#
# {1: [['jaune', 'marron', 'rouge', 'noire'], 0, 2],
#  2: [['orange', 'rouge', 'marron', 'noire'], 0, 2],
#  3: [['marron', 'noire', 'jaune', 'rouge'], 2, 0],
#  4: [['jaune', 'noire', 'bleu', 'rouge'], 0, 1],
#  5: [['orange', 'noire', 'jaune', 'marron'], 1, 2],
#  6: [['marron', 'bleu', 'jaune', 'orange'], 3, 0],
#  7: [['marron', 'noire', 'jaune', 'orange'], 3, 0]}
#
#
# Couleurs proposées : ['marron', 'rouge', 'jaune', 'orange']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 3
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 2
#
#
# {1: [['jaune', 'marron', 'rouge', 'noire'], 0, 2],
#  2: [['orange', 'rouge', 'marron', 'noire'], 0, 2],
#  3: [['marron', 'noire', 'jaune', 'rouge'], 2, 0],
#  4: [['jaune', 'noire', 'bleu', 'rouge'], 0, 1],
#  5: [['orange', 'noire', 'jaune', 'marron'], 1, 2],
#  6: [['marron', 'bleu', 'jaune', 'orange'], 3, 0],
#  7: [['marron', 'noire', 'jaune', 'orange'], 3, 0],
#  8: [['marron', 'rouge', 'jaune', 'orange'], 3, 0]}
#
#
# Couleurs proposées : ['marron', 'vert', 'jaune', 'orange']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 2
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# {1: [['jaune', 'marron', 'rouge', 'noire'], 0, 2],
#  2: [['orange', 'rouge', 'marron', 'noire'], 0, 2],
#  3: [['marron', 'noire', 'jaune', 'rouge'], 2, 0],
#  4: [['jaune', 'noire', 'bleu', 'rouge'], 0, 1],
#  5: [['orange', 'noire', 'jaune', 'marron'], 1, 2],
#  6: [['marron', 'bleu', 'jaune', 'orange'], 3, 0],
#  7: [['marron', 'noire', 'jaune', 'orange'], 3, 0],
#  8: [['marron', 'rouge', 'jaune', 'orange'], 3, 0],
#  9: [['marron', 'vert', 'jaune', 'orange'], 3, 0]}
#
#
# Couleurs proposées : ['marron', 'gris', 'jaune', 'orange']
# Couleurs bien placées : 0
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 1
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# Partie gagnée, bravo loic ! Cela t'a pris seulement 10 tours pour y arriver, you're so french !
# La solution était ['marron', 'gris', 'jaune', 'orange']
#
#
# Nouvelle partie
# Couleurs proposées : ['noire', 'jaune', 'marron', 'bleu']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 1680
# Le nombre de combinaisons quon veut enlever : 209
# Le nombre de combinaisons possibles après la suppression : 1471
#
#
# {1: [['noire', 'jaune', 'marron', 'bleu'], 0, 1]}
#
#
# Couleurs proposées : ['orange', 'bleu', 'gris', 'rouge']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 1471
# Le nombre de combinaisons quon veut enlever : 1045
# Le nombre de combinaisons possibles après la suppression : 426
#
#
# {1: [['noire', 'jaune', 'marron', 'bleu'], 0, 1],
#  2: [['orange', 'bleu', 'gris', 'rouge'], 1, 1]}
#
#
# Couleurs proposées : ['rouge', 'bleu', 'jaune', 'gris']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 426
# Le nombre de combinaisons quon veut enlever : 60
# Le nombre de combinaisons possibles après la suppression : 366
#
#
# {1: [['noire', 'jaune', 'marron', 'bleu'], 0, 1],
#  2: [['orange', 'bleu', 'gris', 'rouge'], 1, 1],
#  3: [['rouge', 'bleu', 'jaune', 'gris'], 0, 1]}
#
#
# Couleurs proposées : ['orange', 'marron', 'bleu', 'rouge']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 366
# Le nombre de combinaisons quon veut enlever : 202
# Le nombre de combinaisons possibles après la suppression : 164
#
#
# {1: [['noire', 'jaune', 'marron', 'bleu'], 0, 1],
#  2: [['orange', 'bleu', 'gris', 'rouge'], 1, 1],
#  3: [['rouge', 'bleu', 'jaune', 'gris'], 0, 1],
#  4: [['orange', 'marron', 'bleu', 'rouge'], 0, 2]}
#
#
# Couleurs proposées : ['marron', 'orange', 'gris', 'vert']
# Couleurs bien placées : 2
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 164
# Le nombre de combinaisons quon veut enlever : 162
# Le nombre de combinaisons possibles après la suppression : 2
#
#
# {1: [['noire', 'jaune', 'marron', 'bleu'], 0, 1],
#  2: [['orange', 'bleu', 'gris', 'rouge'], 1, 1],
#  3: [['rouge', 'bleu', 'jaune', 'gris'], 0, 1],
#  4: [['orange', 'marron', 'bleu', 'rouge'], 0, 2],
#  5: [['marron', 'orange', 'gris', 'vert'], 2, 2]}
#
#
# Couleurs proposées : ['vert', 'orange', 'gris', 'marron']
# Couleurs bien placées : 0
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 2
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# Partie gagnée, bravo loic ! Cela t'a pris seulement 6 tours pour y arriver, you're so french !
# La solution était ['vert', 'orange', 'gris', 'marron']
#
#
# Nouvelle partie
# Couleurs proposées : ['gris', 'marron', 'bleu', 'orange']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 1680
# Le nombre de combinaisons quon veut enlever : 209
# Le nombre de combinaisons possibles après la suppression : 1471
#
#
# {1: [['gris', 'marron', 'bleu', 'orange'], 0, 1]}
#
#
# Couleurs proposées : ['bleu', 'marron', 'jaune', 'rouge']
# Couleurs bien placées : 0
# Couleurs mal placées : 3
#
#
# Le nombre de combinaisons possibles avant la suppression : 1471
# Le nombre de combinaisons quon veut enlever : 1290
# Le nombre de combinaisons possibles après la suppression : 181
#
#
# {1: [['gris', 'marron', 'bleu', 'orange'], 0, 1],
#  2: [['bleu', 'marron', 'jaune', 'rouge'], 0, 3]}
#
#
# Couleurs proposées : ['jaune', 'bleu', 'rouge', 'vert']
# Couleurs bien placées : 1
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 181
# Le nombre de combinaisons quon veut enlever : 148
# Le nombre de combinaisons possibles après la suppression : 33
#
#
# {1: [['gris', 'marron', 'bleu', 'orange'], 0, 1],
#  2: [['bleu', 'marron', 'jaune', 'rouge'], 0, 3],
#  3: [['jaune', 'bleu', 'rouge', 'vert'], 1, 2]}
#
#
# Couleurs proposées : ['jaune', 'rouge', 'vert', 'bleu']
# Couleurs bien placées : 0
# Couleurs mal placées : 3
#
#
# Le nombre de combinaisons possibles avant la suppression : 33
# Le nombre de combinaisons quon veut enlever : 19
# Le nombre de combinaisons possibles après la suppression : 14
#
#
# {1: [['gris', 'marron', 'bleu', 'orange'], 0, 1],
#  2: [['bleu', 'marron', 'jaune', 'rouge'], 0, 3],
#  3: [['jaune', 'bleu', 'rouge', 'vert'], 1, 2],
#  4: [['jaune', 'rouge', 'vert', 'bleu'], 0, 3]}
#
#
# Couleurs proposées : ['rouge', 'bleu', 'vert', 'jaune']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 14
# Le nombre de combinaisons quon veut enlever : 9
# Le nombre de combinaisons possibles après la suppression : 4
#
#
# {1: [['gris', 'marron', 'bleu', 'orange'], 0, 1],
#  2: [['bleu', 'marron', 'jaune', 'rouge'], 0, 3],
#  3: [['jaune', 'bleu', 'rouge', 'vert'], 1, 2],
#  4: [['jaune', 'rouge', 'vert', 'bleu'], 0, 3],
#  5: [['rouge', 'bleu', 'vert', 'jaune'], 3, 0]}
#
#
# Couleurs proposées : ['rouge', 'bleu', 'gris', 'jaune']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 4
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 3
#
#
# {1: [['gris', 'marron', 'bleu', 'orange'], 0, 1],
#  2: [['bleu', 'marron', 'jaune', 'rouge'], 0, 3],
#  3: [['jaune', 'bleu', 'rouge', 'vert'], 1, 2],
#  4: [['jaune', 'rouge', 'vert', 'bleu'], 0, 3],
#  5: [['rouge', 'bleu', 'vert', 'jaune'], 3, 0],
#  6: [['rouge', 'bleu', 'gris', 'jaune'], 3, 0]}
#
#
# Couleurs proposées : ['rouge', 'bleu', 'marron', 'jaune']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 3
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 2
#
#
# {1: [['gris', 'marron', 'bleu', 'orange'], 0, 1],
#  2: [['bleu', 'marron', 'jaune', 'rouge'], 0, 3],
#  3: [['jaune', 'bleu', 'rouge', 'vert'], 1, 2],
#  4: [['jaune', 'rouge', 'vert', 'bleu'], 0, 3],
#  5: [['rouge', 'bleu', 'vert', 'jaune'], 3, 0],
#  6: [['rouge', 'bleu', 'gris', 'jaune'], 3, 0],
#  7: [['rouge', 'bleu', 'marron', 'jaune'], 3, 0]}
#
#
# Couleurs proposées : ['rouge', 'bleu', 'orange', 'jaune']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 2
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# {1: [['gris', 'marron', 'bleu', 'orange'], 0, 1],
#  2: [['bleu', 'marron', 'jaune', 'rouge'], 0, 3],
#  3: [['jaune', 'bleu', 'rouge', 'vert'], 1, 2],
#  4: [['jaune', 'rouge', 'vert', 'bleu'], 0, 3],
#  5: [['rouge', 'bleu', 'vert', 'jaune'], 3, 0],
#  6: [['rouge', 'bleu', 'gris', 'jaune'], 3, 0],
#  7: [['rouge', 'bleu', 'marron', 'jaune'], 3, 0],
#  8: [['rouge', 'bleu', 'orange', 'jaune'], 3, 0]}
#
#
# Couleurs proposées : ['rouge', 'bleu', 'noire', 'jaune']
# Couleurs bien placées : 0
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 1
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# Partie gagnée, bravo loic ! Cela t'a pris seulement 9 tours pour y arriver, you're so french !
# La solution était ['rouge', 'bleu', 'noire', 'jaune']
#
#
# Nouvelle partie
# Couleurs proposées : ['noire', 'vert', 'bleu', 'marron']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 1680
# Le nombre de combinaisons quon veut enlever : 833
# Le nombre de combinaisons possibles après la suppression : 847
#
#
# {1: [['noire', 'vert', 'bleu', 'marron'], 0, 2]}
#
#
# Couleurs proposées : ['gris', 'noire', 'marron', 'orange']
# Couleurs bien placées : 2
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 847
# Le nombre de combinaisons quon veut enlever : 759
# Le nombre de combinaisons possibles après la suppression : 87
#
#
# {1: [['noire', 'vert', 'bleu', 'marron'], 0, 2],
#  2: [['gris', 'noire', 'marron', 'orange'], 2, 0]}
#
#
# Couleurs proposées : ['bleu', 'rouge', 'marron', 'orange']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 87
# Le nombre de combinaisons quon veut enlever : 42
# Le nombre de combinaisons possibles après la suppression : 45
#
#
# {1: [['noire', 'vert', 'bleu', 'marron'], 0, 2],
#  2: [['gris', 'noire', 'marron', 'orange'], 2, 0],
#  3: [['bleu', 'rouge', 'marron', 'orange'], 1, 1]}
#
#
# Couleurs proposées : ['marron', 'noire', 'bleu', 'orange']
# Couleurs bien placées : 2
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 45
# Le nombre de combinaisons quon veut enlever : 35
# Le nombre de combinaisons possibles après la suppression : 9
#
#
# {1: [['noire', 'vert', 'bleu', 'marron'], 0, 2],
#  2: [['gris', 'noire', 'marron', 'orange'], 2, 0],
#  3: [['bleu', 'rouge', 'marron', 'orange'], 1, 1],
#  4: [['marron', 'noire', 'bleu', 'orange'], 2, 0]}
#
#
# Couleurs proposées : ['marron', 'noire', 'jaune', 'orange']
# Couleurs bien placées : 2
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 9
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 8
#
#
# {1: [['noire', 'vert', 'bleu', 'marron'], 0, 2],
#  2: [['gris', 'noire', 'marron', 'orange'], 2, 0],
#  3: [['bleu', 'rouge', 'marron', 'orange'], 1, 1],
#  4: [['marron', 'noire', 'bleu', 'orange'], 2, 0],
#  5: [['marron', 'noire', 'jaune', 'orange'], 2, 0]}
#
#
# Couleurs proposées : ['bleu', 'noire', 'rouge', 'orange']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 8
# Le nombre de combinaisons quon veut enlever : 5
# Le nombre de combinaisons possibles après la suppression : 2
#
#
# {1: [['noire', 'vert', 'bleu', 'marron'], 0, 2],
#  2: [['gris', 'noire', 'marron', 'orange'], 2, 0],
#  3: [['bleu', 'rouge', 'marron', 'orange'], 1, 1],
#  4: [['marron', 'noire', 'bleu', 'orange'], 2, 0],
#  5: [['marron', 'noire', 'jaune', 'orange'], 2, 0],
#  6: [['bleu', 'noire', 'rouge', 'orange'], 3, 0]}
#
#
# Couleurs proposées : ['vert', 'noire', 'rouge', 'orange']
# Couleurs bien placées : 0
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 2
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# Partie gagnée, bravo loic ! Cela t'a pris seulement 7 tours pour y arriver, you're so french !
# La solution était ['vert', 'noire', 'rouge', 'orange']
#
#
# Nouvelle partie
# Couleurs proposées : ['rouge', 'gris', 'orange', 'vert']
# Couleurs bien placées : 2
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 1680
# Le nombre de combinaisons quon veut enlever : 1537
# Le nombre de combinaisons possibles après la suppression : 142
#
#
# {1: [['rouge', 'gris', 'orange', 'vert'], 2, 0]}
#
#
# Couleurs proposées : ['jaune', 'gris', 'rouge', 'vert']
# Couleurs bien placées : 1
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 142
# Le nombre de combinaisons quon veut enlever : 21
# Le nombre de combinaisons possibles après la suppression : 120
#
#
# {1: [['rouge', 'gris', 'orange', 'vert'], 2, 0],
#  2: [['jaune', 'gris', 'rouge', 'vert'], 1, 0]}
#
#
# Couleurs proposées : ['orange', 'gris', 'rouge', 'vert']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 120
# Le nombre de combinaisons quon veut enlever : 20
# Le nombre de combinaisons possibles après la suppression : 100
#
#
# {1: [['rouge', 'gris', 'orange', 'vert'], 2, 0],
#  2: [['jaune', 'gris', 'rouge', 'vert'], 1, 0],
#  3: [['orange', 'gris', 'rouge', 'vert'], 1, 1]}
#
#
# Couleurs proposées : ['rouge', 'marron', 'bleu', 'vert']
# Couleurs bien placées : 0
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 100
# Le nombre de combinaisons quon veut enlever : 40
# Le nombre de combinaisons possibles après la suppression : 60
#
#
# {1: [['rouge', 'gris', 'orange', 'vert'], 2, 0],
#  2: [['jaune', 'gris', 'rouge', 'vert'], 1, 0],
#  3: [['orange', 'gris', 'rouge', 'vert'], 1, 1],
#  4: [['rouge', 'marron', 'bleu', 'vert'], 0, 1]}
#
#
# Couleurs proposées : ['rouge', 'gris', 'vert', 'noire']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 60
# Le nombre de combinaisons quon veut enlever : 36
# Le nombre de combinaisons possibles après la suppression : 24
#
#
# {1: [['rouge', 'gris', 'orange', 'vert'], 2, 0],
#  2: [['jaune', 'gris', 'rouge', 'vert'], 1, 0],
#  3: [['orange', 'gris', 'rouge', 'vert'], 1, 1],
#  4: [['rouge', 'marron', 'bleu', 'vert'], 0, 1],
#  5: [['rouge', 'gris', 'vert', 'noire'], 1, 1]}
#
#
# Couleurs proposées : ['noire', 'gris', 'orange', 'bleu']
# Couleurs bien placées : 0
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 24
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 23
#
#
# Partie gagnée, bravo loic ! Cela t'a pris seulement 6 tours pour y arriver, you're so french !
# La solution était ['noire', 'gris', 'orange', 'bleu']
#
#
# Nouvelle partie
# Couleurs proposées : ['orange', 'jaune', 'marron', 'bleu']
# Couleurs bien placées : 1
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 1680
# Le nombre de combinaisons quon veut enlever : 1001
# Le nombre de combinaisons possibles après la suppression : 678
#
#
# {1: [['orange', 'jaune', 'marron', 'bleu'], 1, 0]}
#
#
# Couleurs proposées : ['rouge', 'marron', 'gris', 'bleu']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 678
# Le nombre de combinaisons quon veut enlever : 461
# Le nombre de combinaisons possibles après la suppression : 217
#
#
# {1: [['orange', 'jaune', 'marron', 'bleu'], 1, 0],
# ...
#
#
# {1: [['jaune', 'orange', 'marron', 'gris'], 1, 2],
#  2: [['jaune', 'gris', 'bleu', 'marron'], 1, 1],
#  3: [['noire', 'gris', 'marron', 'orange'], 0, 3],
#  4: [['gris', 'orange', 'noire', 'marron'], 0, 3]}
#
#
# Couleurs proposées : ['jaune', 'marron', 'gris', 'noire']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 4
# Le nombre de combinaisons quon veut enlever : 2
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# {1: [['jaune', 'orange', 'marron', 'gris'], 1, 2],
#  2: [['jaune', 'gris', 'bleu', 'marron'], 1, 1],
#  3: [['noire', 'gris', 'marron', 'orange'], 0, 3],
#  4: [['gris', 'orange', 'noire', 'marron'], 0, 3],
#  5: [['jaune', 'marron', 'gris', 'noire'], 3, 0]}
#
#
# Couleurs proposées : ['jaune', 'marron', 'orange', 'noire']
# Couleurs bien placées : 0
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 1
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# Partie gagnée, bravo loic ! Cela t'a pris seulement 6 tours pour y arriver, you're so french !
# La solution était ['jaune', 'marron', 'orange', 'noire']
#
#
# Nouvelle partie
# Couleurs proposées : ['vert', 'jaune', 'orange', 'gris']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 1680
# Le nombre de combinaisons quon veut enlever : 833
# Le nombre de combinaisons possibles après la suppression : 847
#
#
# {1: [['vert', 'jaune', 'orange', 'gris'], 0, 2]}
#
#
# Couleurs proposées : ['marron', 'orange', 'jaune', 'gris']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 847
# Le nombre de combinaisons quon veut enlever : 836
# Le nombre de combinaisons possibles après la suppression : 10
#
#
# {1: [['vert', 'jaune', 'orange', 'gris'], 0, 2],
#  2: [['marron', 'orange', 'jaune', 'gris'], 3, 0]}
#
#
# Couleurs proposées : ['rouge', 'orange', 'jaune', 'gris']
# Couleurs bien placées : 2
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 10
# Le nombre de combinaisons quon veut enlever : 9
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# {1: [['vert', 'jaune', 'orange', 'gris'], 0, 2],
#  2: [['marron', 'orange', 'jaune', 'gris'], 3, 0],
#  3: [['rouge', 'orange', 'jaune', 'gris'], 2, 1]}
#
#
# Couleurs proposées : ['marron', 'orange', 'jaune', 'rouge']
# Couleurs bien placées : 0
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 1
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# Partie gagnée, bravo loic ! Cela t'a pris seulement 4 tours pour y arriver, you're so french !
# La solution était ['marron', 'orange', 'jaune', 'rouge']
#
#
# Nouvelle partie
# Couleurs proposées : ['orange', 'noire', 'marron', 'rouge']
# Couleurs bien placées : 0
# Couleurs mal placées : 3
#
#
# Le nombre de combinaisons possibles avant la suppression : 1680
# Le nombre de combinaisons quon veut enlever : 1487
# Le nombre de combinaisons possibles après la suppression : 193
#
#
# {1: [['orange', 'noire', 'marron', 'rouge'], 0, 3]}
#
#
# Couleurs proposées : ['rouge', 'jaune', 'orange', 'noire']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 193
# Le nombre de combinaisons quon veut enlever : 105
# Le nombre de combinaisons possibles après la suppression : 88
#
#
# {1: [['orange', 'noire', 'marron', 'rouge'], 0, 3],
#  2: [['rouge', 'jaune', 'orange', 'noire'], 1, 1]}
#
#
# Couleurs proposées : ['noire', 'marron', 'orange', 'bleu']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 88
# Le nombre de combinaisons quon veut enlever : 38
# Le nombre de combinaisons possibles après la suppression : 50
#
#
# {1: [['orange', 'noire', 'marron', 'rouge'], 0, 3],
#  2: [['rouge', 'jaune', 'orange', 'noire'], 1, 1],
#  3: [['noire', 'marron', 'orange', 'bleu'], 0, 2]}
#
#
# Couleurs proposées : ['marron', 'orange', 'jaune', 'noire']
# Couleurs bien placées : 2
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 50
# Le nombre de combinaisons quon veut enlever : 26
# Le nombre de combinaisons possibles après la suppression : 23
#
#
# {1: [['orange', 'noire', 'marron', 'rouge'], 0, 3],
#  2: [['rouge', 'jaune', 'orange', 'noire'], 1, 1],
#  3: [['noire', 'marron', 'orange', 'bleu'], 0, 2],
#  4: [['marron', 'orange', 'jaune', 'noire'], 2, 0]}
#
#
# Couleurs proposées : ['marron', 'gris', 'rouge', 'noire']
# Couleurs bien placées : 0
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 23
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 22
#
#
# Partie gagnée, bravo loic ! Cela t'a pris seulement 5 tours pour y arriver, you're so french !
# La solution était ['marron', 'gris', 'rouge', 'noire']
#
#
# Nouvelle partie
# Couleurs proposées : ['gris', 'noire', 'rouge', 'jaune']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 1680
# Le nombre de combinaisons quon veut enlever : 1186
# Le nombre de combinaisons possibles après la suppression : 494
#
#
# {1: [['gris', 'noire', 'rouge', 'jaune'], 1, 1]}
#
#
# Couleurs proposées : ['bleu', 'vert', 'rouge', 'gris']
# Couleurs bien placées : 1
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 494
# Le nombre de combinaisons quon veut enlever : 453
# Le nombre de combinaisons possibles après la suppression : 41
#
#
# {1: [['gris', 'noire', 'rouge', 'jaune'], 1, 1],
#  2: [['bleu', 'vert', 'rouge', 'gris'], 1, 2]}
#
#
# Couleurs proposées : ['gris', 'vert', 'noire', 'bleu']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 41
# Le nombre de combinaisons quon veut enlever : 38
# Le nombre de combinaisons possibles après la suppression : 2
#
#
# {1: [['gris', 'noire', 'rouge', 'jaune'], 1, 1],
#  2: [['bleu', 'vert', 'rouge', 'gris'], 1, 2],
#  3: [['gris', 'vert', 'noire', 'bleu'], 3, 0]}
#
#
# Couleurs proposées : ['gris', 'vert', 'jaune', 'bleu']
# Couleurs bien placées : 0
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 2
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# Partie gagnée, bravo loic ! Cela t'a pris seulement 4 tours pour y arriver, you're so french !
# La solution était ['gris', 'vert', 'jaune', 'bleu']
#
#
# Nouvelle partie
# Couleurs proposées : ['bleu', 'noire', 'jaune', 'marron']
# Couleurs bien placées : 0
# Couleurs mal placées : 3
#
#
# Le nombre de combinaisons possibles avant la suppression : 1680
# Le nombre de combinaisons quon veut enlever : 1487
# Le nombre de combinaisons possibles après la suppression : 193
#
#
# {1: [['bleu', 'noire', 'jaune', 'marron'], 0, 3]}
#
#
# Couleurs proposées : ['marron', 'bleu', 'noire', 'jaune']
# Couleurs bien placées : 1
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 193
# Le nombre de combinaisons quon veut enlever : 119
# Le nombre de combinaisons possibles après la suppression : 74
#
#
# {1: [['bleu', 'noire', 'jaune', 'marron'], 0, 3],
#  2: [['marron', 'bleu', 'noire', 'jaune'], 1, 2]}
#
#
# Couleurs proposées : ['noire', 'gris', 'bleu', 'jaune']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 74
# Le nombre de combinaisons quon veut enlever : 55
# Le nombre de combinaisons possibles après la suppression : 19
#
#
# {1: [['bleu', 'noire', 'jaune', 'marron'], 0, 3],
#  2: [['marron', 'bleu', 'noire', 'jaune'], 1, 2],
#  3: [['noire', 'gris', 'bleu', 'jaune'], 1, 1]}
#
#
# Couleurs proposées : ['bleu', 'marron', 'noire', 'jaune']
# Couleurs bien placées : 0
# Couleurs mal placées : 3
#
#
# Le nombre de combinaisons possibles avant la suppression : 19
# Le nombre de combinaisons quon veut enlever : 4
# Le nombre de combinaisons possibles après la suppression : 15
#
#
# {1: [['bleu', 'noire', 'jaune', 'marron'], 0, 3],
#  2: [['marron', 'bleu', 'noire', 'jaune'], 1, 2],
#  3: [['noire', 'gris', 'bleu', 'jaune'], 1, 1],
#  4: [['bleu', 'marron', 'noire', 'jaune'], 0, 3]}
#
#
# Couleurs proposées : ['noire', 'bleu', 'marron', 'vert']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 15
# Le nombre de combinaisons quon veut enlever : 5
# Le nombre de combinaisons possibles après la suppression : 10
#
#
# {1: [['bleu', 'noire', 'jaune', 'marron'], 0, 3],
#  2: [['marron', 'bleu', 'noire', 'jaune'], 1, 2],
#  3: [['noire', 'gris', 'bleu', 'jaune'], 1, 1],
#  4: [['bleu', 'marron', 'noire', 'jaune'], 0, 3],
#  5: [['noire', 'bleu', 'marron', 'vert'], 0, 2]}
#
#
# Couleurs proposées : ['marron', 'jaune', 'bleu', 'vert']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 10
# Le nombre de combinaisons quon veut enlever : 5
# Le nombre de combinaisons possibles après la suppression : 4
#
#
# {1: [['bleu', 'noire', 'jaune', 'marron'], 0, 3],
#  2: [['marron', 'bleu', 'noire', 'jaune'], 1, 2],
#  3: [['noire', 'gris', 'bleu', 'jaune'], 1, 1],
#  4: [['bleu', 'marron', 'noire', 'jaune'], 0, 3],
#  5: [['noire', 'bleu', 'marron', 'vert'], 0, 2],
#  6: [['marron', 'jaune', 'bleu', 'vert'], 3, 0]}
#
#
# Couleurs proposées : ['marron', 'jaune', 'bleu', 'orange']
# Couleurs bien placées : 0
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 4
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 3
#
#
# Partie gagnée, bravo loic ! Cela t'a pris seulement 7 tours pour y arriver, you're so french !
# La solution était ['marron', 'jaune', 'bleu', 'orange']
#
#
# Nouvelle partie
# Couleurs proposées : ['gris', 'noire', 'rouge', 'orange']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 1680
# Le nombre de combinaisons quon veut enlever : 1186
# Le nombre de combinaisons possibles après la suppression : 494
#
#
# {1: [['gris', 'noire', 'rouge', 'orange'], 1, 1]}
#
#
# Couleurs proposées : ['vert', 'noire', 'orange', 'jaune']
# Couleurs bien placées : 2
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 494
# Le nombre de combinaisons quon veut enlever : 435
# Le nombre de combinaisons possibles après la suppression : 58
#
#
# {1: [['gris', 'noire', 'rouge', 'orange'], 1, 1],
#  2: [['vert', 'noire', 'orange', 'jaune'], 2, 0]}
#
#
# Couleurs proposées : ['vert', 'noire', 'jaune', 'rouge']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 58
# Le nombre de combinaisons quon veut enlever : 27
# Le nombre de combinaisons possibles après la suppression : 31
#
#
# {1: [['gris', 'noire', 'rouge', 'orange'], 1, 1],
#  2: [['vert', 'noire', 'orange', 'jaune'], 2, 0],
#  3: [['vert', 'noire', 'jaune', 'rouge'], 1, 1]}
#
#
# Couleurs proposées : ['rouge', 'noire', 'orange', 'marron']
# Couleurs bien placées : 1
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 31
# Le nombre de combinaisons quon veut enlever : 20
# Le nombre de combinaisons possibles après la suppression : 11
#
#
# {1: [['gris', 'noire', 'rouge', 'orange'], 1, 1],
#  2: [['vert', 'noire', 'orange', 'jaune'], 2, 0],
#  3: [['vert', 'noire', 'jaune', 'rouge'], 1, 1],
#  4: [['rouge', 'noire', 'orange', 'marron'], 1, 1]}
#
#
# Couleurs proposées : ['orange', 'noire', 'marron', 'jaune']
# Couleurs bien placées : 2
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 11
# Le nombre de combinaisons quon veut enlever : 9
# Le nombre de combinaisons possibles après la suppression : 2
#
#
# {1: [['gris', 'noire', 'rouge', 'orange'], 1, 1],
#  2: [['vert', 'noire', 'orange', 'jaune'], 2, 0],
#  3: [['vert', 'noire', 'jaune', 'rouge'], 1, 1],
#  4: [['rouge', 'noire', 'orange', 'marron'], 1, 1],
#  5: [['orange', 'noire', 'marron', 'jaune'], 2, 1]}
#
#
# Couleurs proposées : ['marron', 'noire', 'gris', 'jaune']
# Couleurs bien placées : 0
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 2
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 1
#
#
# Partie gagnée, bravo loic ! Cela t'a pris seulement 6 tours pour y arriver, you're so french !
# La solution était ['marron', 'noire', 'gris', 'jaune']
#
#
# Nouvelle partie
# Couleurs proposées : ['marron', 'vert', 'rouge', 'noire']
# Couleurs bien placées : 1
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 1680
# Le nombre de combinaisons quon veut enlever : 1522
# Le nombre de combinaisons possibles après la suppression : 158
#
#
# {1: [['marron', 'vert', 'rouge', 'noire'], 1, 2]}
#
#
# Couleurs proposées : ['rouge', 'marron', 'bleu', 'noire']
# Couleurs bien placées : 0
# Couleurs mal placées : 2
#
#
# Le nombre de combinaisons possibles avant la suppression : 158
# Le nombre de combinaisons quon veut enlever : 48
# Le nombre de combinaisons possibles après la suppression : 110
#
#
# {1: [['marron', 'vert', 'rouge', 'noire'], 1, 2],
#  2: [['rouge', 'marron', 'bleu', 'noire'], 0, 2]}
#
#
# Couleurs proposées : ['marron', 'orange', 'noire', 'vert']
# Couleurs bien placées : 0
# Couleurs mal placées : 3
#
#
# Le nombre de combinaisons possibles avant la suppression : 110
# Le nombre de combinaisons quon veut enlever : 89
# Le nombre de combinaisons possibles après la suppression : 21
#
#
# {1: [['marron', 'vert', 'rouge', 'noire'], 1, 2],
#  2: [['rouge', 'marron', 'bleu', 'noire'], 0, 2],
#  3: [['marron', 'orange', 'noire', 'vert'], 0, 3]}
#
#
# Couleurs proposées : ['noire', 'vert', 'orange', 'rouge']
# Couleurs bien placées : 2
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 21
# Le nombre de combinaisons quon veut enlever : 9
# Le nombre de combinaisons possibles après la suppression : 11
#
#
# {1: [['marron', 'vert', 'rouge', 'noire'], 1, 2],
#  2: [['rouge', 'marron', 'bleu', 'noire'], 0, 2],
#  3: [['marron', 'orange', 'noire', 'vert'], 0, 3],
#  4: [['noire', 'vert', 'orange', 'rouge'], 2, 0]}
#
#
# Couleurs proposées : ['noire', 'vert', 'orange', 'marron']
# Couleurs bien placées : 2
# Couleurs mal placées : 1
#
#
# Le nombre de combinaisons possibles avant la suppression : 11
# Le nombre de combinaisons quon veut enlever : 6
# Le nombre de combinaisons possibles après la suppression : 5
#
#
# {1: [['marron', 'vert', 'rouge', 'noire'], 1, 2],
#  2: [['rouge', 'marron', 'bleu', 'noire'], 0, 2],
#  3: [['marron', 'orange', 'noire', 'vert'], 0, 3],
#  4: [['noire', 'vert', 'orange', 'rouge'], 2, 0],
#  5: [['noire', 'vert', 'orange', 'marron'], 2, 1]}
#
#
# Couleurs proposées : ['noire', 'vert', 'marron', 'jaune']
# Couleurs bien placées : 3
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 5
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 4
#
#
# {1: [['marron', 'vert', 'rouge', 'noire'], 1, 2],
#  2: [['rouge', 'marron', 'bleu', 'noire'], 0, 2],
#  3: [['marron', 'orange', 'noire', 'vert'], 0, 3],
#  4: [['noire', 'vert', 'orange', 'rouge'], 2, 0],
#  5: [['noire', 'vert', 'orange', 'marron'], 2, 1],
#  6: [['noire', 'vert', 'marron', 'jaune'], 3, 0]}
#
#
# Couleurs proposées : ['noire', 'vert', 'marron', 'gris']
# Couleurs bien placées : 0
# Couleurs mal placées : 0
#
#
# Le nombre de combinaisons possibles avant la suppression : 4
# Le nombre de combinaisons quon veut enlever : 0
# Le nombre de combinaisons possibles après la suppression : 3
#
#
# Partie gagnée, bravo loic ! Cela t'a pris seulement 7 tours pour y arriver, you're so french !
# La solution était ['noire', 'vert', 'marron', 'gris']
#
#
# IaDumb : 2 victoires sur 1000 parties - soit un taux de 0.200000%
# Elle met en moyenne 4 tours pour gagner.
# IaSmart : 971 victoires sur 1000 parties - soit un taux de 97.100000%
# Elle met en moyenne 7.33 tours pour gagner.
# Text(0.5, 1.0, "Pourcentage de victoires en fonction de 1000 parties de l'IaSmart")
